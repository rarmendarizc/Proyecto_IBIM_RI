# %%
import os

# Ruta donde están los archivos
ruta_carpeta = "./data"

# Iterar sobre todos los archivos en la carpeta
for archivo in os.listdir(ruta_carpeta):
    # Ruta completa del archivo original
    archivo_original = os.path.join(ruta_carpeta, archivo)

    # Verificar que sea un archivo (no una carpeta)
    if os.path.isfile(archivo_original):
        # Separar el nombre y la extensión
        nombre, extension = os.path.splitext(archivo)

        # Crear el nuevo nombre con la extensión .txt
        nuevo_nombre = nombre + ".txt"
        archivo_nuevo = os.path.join(ruta_carpeta, nuevo_nombre)

        # Renombrar el archivo
        os.rename(archivo_original, archivo_nuevo)
        print(f"Archivo renombrado: {archivo} -> {nuevo_nombre}")
# Out:
# Archivo renombrado: 1 -> 1.txt
# Archivo renombrado: 10 -> 10.txt
# Archivo renombrado: 100 -> 100.txt
# Archivo renombrado: 1000 -> 1000.txt
# Archivo renombrado: 10000 -> 10000.txt
# Archivo renombrado: 10002 -> 10002.txt
# Archivo renombrado: 10005 -> 10005.txt
# Archivo renombrado: 10008 -> 10008.txt
# Archivo renombrado: 10011 -> 10011.txt
# Archivo renombrado: 10014 -> 10014.txt
# Archivo renombrado: 10015 -> 10015.txt
# Archivo renombrado: 10018 -> 10018.txt
# Archivo renombrado: 10023 -> 10023.txt
# Archivo renombrado: 10025 -> 10025.txt
# Archivo renombrado: 10027 -> 10027.txt
# Archivo renombrado: 1003 -> 1003.txt
# Archivo renombrado: 10032 -> 10032.txt
# Archivo renombrado: 10035 -> 10035.txt
# Archivo renombrado: 10037 -> 10037.txt
# Archivo renombrado: 10038 -> 10038.txt
# Archivo renombrado: 10040 -> 10040.txt
# Archivo renombrado: 10041 -> 10041.txt
# Archivo renombrado: 10042 -> 10042.txt
# Archivo renombrado: 10043 -> 10043.txt
# Archivo renombrado: 10046 -> 10046.txt
# Archivo renombrado: 10048 -> 10048.txt
# Archivo renombrado: 10049 -> 10049.txt
# Archivo renombrado: 10050 -> 10050.txt
# Archivo renombrado: 10052 -> 10052.txt
# Archivo renombrado: 10053 -> 10053.txt
# Archivo renombrado: 10054 -> 10054.txt
# Archivo renombrado: 10057 -> 10057.txt
# Archivo renombrado: 10058 -> 10058.txt
# Archivo renombrado: 10061 -> 10061.txt
# Archivo renombrado: 10062 -> 10062.txt
# Archivo renombrado: 10064 -> 10064.txt
# Archivo renombrado: 10065 -> 10065.txt
# Archivo renombrado: 10066 -> 10066.txt
# Archivo renombrado: 10067 -> 10067.txt
# Archivo renombrado: 10068 -> 10068.txt
# Archivo renombrado: 1007 -> 1007.txt
# Archivo renombrado: 10071 -> 10071.txt
# Archivo renombrado: 10073 -> 10073.txt
# Archivo renombrado: 10074 -> 10074.txt
# Archivo renombrado: 10075 -> 10075.txt
# Archivo renombrado: 10076 -> 10076.txt
# Archivo renombrado: 10078 -> 10078.txt
# Archivo renombrado: 10079 -> 10079.txt
# Archivo renombrado: 1008 -> 1008.txt
# Archivo renombrado: 10080 -> 10080.txt
# Archivo renombrado: 10081 -> 10081.txt
# Archivo renombrado: 10083 -> 10083.txt
# Archivo renombrado: 10085 -> 10085.txt
# Archivo renombrado: 10086 -> 10086.txt
# Archivo renombrado: 10088 -> 10088.txt
# Archivo renombrado: 10089 -> 10089.txt
# Archivo renombrado: 1009 -> 1009.txt
# Archivo renombrado: 10090 -> 10090.txt
# Archivo renombrado: 10091 -> 10091.txt
# Archivo renombrado: 10092 -> 10092.txt
# Archivo renombrado: 10094 -> 10094.txt
# Archivo renombrado: 10095 -> 10095.txt
# Archivo renombrado: 10096 -> 10096.txt
# Archivo renombrado: 10097 -> 10097.txt
# Archivo renombrado: 10098 -> 10098.txt
# Archivo renombrado: 10099 -> 10099.txt
# Archivo renombrado: 101 -> 101.txt
# Archivo renombrado: 1010 -> 1010.txt
# Archivo renombrado: 10100 -> 10100.txt
# Archivo renombrado: 10102 -> 10102.txt
# Archivo renombrado: 10105 -> 10105.txt
# Archivo renombrado: 10106 -> 10106.txt
# Archivo renombrado: 10107 -> 10107.txt
# Archivo renombrado: 10108 -> 10108.txt
# Archivo renombrado: 10109 -> 10109.txt
# Archivo renombrado: 1011 -> 1011.txt
# Archivo renombrado: 10110 -> 10110.txt
# Archivo renombrado: 10112 -> 10112.txt
# Archivo renombrado: 10114 -> 10114.txt
# Archivo renombrado: 10115 -> 10115.txt
# Archivo renombrado: 10119 -> 10119.txt
# Archivo renombrado: 10120 -> 10120.txt
# Archivo renombrado: 10122 -> 10122.txt
# Archivo renombrado: 10124 -> 10124.txt
# Archivo renombrado: 10128 -> 10128.txt
# Archivo renombrado: 10129 -> 10129.txt
# Archivo renombrado: 1013 -> 1013.txt
# Archivo renombrado: 10130 -> 10130.txt
# Archivo renombrado: 10135 -> 10135.txt
# Archivo renombrado: 10136 -> 10136.txt
# Archivo renombrado: 10139 -> 10139.txt
# Archivo renombrado: 10140 -> 10140.txt
# Archivo renombrado: 10146 -> 10146.txt
# Archivo renombrado: 1015 -> 1015.txt
# Archivo renombrado: 10151 -> 10151.txt
# Archivo renombrado: 10153 -> 10153.txt
# Archivo renombrado: 10154 -> 10154.txt
# Archivo renombrado: 10155 -> 10155.txt
# Archivo renombrado: 10156 -> 10156.txt
# Archivo renombrado: 10158 -> 10158.txt
# Archivo renombrado: 1016 -> 1016.txt
# Archivo renombrado: 10162 -> 10162.txt
# Archivo renombrado: 10163 -> 10163.txt
# Archivo renombrado: 10165 -> 10165.txt
# Archivo renombrado: 10168 -> 10168.txt
# Archivo renombrado: 1017 -> 1017.txt
# Archivo renombrado: 10171 -> 10171.txt
# Archivo renombrado: 10172 -> 10172.txt
# Archivo renombrado: 10173 -> 10173.txt
# Archivo renombrado: 10174 -> 10174.txt
# Archivo renombrado: 10175 -> 10175.txt
# Archivo renombrado: 10176 -> 10176.txt
# Archivo renombrado: 10177 -> 10177.txt
# Archivo renombrado: 10178 -> 10178.txt
# Archivo renombrado: 10180 -> 10180.txt
# Archivo renombrado: 10181 -> 10181.txt
# Archivo renombrado: 10183 -> 10183.txt
# Archivo renombrado: 10185 -> 10185.txt
# Archivo renombrado: 10186 -> 10186.txt
# Archivo renombrado: 1019 -> 1019.txt
# Archivo renombrado: 10190 -> 10190.txt
# Archivo renombrado: 10191 -> 10191.txt
# Archivo renombrado: 10192 -> 10192.txt
# Archivo renombrado: 10196 -> 10196.txt
# Archivo renombrado: 10197 -> 10197.txt
# Archivo renombrado: 102 -> 102.txt
# Archivo renombrado: 1020 -> 1020.txt
# Archivo renombrado: 10200 -> 10200.txt
# Archivo renombrado: 10201 -> 10201.txt
# Archivo renombrado: 10207 -> 10207.txt
# Archivo renombrado: 10208 -> 10208.txt
# Archivo renombrado: 10209 -> 10209.txt
# Archivo renombrado: 10211 -> 10211.txt
# Archivo renombrado: 10213 -> 10213.txt
# Archivo renombrado: 10214 -> 10214.txt
# Archivo renombrado: 10215 -> 10215.txt
# Archivo renombrado: 10216 -> 10216.txt
# Archivo renombrado: 10218 -> 10218.txt
# Archivo renombrado: 10219 -> 10219.txt
# Archivo renombrado: 1022 -> 1022.txt
# Archivo renombrado: 10222 -> 10222.txt
# Archivo renombrado: 10224 -> 10224.txt
# Archivo renombrado: 10225 -> 10225.txt
# Archivo renombrado: 10227 -> 10227.txt
# Archivo renombrado: 10228 -> 10228.txt
# Archivo renombrado: 1023 -> 1023.txt
# Archivo renombrado: 10230 -> 10230.txt
# Archivo renombrado: 10231 -> 10231.txt
# Archivo renombrado: 10233 -> 10233.txt
# Archivo renombrado: 10235 -> 10235.txt
# Archivo renombrado: 10237 -> 10237.txt
# Archivo renombrado: 10238 -> 10238.txt
# Archivo renombrado: 1024 -> 1024.txt
# Archivo renombrado: 10240 -> 10240.txt
# Archivo renombrado: 10242 -> 10242.txt
# Archivo renombrado: 10243 -> 10243.txt
# Archivo renombrado: 10245 -> 10245.txt
# Archivo renombrado: 10246 -> 10246.txt
# Archivo renombrado: 10253 -> 10253.txt
# Archivo renombrado: 10254 -> 10254.txt
# Archivo renombrado: 10255 -> 10255.txt
# Archivo renombrado: 10258 -> 10258.txt
# Archivo renombrado: 1026 -> 1026.txt
# Archivo renombrado: 10260 -> 10260.txt
# Archivo renombrado: 10261 -> 10261.txt
# Archivo renombrado: 10262 -> 10262.txt
# Archivo renombrado: 10263 -> 10263.txt
# Archivo renombrado: 10264 -> 10264.txt
# Archivo renombrado: 10265 -> 10265.txt
# Archivo renombrado: 10268 -> 10268.txt
# Archivo renombrado: 10272 -> 10272.txt
# Archivo renombrado: 10275 -> 10275.txt
# Archivo renombrado: 10277 -> 10277.txt
# Archivo renombrado: 10280 -> 10280.txt
# Archivo renombrado: 10281 -> 10281.txt
# Archivo renombrado: 10282 -> 10282.txt
# Archivo renombrado: 10283 -> 10283.txt
# Archivo renombrado: 10284 -> 10284.txt
# Archivo renombrado: 10285 -> 10285.txt
# Archivo renombrado: 10289 -> 10289.txt
# Archivo renombrado: 1029 -> 1029.txt
# Archivo renombrado: 10291 -> 10291.txt
# Archivo renombrado: 10292 -> 10292.txt
# Archivo renombrado: 10294 -> 10294.txt
# Archivo renombrado: 10295 -> 10295.txt
# Archivo renombrado: 10297 -> 10297.txt
# Archivo renombrado: 10299 -> 10299.txt
# Archivo renombrado: 103 -> 103.txt
# Archivo renombrado: 1030 -> 1030.txt
# Archivo renombrado: 10300 -> 10300.txt
# Archivo renombrado: 10302 -> 10302.txt
# Archivo renombrado: 10305 -> 10305.txt
# Archivo renombrado: 10306 -> 10306.txt
# Archivo renombrado: 10308 -> 10308.txt
# Archivo renombrado: 10310 -> 10310.txt
# Archivo renombrado: 10311 -> 10311.txt
# Archivo renombrado: 10313 -> 10313.txt
# Archivo renombrado: 10314 -> 10314.txt
# Archivo renombrado: 10315 -> 10315.txt
# Archivo renombrado: 10318 -> 10318.txt
# Archivo renombrado: 10319 -> 10319.txt
# Archivo renombrado: 1032 -> 1032.txt
# Archivo renombrado: 10321 -> 10321.txt
# Archivo renombrado: 10322 -> 10322.txt
# Archivo renombrado: 10323 -> 10323.txt
# Archivo renombrado: 10324 -> 10324.txt
# Archivo renombrado: 10328 -> 10328.txt
# Archivo renombrado: 1033 -> 1033.txt
# Archivo renombrado: 10330 -> 10330.txt
# Archivo renombrado: 10332 -> 10332.txt
# Archivo renombrado: 10334 -> 10334.txt
# Archivo renombrado: 10335 -> 10335.txt
# Archivo renombrado: 10337 -> 10337.txt
# Archivo renombrado: 10338 -> 10338.txt
# Archivo renombrado: 10339 -> 10339.txt
# Archivo renombrado: 10340 -> 10340.txt
# Archivo renombrado: 10341 -> 10341.txt
# Archivo renombrado: 10342 -> 10342.txt
# Archivo renombrado: 10344 -> 10344.txt
# Archivo renombrado: 10347 -> 10347.txt
# Archivo renombrado: 10348 -> 10348.txt
# Archivo renombrado: 10349 -> 10349.txt
# Archivo renombrado: 1035 -> 1035.txt
# Archivo renombrado: 10352 -> 10352.txt
# Archivo renombrado: 10354 -> 10354.txt
# Archivo renombrado: 10355 -> 10355.txt
# Archivo renombrado: 10356 -> 10356.txt
# Archivo renombrado: 10357 -> 10357.txt
# Archivo renombrado: 10358 -> 10358.txt
# Archivo renombrado: 10359 -> 10359.txt
# Archivo renombrado: 1036 -> 1036.txt
# Archivo renombrado: 10361 -> 10361.txt
# Archivo renombrado: 10362 -> 10362.txt
# Archivo renombrado: 10364 -> 10364.txt
# Archivo renombrado: 10367 -> 10367.txt
# Archivo renombrado: 10368 -> 10368.txt
# Archivo renombrado: 10370 -> 10370.txt
# Archivo renombrado: 10371 -> 10371.txt
# Archivo renombrado: 10372 -> 10372.txt
# Archivo renombrado: 10373 -> 10373.txt
# Archivo renombrado: 10375 -> 10375.txt
# Archivo renombrado: 10376 -> 10376.txt
# Archivo renombrado: 10377 -> 10377.txt
# Archivo renombrado: 10381 -> 10381.txt
# Archivo renombrado: 10382 -> 10382.txt
# Archivo renombrado: 10384 -> 10384.txt
# Archivo renombrado: 10385 -> 10385.txt
# Archivo renombrado: 10387 -> 10387.txt
# Archivo renombrado: 10388 -> 10388.txt
# Archivo renombrado: 1039 -> 1039.txt
# Archivo renombrado: 10390 -> 10390.txt
# Archivo renombrado: 10391 -> 10391.txt
# Archivo renombrado: 10393 -> 10393.txt
# Archivo renombrado: 10394 -> 10394.txt
# Archivo renombrado: 10395 -> 10395.txt
# Archivo renombrado: 10397 -> 10397.txt
# Archivo renombrado: 10398 -> 10398.txt
# Archivo renombrado: 10399 -> 10399.txt
# Archivo renombrado: 104 -> 104.txt
# Archivo renombrado: 1040 -> 1040.txt
# Archivo renombrado: 10401 -> 10401.txt
# Archivo renombrado: 10402 -> 10402.txt
# Archivo renombrado: 10403 -> 10403.txt
# Archivo renombrado: 10404 -> 10404.txt
# Archivo renombrado: 10406 -> 10406.txt
# Archivo renombrado: 10411 -> 10411.txt
# Archivo renombrado: 10412 -> 10412.txt
# Archivo renombrado: 10414 -> 10414.txt
# Archivo renombrado: 10416 -> 10416.txt
# Archivo renombrado: 10418 -> 10418.txt
# Archivo renombrado: 10419 -> 10419.txt
# Archivo renombrado: 10423 -> 10423.txt
# Archivo renombrado: 10427 -> 10427.txt
# Archivo renombrado: 10429 -> 10429.txt
# Archivo renombrado: 10430 -> 10430.txt
# Archivo renombrado: 10431 -> 10431.txt
# Archivo renombrado: 10432 -> 10432.txt
# Archivo renombrado: 10434 -> 10434.txt
# Archivo renombrado: 10435 -> 10435.txt
# Archivo renombrado: 10436 -> 10436.txt
# Archivo renombrado: 10439 -> 10439.txt
# Archivo renombrado: 1044 -> 1044.txt
# Archivo renombrado: 10440 -> 10440.txt
# Archivo renombrado: 10442 -> 10442.txt
# Archivo renombrado: 10444 -> 10444.txt
# Archivo renombrado: 10445 -> 10445.txt
# Archivo renombrado: 10446 -> 10446.txt
# Archivo renombrado: 10447 -> 10447.txt
# Archivo renombrado: 10449 -> 10449.txt
# Archivo renombrado: 10452 -> 10452.txt
# Archivo renombrado: 10453 -> 10453.txt
# Archivo renombrado: 10454 -> 10454.txt
# Archivo renombrado: 10455 -> 10455.txt
# Archivo renombrado: 10458 -> 10458.txt
# Archivo renombrado: 10459 -> 10459.txt
# Archivo renombrado: 10462 -> 10462.txt
# Archivo renombrado: 10464 -> 10464.txt
# Archivo renombrado: 10467 -> 10467.txt
# Archivo renombrado: 1047 -> 1047.txt
# Archivo renombrado: 10470 -> 10470.txt
# Archivo renombrado: 10471 -> 10471.txt
# Archivo renombrado: 10472 -> 10472.txt
# Archivo renombrado: 10473 -> 10473.txt
# Archivo renombrado: 10475 -> 10475.txt
# Archivo renombrado: 10478 -> 10478.txt
# Archivo renombrado: 10484 -> 10484.txt
# Archivo renombrado: 10485 -> 10485.txt
# Archivo renombrado: 10487 -> 10487.txt
# Archivo renombrado: 10489 -> 10489.txt
# Archivo renombrado: 1049 -> 1049.txt
# Archivo renombrado: 10491 -> 10491.txt
# Archivo renombrado: 10494 -> 10494.txt
# Archivo renombrado: 10498 -> 10498.txt
# Archivo renombrado: 10499 -> 10499.txt
# Archivo renombrado: 105 -> 105.txt
# Archivo renombrado: 1050 -> 1050.txt
# Archivo renombrado: 10500 -> 10500.txt
# Archivo renombrado: 10503 -> 10503.txt
# Archivo renombrado: 10505 -> 10505.txt
# Archivo renombrado: 10506 -> 10506.txt
# Archivo renombrado: 10508 -> 10508.txt
# Archivo renombrado: 10509 -> 10509.txt
# Archivo renombrado: 10515 -> 10515.txt
# Archivo renombrado: 10518 -> 10518.txt
# Archivo renombrado: 10519 -> 10519.txt
# Archivo renombrado: 1052 -> 1052.txt
# Archivo renombrado: 10520 -> 10520.txt
# Archivo renombrado: 10521 -> 10521.txt
# Archivo renombrado: 10524 -> 10524.txt
# Archivo renombrado: 10527 -> 10527.txt
# Archivo renombrado: 10529 -> 10529.txt
# Archivo renombrado: 10530 -> 10530.txt
# Archivo renombrado: 10531 -> 10531.txt
# Archivo renombrado: 10532 -> 10532.txt
# Archivo renombrado: 10534 -> 10534.txt
# Archivo renombrado: 10536 -> 10536.txt
# Archivo renombrado: 10537 -> 10537.txt
# Archivo renombrado: 10538 -> 10538.txt
# Archivo renombrado: 10539 -> 10539.txt
# Archivo renombrado: 10541 -> 10541.txt
# Archivo renombrado: 10542 -> 10542.txt
# Archivo renombrado: 10544 -> 10544.txt
# Archivo renombrado: 10545 -> 10545.txt
# Archivo renombrado: 10546 -> 10546.txt
# Archivo renombrado: 10547 -> 10547.txt
# Archivo renombrado: 10548 -> 10548.txt
# Archivo renombrado: 10551 -> 10551.txt
# Archivo renombrado: 10553 -> 10553.txt
# Archivo renombrado: 10555 -> 10555.txt
# Archivo renombrado: 10556 -> 10556.txt
# Archivo renombrado: 10559 -> 10559.txt
# Archivo renombrado: 10561 -> 10561.txt
# Archivo renombrado: 10563 -> 10563.txt
# Archivo renombrado: 10564 -> 10564.txt
# Archivo renombrado: 10565 -> 10565.txt
# Archivo renombrado: 10566 -> 10566.txt
# Archivo renombrado: 10567 -> 10567.txt
# Archivo renombrado: 10569 -> 10569.txt
# Archivo renombrado: 1057 -> 1057.txt
# Archivo renombrado: 10573 -> 10573.txt
# Archivo renombrado: 10576 -> 10576.txt
# Archivo renombrado: 1058 -> 1058.txt
# Archivo renombrado: 10581 -> 10581.txt
# Archivo renombrado: 10582 -> 10582.txt
# Archivo renombrado: 10584 -> 10584.txt
# Archivo renombrado: 10585 -> 10585.txt
# Archivo renombrado: 10586 -> 10586.txt
# Archivo renombrado: 10587 -> 10587.txt
# Archivo renombrado: 10588 -> 10588.txt
# Archivo renombrado: 1059 -> 1059.txt
# Archivo renombrado: 10590 -> 10590.txt
# Archivo renombrado: 10592 -> 10592.txt
# Archivo renombrado: 10593 -> 10593.txt
# Archivo renombrado: 10594 -> 10594.txt
# Archivo renombrado: 10596 -> 10596.txt
# Archivo renombrado: 10597 -> 10597.txt
# Archivo renombrado: 10598 -> 10598.txt
# Archivo renombrado: 10599 -> 10599.txt
# Archivo renombrado: 106 -> 106.txt
# Archivo renombrado: 10600 -> 10600.txt
# Archivo renombrado: 10601 -> 10601.txt
# Archivo renombrado: 10602 -> 10602.txt
# Archivo renombrado: 10604 -> 10604.txt
# Archivo renombrado: 10606 -> 10606.txt
# Archivo renombrado: 10608 -> 10608.txt
# Archivo renombrado: 10609 -> 10609.txt
# Archivo renombrado: 10610 -> 10610.txt
# Archivo renombrado: 10611 -> 10611.txt
# Archivo renombrado: 10612 -> 10612.txt
# Archivo renombrado: 10613 -> 10613.txt
# Archivo renombrado: 10615 -> 10615.txt
# Archivo renombrado: 10616 -> 10616.txt
# Archivo renombrado: 10617 -> 10617.txt
# Archivo renombrado: 10618 -> 10618.txt
# Archivo renombrado: 10619 -> 10619.txt
# Archivo renombrado: 10620 -> 10620.txt
# Archivo renombrado: 10621 -> 10621.txt
# Archivo renombrado: 10622 -> 10622.txt
# Archivo renombrado: 10623 -> 10623.txt
# Archivo renombrado: 10625 -> 10625.txt
# Archivo renombrado: 10627 -> 10627.txt
# Archivo renombrado: 1063 -> 1063.txt
# Archivo renombrado: 10632 -> 10632.txt
# Archivo renombrado: 10633 -> 10633.txt
# Archivo renombrado: 10634 -> 10634.txt
# Archivo renombrado: 10636 -> 10636.txt
# Archivo renombrado: 10638 -> 10638.txt
# Archivo renombrado: 10640 -> 10640.txt
# Archivo renombrado: 10641 -> 10641.txt
# Archivo renombrado: 10642 -> 10642.txt
# Archivo renombrado: 10643 -> 10643.txt
# Archivo renombrado: 10644 -> 10644.txt
# Archivo renombrado: 10648 -> 10648.txt
# Archivo renombrado: 1065 -> 1065.txt
# Archivo renombrado: 10650 -> 10650.txt
# Archivo renombrado: 10651 -> 10651.txt
# Archivo renombrado: 10652 -> 10652.txt
# Archivo renombrado: 10653 -> 10653.txt
# Archivo renombrado: 10654 -> 10654.txt
# Archivo renombrado: 10657 -> 10657.txt
# Archivo renombrado: 10658 -> 10658.txt
# Archivo renombrado: 10659 -> 10659.txt
# Archivo renombrado: 1066 -> 1066.txt
# Archivo renombrado: 10660 -> 10660.txt
# Archivo renombrado: 10661 -> 10661.txt
# Archivo renombrado: 10662 -> 10662.txt
# Archivo renombrado: 10665 -> 10665.txt
# Archivo renombrado: 10669 -> 10669.txt
# Archivo renombrado: 1067 -> 1067.txt
# Archivo renombrado: 10674 -> 10674.txt
# Archivo renombrado: 10676 -> 10676.txt
# Archivo renombrado: 10678 -> 10678.txt
# Archivo renombrado: 10679 -> 10679.txt
# Archivo renombrado: 1068 -> 1068.txt
# Archivo renombrado: 10681 -> 10681.txt
# Archivo renombrado: 10682 -> 10682.txt
# Archivo renombrado: 10684 -> 10684.txt
# Archivo renombrado: 10685 -> 10685.txt
# Archivo renombrado: 10687 -> 10687.txt
# Archivo renombrado: 10688 -> 10688.txt
# Archivo renombrado: 10689 -> 10689.txt
# Archivo renombrado: 1069 -> 1069.txt
# Archivo renombrado: 10692 -> 10692.txt
# Archivo renombrado: 10693 -> 10693.txt
# Archivo renombrado: 10694 -> 10694.txt
# Archivo renombrado: 10695 -> 10695.txt
# Archivo renombrado: 10696 -> 10696.txt
# Archivo renombrado: 10699 -> 10699.txt
# Archivo renombrado: 1070 -> 1070.txt
# Archivo renombrado: 10701 -> 10701.txt
# Archivo renombrado: 10702 -> 10702.txt
# Archivo renombrado: 10703 -> 10703.txt
# Archivo renombrado: 10704 -> 10704.txt
# Archivo renombrado: 10705 -> 10705.txt
# Archivo renombrado: 10708 -> 10708.txt
# Archivo renombrado: 10709 -> 10709.txt
# Archivo renombrado: 1071 -> 1071.txt
# Archivo renombrado: 10710 -> 10710.txt
# Archivo renombrado: 10712 -> 10712.txt
# Archivo renombrado: 10714 -> 10714.txt
# Archivo renombrado: 10715 -> 10715.txt
# Archivo renombrado: 10717 -> 10717.txt
# Archivo renombrado: 10718 -> 10718.txt
# Archivo renombrado: 1072 -> 1072.txt
# Archivo renombrado: 10720 -> 10720.txt
# Archivo renombrado: 10721 -> 10721.txt
# Archivo renombrado: 10724 -> 10724.txt
# Archivo renombrado: 10729 -> 10729.txt
# Archivo renombrado: 10731 -> 10731.txt
# Archivo renombrado: 10734 -> 10734.txt
# Archivo renombrado: 10736 -> 10736.txt
# Archivo renombrado: 10737 -> 10737.txt
# Archivo renombrado: 10738 -> 10738.txt
# Archivo renombrado: 1074 -> 1074.txt
# Archivo renombrado: 10742 -> 10742.txt
# Archivo renombrado: 10743 -> 10743.txt
# Archivo renombrado: 10744 -> 10744.txt
# Archivo renombrado: 10746 -> 10746.txt
# Archivo renombrado: 10748 -> 10748.txt
# Archivo renombrado: 10749 -> 10749.txt
# Archivo renombrado: 10750 -> 10750.txt
# Archivo renombrado: 10751 -> 10751.txt
# Archivo renombrado: 10752 -> 10752.txt
# Archivo renombrado: 10754 -> 10754.txt
# Archivo renombrado: 10755 -> 10755.txt
# Archivo renombrado: 10756 -> 10756.txt
# Archivo renombrado: 10757 -> 10757.txt
# Archivo renombrado: 10758 -> 10758.txt
# Archivo renombrado: 1076 -> 1076.txt
# Archivo renombrado: 10760 -> 10760.txt
# Archivo renombrado: 10762 -> 10762.txt
# Archivo renombrado: 10766 -> 10766.txt
# Archivo renombrado: 10767 -> 10767.txt
# Archivo renombrado: 10768 -> 10768.txt
# Archivo renombrado: 10769 -> 10769.txt
# Archivo renombrado: 1077 -> 1077.txt
# Archivo renombrado: 10770 -> 10770.txt
# Archivo renombrado: 10771 -> 10771.txt
# Archivo renombrado: 10773 -> 10773.txt
# Archivo renombrado: 10774 -> 10774.txt
# Archivo renombrado: 10779 -> 10779.txt
# Archivo renombrado: 1078 -> 1078.txt
# Archivo renombrado: 10780 -> 10780.txt
# Archivo renombrado: 10781 -> 10781.txt
# Archivo renombrado: 10782 -> 10782.txt
# Archivo renombrado: 10784 -> 10784.txt
# Archivo renombrado: 10786 -> 10786.txt
# Archivo renombrado: 10787 -> 10787.txt
# Archivo renombrado: 10788 -> 10788.txt
# Archivo renombrado: 1079 -> 1079.txt
# Archivo renombrado: 10790 -> 10790.txt
# Archivo renombrado: 10794 -> 10794.txt
# Archivo renombrado: 10796 -> 10796.txt
# Archivo renombrado: 10797 -> 10797.txt
# Archivo renombrado: 108 -> 108.txt
# Archivo renombrado: 1080 -> 1080.txt
# Archivo renombrado: 10803 -> 10803.txt
# Archivo renombrado: 10804 -> 10804.txt
# Archivo renombrado: 10805 -> 10805.txt
# Archivo renombrado: 10807 -> 10807.txt
# Archivo renombrado: 10808 -> 10808.txt
# Archivo renombrado: 10809 -> 10809.txt
# Archivo renombrado: 10811 -> 10811.txt
# Archivo renombrado: 10815 -> 10815.txt
# Archivo renombrado: 10816 -> 10816.txt
# Archivo renombrado: 10817 -> 10817.txt
# Archivo renombrado: 1082 -> 1082.txt
# Archivo renombrado: 10822 -> 10822.txt
# Archivo renombrado: 10825 -> 10825.txt
# Archivo renombrado: 10826 -> 10826.txt
# Archivo renombrado: 10827 -> 10827.txt
# Archivo renombrado: 10830 -> 10830.txt
# Archivo renombrado: 10831 -> 10831.txt
# Archivo renombrado: 10832 -> 10832.txt
# Archivo renombrado: 10833 -> 10833.txt
# Archivo renombrado: 10834 -> 10834.txt
# Archivo renombrado: 10839 -> 10839.txt
# Archivo renombrado: 1084 -> 1084.txt
# Archivo renombrado: 10840 -> 10840.txt
# Archivo renombrado: 10841 -> 10841.txt
# Archivo renombrado: 10843 -> 10843.txt
# Archivo renombrado: 10844 -> 10844.txt
# Archivo renombrado: 10845 -> 10845.txt
# Archivo renombrado: 10847 -> 10847.txt
# Archivo renombrado: 10848 -> 10848.txt
# Archivo renombrado: 10849 -> 10849.txt
# Archivo renombrado: 1085 -> 1085.txt
# Archivo renombrado: 10851 -> 10851.txt
# Archivo renombrado: 10853 -> 10853.txt
# Archivo renombrado: 10855 -> 10855.txt
# Archivo renombrado: 10856 -> 10856.txt
# Archivo renombrado: 10857 -> 10857.txt
# Archivo renombrado: 10859 -> 10859.txt
# Archivo renombrado: 10860 -> 10860.txt
# Archivo renombrado: 10864 -> 10864.txt
# Archivo renombrado: 10867 -> 10867.txt
# Archivo renombrado: 10868 -> 10868.txt
# Archivo renombrado: 1087 -> 1087.txt
# Archivo renombrado: 10870 -> 10870.txt
# Archivo renombrado: 10871 -> 10871.txt
# Archivo renombrado: 10872 -> 10872.txt
# Archivo renombrado: 10873 -> 10873.txt
# Archivo renombrado: 10874 -> 10874.txt
# Archivo renombrado: 10876 -> 10876.txt
# Archivo renombrado: 10877 -> 10877.txt
# Archivo renombrado: 10879 -> 10879.txt
# Archivo renombrado: 1088 -> 1088.txt
# Archivo renombrado: 10882 -> 10882.txt
# Archivo renombrado: 10883 -> 10883.txt
# Archivo renombrado: 10884 -> 10884.txt
# Archivo renombrado: 10885 -> 10885.txt
# Archivo renombrado: 10886 -> 10886.txt
# Archivo renombrado: 10887 -> 10887.txt
# Archivo renombrado: 10891 -> 10891.txt
# Archivo renombrado: 10892 -> 10892.txt
# Archivo renombrado: 10893 -> 10893.txt
# Archivo renombrado: 10894 -> 10894.txt
# Archivo renombrado: 10895 -> 10895.txt
# Archivo renombrado: 10897 -> 10897.txt
# Archivo renombrado: 10899 -> 10899.txt
# Archivo renombrado: 109 -> 109.txt
# Archivo renombrado: 1090 -> 1090.txt
# Archivo renombrado: 10901 -> 10901.txt
# Archivo renombrado: 10902 -> 10902.txt
# Archivo renombrado: 10903 -> 10903.txt
# Archivo renombrado: 10904 -> 10904.txt
# Archivo renombrado: 10905 -> 10905.txt
# Archivo renombrado: 10907 -> 10907.txt
# Archivo renombrado: 10908 -> 10908.txt
# Archivo renombrado: 10909 -> 10909.txt
# Archivo renombrado: 1091 -> 1091.txt
# Archivo renombrado: 10913 -> 10913.txt
# Archivo renombrado: 10917 -> 10917.txt
# Archivo renombrado: 10918 -> 10918.txt
# Archivo renombrado: 10919 -> 10919.txt
# Archivo renombrado: 10921 -> 10921.txt
# Archivo renombrado: 10922 -> 10922.txt
# Archivo renombrado: 10923 -> 10923.txt
# Archivo renombrado: 10924 -> 10924.txt
# Archivo renombrado: 10925 -> 10925.txt
# Archivo renombrado: 10926 -> 10926.txt
# Archivo renombrado: 10928 -> 10928.txt
# Archivo renombrado: 10931 -> 10931.txt
# Archivo renombrado: 1094 -> 1094.txt
# Archivo renombrado: 10941 -> 10941.txt
# Archivo renombrado: 10943 -> 10943.txt
# Archivo renombrado: 10944 -> 10944.txt
# Archivo renombrado: 10946 -> 10946.txt
# Archivo renombrado: 10947 -> 10947.txt
# Archivo renombrado: 10950 -> 10950.txt
# Archivo renombrado: 10956 -> 10956.txt
# Archivo renombrado: 10959 -> 10959.txt
# Archivo renombrado: 1096 -> 1096.txt
# Archivo renombrado: 10960 -> 10960.txt
# Archivo renombrado: 10961 -> 10961.txt
# Archivo renombrado: 10962 -> 10962.txt
# Archivo renombrado: 10963 -> 10963.txt
# Archivo renombrado: 10964 -> 10964.txt
# Archivo renombrado: 10966 -> 10966.txt
# Archivo renombrado: 10969 -> 10969.txt
# Archivo renombrado: 10971 -> 10971.txt
# Archivo renombrado: 10972 -> 10972.txt
# Archivo renombrado: 10973 -> 10973.txt
# Archivo renombrado: 10974 -> 10974.txt
# Archivo renombrado: 10978 -> 10978.txt
# Archivo renombrado: 10980 -> 10980.txt
# Archivo renombrado: 10983 -> 10983.txt
# Archivo renombrado: 10985 -> 10985.txt
# Archivo renombrado: 10988 -> 10988.txt
# Archivo renombrado: 10989 -> 10989.txt
# Archivo renombrado: 1099 -> 1099.txt
# Archivo renombrado: 10992 -> 10992.txt
# Archivo renombrado: 10994 -> 10994.txt
# Archivo renombrado: 10998 -> 10998.txt
# Archivo renombrado: 10999 -> 10999.txt
# Archivo renombrado: 11 -> 11.txt
# Archivo renombrado: 110 -> 110.txt
# Archivo renombrado: 1100 -> 1100.txt
# Archivo renombrado: 11000 -> 11000.txt
# Archivo renombrado: 11006 -> 11006.txt
# Archivo renombrado: 11007 -> 11007.txt
# Archivo renombrado: 1101 -> 1101.txt
# Archivo renombrado: 11012 -> 11012.txt
# Archivo renombrado: 11015 -> 11015.txt
# Archivo renombrado: 11018 -> 11018.txt
# Archivo renombrado: 11019 -> 11019.txt
# Archivo renombrado: 1102 -> 1102.txt
# Archivo renombrado: 11025 -> 11025.txt
# Archivo renombrado: 11027 -> 11027.txt
# Archivo renombrado: 11028 -> 11028.txt
# Archivo renombrado: 11029 -> 11029.txt
# Archivo renombrado: 1103 -> 1103.txt
# Archivo renombrado: 11030 -> 11030.txt
# Archivo renombrado: 11031 -> 11031.txt
# Archivo renombrado: 11034 -> 11034.txt
# Archivo renombrado: 11035 -> 11035.txt
# Archivo renombrado: 11036 -> 11036.txt
# Archivo renombrado: 11039 -> 11039.txt
# Archivo renombrado: 1104 -> 1104.txt
# Archivo renombrado: 11040 -> 11040.txt
# Archivo renombrado: 11041 -> 11041.txt
# Archivo renombrado: 11043 -> 11043.txt
# Archivo renombrado: 11046 -> 11046.txt
# Archivo renombrado: 11047 -> 11047.txt
# Archivo renombrado: 11048 -> 11048.txt
# Archivo renombrado: 11049 -> 11049.txt
# Archivo renombrado: 1105 -> 1105.txt
# Archivo renombrado: 11051 -> 11051.txt
# Archivo renombrado: 11052 -> 11052.txt
# Archivo renombrado: 11056 -> 11056.txt
# Archivo renombrado: 11057 -> 11057.txt
# Archivo renombrado: 11058 -> 11058.txt
# Archivo renombrado: 11059 -> 11059.txt
# Archivo renombrado: 11060 -> 11060.txt
# Archivo renombrado: 11063 -> 11063.txt
# Archivo renombrado: 11064 -> 11064.txt
# Archivo renombrado: 11065 -> 11065.txt
# Archivo renombrado: 11066 -> 11066.txt
# Archivo renombrado: 11070 -> 11070.txt
# Archivo renombrado: 11071 -> 11071.txt
# Archivo renombrado: 11074 -> 11074.txt
# Archivo renombrado: 11076 -> 11076.txt
# Archivo renombrado: 11078 -> 11078.txt
# Archivo renombrado: 1108 -> 1108.txt
# Archivo renombrado: 11083 -> 11083.txt
# Archivo renombrado: 11085 -> 11085.txt
# Archivo renombrado: 11086 -> 11086.txt
# Archivo renombrado: 11087 -> 11087.txt
# Archivo renombrado: 11088 -> 11088.txt
# Archivo renombrado: 1109 -> 1109.txt
# Archivo renombrado: 11090 -> 11090.txt
# Archivo renombrado: 11091 -> 11091.txt
# Archivo renombrado: 11093 -> 11093.txt
# Archivo renombrado: 11095 -> 11095.txt
# Archivo renombrado: 11098 -> 11098.txt
# Archivo renombrado: 111 -> 111.txt
# Archivo renombrado: 1110 -> 1110.txt
# Archivo renombrado: 11100 -> 11100.txt
# Archivo renombrado: 11101 -> 11101.txt
# Archivo renombrado: 11102 -> 11102.txt
# Archivo renombrado: 11103 -> 11103.txt
# Archivo renombrado: 11104 -> 11104.txt
# Archivo renombrado: 11105 -> 11105.txt
# Archivo renombrado: 11106 -> 11106.txt
# Archivo renombrado: 11107 -> 11107.txt
# Archivo renombrado: 11109 -> 11109.txt
# Archivo renombrado: 1111 -> 1111.txt
# Archivo renombrado: 11111 -> 11111.txt
# Archivo renombrado: 11112 -> 11112.txt
# Archivo renombrado: 11113 -> 11113.txt
# Archivo renombrado: 11115 -> 11115.txt
# Archivo renombrado: 11118 -> 11118.txt
# Archivo renombrado: 11119 -> 11119.txt
# Archivo renombrado: 1112 -> 1112.txt
# Archivo renombrado: 11120 -> 11120.txt
# Archivo renombrado: 11121 -> 11121.txt
# Archivo renombrado: 11123 -> 11123.txt
# Archivo renombrado: 11124 -> 11124.txt
# Archivo renombrado: 11126 -> 11126.txt
# Archivo renombrado: 11127 -> 11127.txt
# Archivo renombrado: 11128 -> 11128.txt
# Archivo renombrado: 11132 -> 11132.txt
# Archivo renombrado: 11133 -> 11133.txt
# Archivo renombrado: 11134 -> 11134.txt
# Archivo renombrado: 11135 -> 11135.txt
# Archivo renombrado: 11136 -> 11136.txt
# Archivo renombrado: 11137 -> 11137.txt
# Archivo renombrado: 11139 -> 11139.txt
# Archivo renombrado: 11143 -> 11143.txt
# Archivo renombrado: 11144 -> 11144.txt
# Archivo renombrado: 11145 -> 11145.txt
# Archivo renombrado: 11149 -> 11149.txt
# Archivo renombrado: 11153 -> 11153.txt
# Archivo renombrado: 11154 -> 11154.txt
# Archivo renombrado: 11156 -> 11156.txt
# Archivo renombrado: 11158 -> 11158.txt
# Archivo renombrado: 11159 -> 11159.txt
# Archivo renombrado: 11160 -> 11160.txt
# Archivo renombrado: 11161 -> 11161.txt
# Archivo renombrado: 11162 -> 11162.txt
# Archivo renombrado: 11163 -> 11163.txt
# Archivo renombrado: 11164 -> 11164.txt
# Archivo renombrado: 11166 -> 11166.txt
# Archivo renombrado: 11168 -> 11168.txt
# Archivo renombrado: 1117 -> 1117.txt
# Archivo renombrado: 11170 -> 11170.txt
# Archivo renombrado: 11171 -> 11171.txt
# Archivo renombrado: 11173 -> 11173.txt
# Archivo renombrado: 11174 -> 11174.txt
# Archivo renombrado: 11175 -> 11175.txt
# Archivo renombrado: 11177 -> 11177.txt
# Archivo renombrado: 11179 -> 11179.txt
# Archivo renombrado: 1118 -> 1118.txt
# Archivo renombrado: 11181 -> 11181.txt
# Archivo renombrado: 11183 -> 11183.txt
# Archivo renombrado: 11185 -> 11185.txt
# Archivo renombrado: 11190 -> 11190.txt
# Archivo renombrado: 11191 -> 11191.txt
# Archivo renombrado: 11192 -> 11192.txt
# Archivo renombrado: 11193 -> 11193.txt
# Archivo renombrado: 11196 -> 11196.txt
# Archivo renombrado: 11197 -> 11197.txt
# Archivo renombrado: 11198 -> 11198.txt
# Archivo renombrado: 1120 -> 1120.txt
# Archivo renombrado: 11200 -> 11200.txt
# Archivo renombrado: 11201 -> 11201.txt
# Archivo renombrado: 11202 -> 11202.txt
# Archivo renombrado: 11203 -> 11203.txt
# Archivo renombrado: 11205 -> 11205.txt
# Archivo renombrado: 11208 -> 11208.txt
# Archivo renombrado: 11209 -> 11209.txt
# Archivo renombrado: 11210 -> 11210.txt
# Archivo renombrado: 11211 -> 11211.txt
# Archivo renombrado: 11212 -> 11212.txt
# Archivo renombrado: 11213 -> 11213.txt
# Archivo renombrado: 11216 -> 11216.txt
# Archivo renombrado: 1122 -> 1122.txt
# Archivo renombrado: 11220 -> 11220.txt
# Archivo renombrado: 11221 -> 11221.txt
# Archivo renombrado: 11222 -> 11222.txt
# Archivo renombrado: 11224 -> 11224.txt
# Archivo renombrado: 11225 -> 11225.txt
# Archivo renombrado: 11227 -> 11227.txt
# Archivo renombrado: 11228 -> 11228.txt
# Archivo renombrado: 11229 -> 11229.txt
# Archivo renombrado: 1123 -> 1123.txt
# Archivo renombrado: 11230 -> 11230.txt
# Archivo renombrado: 11231 -> 11231.txt
# Archivo renombrado: 11232 -> 11232.txt
# Archivo renombrado: 11233 -> 11233.txt
# Archivo renombrado: 11234 -> 11234.txt
# Archivo renombrado: 11236 -> 11236.txt
# Archivo renombrado: 11237 -> 11237.txt
# Archivo renombrado: 11238 -> 11238.txt
# Archivo renombrado: 11239 -> 11239.txt
# Archivo renombrado: 1124 -> 1124.txt
# Archivo renombrado: 11241 -> 11241.txt
# Archivo renombrado: 11242 -> 11242.txt
# Archivo renombrado: 11243 -> 11243.txt
# Archivo renombrado: 11244 -> 11244.txt
# Archivo renombrado: 11249 -> 11249.txt
# Archivo renombrado: 1125 -> 1125.txt
# Archivo renombrado: 11251 -> 11251.txt
# Archivo renombrado: 11252 -> 11252.txt
# Archivo renombrado: 11253 -> 11253.txt
# Archivo renombrado: 11254 -> 11254.txt
# Archivo renombrado: 11255 -> 11255.txt
# Archivo renombrado: 11256 -> 11256.txt
# Archivo renombrado: 11257 -> 11257.txt
# Archivo renombrado: 11259 -> 11259.txt
# Archivo renombrado: 11260 -> 11260.txt
# Archivo renombrado: 11261 -> 11261.txt
# Archivo renombrado: 11263 -> 11263.txt
# Archivo renombrado: 11265 -> 11265.txt
# Archivo renombrado: 11268 -> 11268.txt
# Archivo renombrado: 11269 -> 11269.txt
# Archivo renombrado: 11270 -> 11270.txt
# Archivo renombrado: 11271 -> 11271.txt
# Archivo renombrado: 11272 -> 11272.txt
# Archivo renombrado: 11273 -> 11273.txt
# Archivo renombrado: 11274 -> 11274.txt
# Archivo renombrado: 11276 -> 11276.txt
# Archivo renombrado: 11277 -> 11277.txt
# Archivo renombrado: 11278 -> 11278.txt
# Archivo renombrado: 11279 -> 11279.txt
# Archivo renombrado: 1128 -> 1128.txt
# Archivo renombrado: 11281 -> 11281.txt
# Archivo renombrado: 11282 -> 11282.txt
# Archivo renombrado: 11283 -> 11283.txt
# Archivo renombrado: 11284 -> 11284.txt
# Archivo renombrado: 11285 -> 11285.txt
# Archivo renombrado: 11287 -> 11287.txt
# Archivo renombrado: 11289 -> 11289.txt
# Archivo renombrado: 11291 -> 11291.txt
# Archivo renombrado: 11292 -> 11292.txt
# Archivo renombrado: 11295 -> 11295.txt
# Archivo renombrado: 11297 -> 11297.txt
# Archivo renombrado: 11299 -> 11299.txt
# Archivo renombrado: 113 -> 113.txt
# Archivo renombrado: 11300 -> 11300.txt
# Archivo renombrado: 11301 -> 11301.txt
# Archivo renombrado: 11302 -> 11302.txt
# Archivo renombrado: 11305 -> 11305.txt
# Archivo renombrado: 11306 -> 11306.txt
# Archivo renombrado: 11307 -> 11307.txt
# Archivo renombrado: 11308 -> 11308.txt
# Archivo renombrado: 1131 -> 1131.txt
# Archivo renombrado: 11314 -> 11314.txt
# Archivo renombrado: 11315 -> 11315.txt
# Archivo renombrado: 11316 -> 11316.txt
# Archivo renombrado: 11317 -> 11317.txt
# Archivo renombrado: 11320 -> 11320.txt
# Archivo renombrado: 11322 -> 11322.txt
# Archivo renombrado: 11324 -> 11324.txt
# Archivo renombrado: 11327 -> 11327.txt
# Archivo renombrado: 11330 -> 11330.txt
# Archivo renombrado: 11333 -> 11333.txt
# Archivo renombrado: 11335 -> 11335.txt
# Archivo renombrado: 11336 -> 11336.txt
# Archivo renombrado: 11338 -> 11338.txt
# Archivo renombrado: 1134 -> 1134.txt
# Archivo renombrado: 11340 -> 11340.txt
# Archivo renombrado: 11341 -> 11341.txt
# Archivo renombrado: 11343 -> 11343.txt
# Archivo renombrado: 11344 -> 11344.txt
# Archivo renombrado: 11348 -> 11348.txt
# Archivo renombrado: 11349 -> 11349.txt
# Archivo renombrado: 1135 -> 1135.txt
# Archivo renombrado: 11350 -> 11350.txt
# Archivo renombrado: 11352 -> 11352.txt
# Archivo renombrado: 11354 -> 11354.txt
# Archivo renombrado: 11356 -> 11356.txt
# Archivo renombrado: 11357 -> 11357.txt
# Archivo renombrado: 11358 -> 11358.txt
# Archivo renombrado: 11359 -> 11359.txt
# Archivo renombrado: 11362 -> 11362.txt
# Archivo renombrado: 11365 -> 11365.txt
# Archivo renombrado: 11369 -> 11369.txt
# Archivo renombrado: 1137 -> 1137.txt
# Archivo renombrado: 11370 -> 11370.txt
# Archivo renombrado: 11371 -> 11371.txt
# Archivo renombrado: 11372 -> 11372.txt
# Archivo renombrado: 11373 -> 11373.txt
# Archivo renombrado: 11374 -> 11374.txt
# Archivo renombrado: 11377 -> 11377.txt
# Archivo renombrado: 11378 -> 11378.txt
# Archivo renombrado: 11379 -> 11379.txt
# Archivo renombrado: 1138 -> 1138.txt
# Archivo renombrado: 11380 -> 11380.txt
# Archivo renombrado: 11381 -> 11381.txt
# Archivo renombrado: 11384 -> 11384.txt
# Archivo renombrado: 11385 -> 11385.txt
# Archivo renombrado: 11386 -> 11386.txt
# Archivo renombrado: 11387 -> 11387.txt
# Archivo renombrado: 11388 -> 11388.txt
# Archivo renombrado: 11390 -> 11390.txt
# Archivo renombrado: 11392 -> 11392.txt
# Archivo renombrado: 11393 -> 11393.txt
# Archivo renombrado: 11394 -> 11394.txt
# Archivo renombrado: 11395 -> 11395.txt
# Archivo renombrado: 11396 -> 11396.txt
# Archivo renombrado: 11397 -> 11397.txt
# Archivo renombrado: 11399 -> 11399.txt
# Archivo renombrado: 11400 -> 11400.txt
# Archivo renombrado: 11402 -> 11402.txt
# Archivo renombrado: 11403 -> 11403.txt
# Archivo renombrado: 11405 -> 11405.txt
# Archivo renombrado: 11406 -> 11406.txt
# Archivo renombrado: 11407 -> 11407.txt
# Archivo renombrado: 11413 -> 11413.txt
# Archivo renombrado: 11415 -> 11415.txt
# Archivo renombrado: 11416 -> 11416.txt
# Archivo renombrado: 11417 -> 11417.txt
# Archivo renombrado: 11418 -> 11418.txt
# Archivo renombrado: 11420 -> 11420.txt
# Archivo renombrado: 11421 -> 11421.txt
# Archivo renombrado: 11422 -> 11422.txt
# Archivo renombrado: 11424 -> 11424.txt
# Archivo renombrado: 11425 -> 11425.txt
# Archivo renombrado: 11427 -> 11427.txt
# Archivo renombrado: 11428 -> 11428.txt
# Archivo renombrado: 11429 -> 11429.txt
# Archivo renombrado: 1143 -> 1143.txt
# Archivo renombrado: 11430 -> 11430.txt
# Archivo renombrado: 11431 -> 11431.txt
# Archivo renombrado: 11433 -> 11433.txt
# Archivo renombrado: 11435 -> 11435.txt
# Archivo renombrado: 11436 -> 11436.txt
# Archivo renombrado: 11437 -> 11437.txt
# Archivo renombrado: 11440 -> 11440.txt
# Archivo renombrado: 11441 -> 11441.txt
# Archivo renombrado: 11443 -> 11443.txt
# Archivo renombrado: 11444 -> 11444.txt
# Archivo renombrado: 11445 -> 11445.txt
# Archivo renombrado: 11446 -> 11446.txt
# Archivo renombrado: 11447 -> 11447.txt
# Archivo renombrado: 11449 -> 11449.txt
# Archivo renombrado: 11450 -> 11450.txt
# Archivo renombrado: 11451 -> 11451.txt
# Archivo renombrado: 11452 -> 11452.txt
# Archivo renombrado: 11455 -> 11455.txt
# Archivo renombrado: 11459 -> 11459.txt
# Archivo renombrado: 11460 -> 11460.txt
# Archivo renombrado: 11461 -> 11461.txt
# Archivo renombrado: 11462 -> 11462.txt
# Archivo renombrado: 11464 -> 11464.txt
# Archivo renombrado: 11465 -> 11465.txt
# Archivo renombrado: 11466 -> 11466.txt
# Archivo renombrado: 11468 -> 11468.txt
# Archivo renombrado: 11469 -> 11469.txt
# Archivo renombrado: 1147 -> 1147.txt
# Archivo renombrado: 11470 -> 11470.txt
# Archivo renombrado: 11475 -> 11475.txt
# Archivo renombrado: 11476 -> 11476.txt
# Archivo renombrado: 11477 -> 11477.txt
# Archivo renombrado: 11478 -> 11478.txt
# Archivo renombrado: 11479 -> 11479.txt
# Archivo renombrado: 1148 -> 1148.txt
# Archivo renombrado: 11481 -> 11481.txt
# Archivo renombrado: 11484 -> 11484.txt
# Archivo renombrado: 11487 -> 11487.txt
# Archivo renombrado: 11488 -> 11488.txt
# Archivo renombrado: 11490 -> 11490.txt
# Archivo renombrado: 11491 -> 11491.txt
# Archivo renombrado: 11492 -> 11492.txt
# Archivo renombrado: 11494 -> 11494.txt
# Archivo renombrado: 11496 -> 11496.txt
# Archivo renombrado: 11497 -> 11497.txt
# Archivo renombrado: 11498 -> 11498.txt
# Archivo renombrado: 11499 -> 11499.txt
# Archivo renombrado: 11500 -> 11500.txt
# Archivo renombrado: 11501 -> 11501.txt
# Archivo renombrado: 11503 -> 11503.txt
# Archivo renombrado: 11504 -> 11504.txt
# Archivo renombrado: 11505 -> 11505.txt
# Archivo renombrado: 11506 -> 11506.txt
# Archivo renombrado: 11507 -> 11507.txt
# Archivo renombrado: 11508 -> 11508.txt
# Archivo renombrado: 1151 -> 1151.txt
# Archivo renombrado: 11510 -> 11510.txt
# Archivo renombrado: 11514 -> 11514.txt
# Archivo renombrado: 11515 -> 11515.txt
# Archivo renombrado: 11519 -> 11519.txt
# Archivo renombrado: 1152 -> 1152.txt
# Archivo renombrado: 11522 -> 11522.txt
# Archivo renombrado: 11523 -> 11523.txt
# Archivo renombrado: 11526 -> 11526.txt
# Archivo renombrado: 11527 -> 11527.txt
# Archivo renombrado: 11528 -> 11528.txt
# Archivo renombrado: 11529 -> 11529.txt
# Archivo renombrado: 1153 -> 1153.txt
# Archivo renombrado: 11536 -> 11536.txt
# Archivo renombrado: 11539 -> 11539.txt
# Archivo renombrado: 1154 -> 1154.txt
# Archivo renombrado: 11540 -> 11540.txt
# Archivo renombrado: 11541 -> 11541.txt
# Archivo renombrado: 11543 -> 11543.txt
# Archivo renombrado: 11544 -> 11544.txt
# Archivo renombrado: 11545 -> 11545.txt
# Archivo renombrado: 11546 -> 11546.txt
# Archivo renombrado: 11549 -> 11549.txt
# Archivo renombrado: 11550 -> 11550.txt
# Archivo renombrado: 11551 -> 11551.txt
# Archivo renombrado: 11553 -> 11553.txt
# Archivo renombrado: 11554 -> 11554.txt
# Archivo renombrado: 11555 -> 11555.txt
# Archivo renombrado: 11558 -> 11558.txt
# Archivo renombrado: 11559 -> 11559.txt
# Archivo renombrado: 1156 -> 1156.txt
# Archivo renombrado: 11563 -> 11563.txt
# Archivo renombrado: 11564 -> 11564.txt
# Archivo renombrado: 11565 -> 11565.txt
# Archivo renombrado: 11566 -> 11566.txt
# Archivo renombrado: 11567 -> 11567.txt
# Archivo renombrado: 11568 -> 11568.txt
# Archivo renombrado: 11569 -> 11569.txt
# Archivo renombrado: 1157 -> 1157.txt
# Archivo renombrado: 11570 -> 11570.txt
# Archivo renombrado: 11571 -> 11571.txt
# Archivo renombrado: 11572 -> 11572.txt
# Archivo renombrado: 11574 -> 11574.txt
# Archivo renombrado: 11575 -> 11575.txt
# Archivo renombrado: 11578 -> 11578.txt
# Archivo renombrado: 11579 -> 11579.txt
# Archivo renombrado: 1158 -> 1158.txt
# Archivo renombrado: 11580 -> 11580.txt
# Archivo renombrado: 11584 -> 11584.txt
# Archivo renombrado: 11587 -> 11587.txt
# Archivo renombrado: 11588 -> 11588.txt
# Archivo renombrado: 1159 -> 1159.txt
# Archivo renombrado: 11597 -> 11597.txt
# Archivo renombrado: 11598 -> 11598.txt
# Archivo renombrado: 11599 -> 11599.txt
# Archivo renombrado: 1160 -> 1160.txt
# Archivo renombrado: 11602 -> 11602.txt
# Archivo renombrado: 11607 -> 11607.txt
# Archivo renombrado: 11608 -> 11608.txt
# Archivo renombrado: 11609 -> 11609.txt
# Archivo renombrado: 11610 -> 11610.txt
# Archivo renombrado: 11611 -> 11611.txt
# Archivo renombrado: 11612 -> 11612.txt
# Archivo renombrado: 11614 -> 11614.txt
# Archivo renombrado: 11617 -> 11617.txt
# Archivo renombrado: 11619 -> 11619.txt
# Archivo renombrado: 11621 -> 11621.txt
# Archivo renombrado: 11622 -> 11622.txt
# Archivo renombrado: 11623 -> 11623.txt
# Archivo renombrado: 11625 -> 11625.txt
# Archivo renombrado: 11627 -> 11627.txt
# Archivo renombrado: 11628 -> 11628.txt
# Archivo renombrado: 11629 -> 11629.txt
# Archivo renombrado: 11630 -> 11630.txt
# Archivo renombrado: 11632 -> 11632.txt
# Archivo renombrado: 11633 -> 11633.txt
# Archivo renombrado: 11634 -> 11634.txt
# Archivo renombrado: 11635 -> 11635.txt
# Archivo renombrado: 11636 -> 11636.txt
# Archivo renombrado: 11637 -> 11637.txt
# Archivo renombrado: 11638 -> 11638.txt
# Archivo renombrado: 11639 -> 11639.txt
# Archivo renombrado: 1164 -> 1164.txt
# Archivo renombrado: 11640 -> 11640.txt
# Archivo renombrado: 11643 -> 11643.txt
# Archivo renombrado: 11644 -> 11644.txt
# Archivo renombrado: 11645 -> 11645.txt
# Archivo renombrado: 11649 -> 11649.txt
# Archivo renombrado: 11655 -> 11655.txt
# Archivo renombrado: 11657 -> 11657.txt
# Archivo renombrado: 11658 -> 11658.txt
# Archivo renombrado: 11660 -> 11660.txt
# Archivo renombrado: 11661 -> 11661.txt
# Archivo renombrado: 11663 -> 11663.txt
# Archivo renombrado: 11664 -> 11664.txt
# Archivo renombrado: 11665 -> 11665.txt
# Archivo renombrado: 11666 -> 11666.txt
# Archivo renombrado: 11667 -> 11667.txt
# Archivo renombrado: 11668 -> 11668.txt
# Archivo renombrado: 1167 -> 1167.txt
# Archivo renombrado: 11671 -> 11671.txt
# Archivo renombrado: 11674 -> 11674.txt
# Archivo renombrado: 11679 -> 11679.txt
# Archivo renombrado: 11682 -> 11682.txt
# Archivo renombrado: 11683 -> 11683.txt
# Archivo renombrado: 11684 -> 11684.txt
# Archivo renombrado: 11685 -> 11685.txt
# Archivo renombrado: 11687 -> 11687.txt
# Archivo renombrado: 11689 -> 11689.txt
# Archivo renombrado: 1169 -> 1169.txt
# Archivo renombrado: 11690 -> 11690.txt
# Archivo renombrado: 11694 -> 11694.txt
# Archivo renombrado: 11696 -> 11696.txt
# Archivo renombrado: 11697 -> 11697.txt
# Archivo renombrado: 11699 -> 11699.txt
# Archivo renombrado: 1170 -> 1170.txt
# Archivo renombrado: 11700 -> 11700.txt
# Archivo renombrado: 11701 -> 11701.txt
# Archivo renombrado: 11702 -> 11702.txt
# Archivo renombrado: 11705 -> 11705.txt
# Archivo renombrado: 11706 -> 11706.txt
# Archivo renombrado: 11707 -> 11707.txt
# Archivo renombrado: 11708 -> 11708.txt
# Archivo renombrado: 11711 -> 11711.txt
# Archivo renombrado: 11713 -> 11713.txt
# Archivo renombrado: 11714 -> 11714.txt
# Archivo renombrado: 11716 -> 11716.txt
# Archivo renombrado: 11717 -> 11717.txt
# Archivo renombrado: 11721 -> 11721.txt
# Archivo renombrado: 11722 -> 11722.txt
# Archivo renombrado: 11723 -> 11723.txt
# Archivo renombrado: 11724 -> 11724.txt
# Archivo renombrado: 11725 -> 11725.txt
# Archivo renombrado: 11726 -> 11726.txt
# Archivo renombrado: 11727 -> 11727.txt
# Archivo renombrado: 11728 -> 11728.txt
# Archivo renombrado: 11729 -> 11729.txt
# Archivo renombrado: 1173 -> 1173.txt
# Archivo renombrado: 11730 -> 11730.txt
# Archivo renombrado: 11731 -> 11731.txt
# Archivo renombrado: 11733 -> 11733.txt
# Archivo renombrado: 11734 -> 11734.txt
# Archivo renombrado: 11736 -> 11736.txt
# Archivo renombrado: 11738 -> 11738.txt
# Archivo renombrado: 11739 -> 11739.txt
# Archivo renombrado: 1174 -> 1174.txt
# Archivo renombrado: 11743 -> 11743.txt
# Archivo renombrado: 11744 -> 11744.txt
# Archivo renombrado: 11746 -> 11746.txt
# Archivo renombrado: 11748 -> 11748.txt
# Archivo renombrado: 11750 -> 11750.txt
# Archivo renombrado: 11751 -> 11751.txt
# Archivo renombrado: 11752 -> 11752.txt
# Archivo renombrado: 11753 -> 11753.txt
# Archivo renombrado: 11754 -> 11754.txt
# Archivo renombrado: 11755 -> 11755.txt
# Archivo renombrado: 11756 -> 11756.txt
# Archivo renombrado: 11758 -> 11758.txt
# Archivo renombrado: 1176 -> 1176.txt
# Archivo renombrado: 11762 -> 11762.txt
# Archivo renombrado: 11763 -> 11763.txt
# Archivo renombrado: 11764 -> 11764.txt
# Archivo renombrado: 11765 -> 11765.txt
# Archivo renombrado: 11767 -> 11767.txt
# Archivo renombrado: 11768 -> 11768.txt
# Archivo renombrado: 11769 -> 11769.txt
# Archivo renombrado: 1177 -> 1177.txt
# Archivo renombrado: 11771 -> 11771.txt
# Archivo renombrado: 11772 -> 11772.txt
# Archivo renombrado: 11773 -> 11773.txt
# Archivo renombrado: 11774 -> 11774.txt
# Archivo renombrado: 11775 -> 11775.txt
# Archivo renombrado: 11776 -> 11776.txt
# Archivo renombrado: 11778 -> 11778.txt
# Archivo renombrado: 1178 -> 1178.txt
# Archivo renombrado: 11783 -> 11783.txt
# Archivo renombrado: 11787 -> 11787.txt
# Archivo renombrado: 11789 -> 11789.txt
# Archivo renombrado: 11790 -> 11790.txt
# Archivo renombrado: 11791 -> 11791.txt
# Archivo renombrado: 11793 -> 11793.txt
# Archivo renombrado: 11794 -> 11794.txt
# Archivo renombrado: 11795 -> 11795.txt
# Archivo renombrado: 11798 -> 11798.txt
# Archivo renombrado: 11801 -> 11801.txt
# Archivo renombrado: 11802 -> 11802.txt
# Archivo renombrado: 11808 -> 11808.txt
# Archivo renombrado: 1181 -> 1181.txt
# Archivo renombrado: 11811 -> 11811.txt
# Archivo renombrado: 11812 -> 11812.txt
# Archivo renombrado: 11813 -> 11813.txt
# Archivo renombrado: 11815 -> 11815.txt
# Archivo renombrado: 11816 -> 11816.txt
# Archivo renombrado: 11817 -> 11817.txt
# Archivo renombrado: 1182 -> 1182.txt
# Archivo renombrado: 11820 -> 11820.txt
# Archivo renombrado: 11821 -> 11821.txt
# Archivo renombrado: 11822 -> 11822.txt
# Archivo renombrado: 11825 -> 11825.txt
# Archivo renombrado: 11826 -> 11826.txt
# Archivo renombrado: 11829 -> 11829.txt
# Archivo renombrado: 11830 -> 11830.txt
# Archivo renombrado: 11831 -> 11831.txt
# Archivo renombrado: 11832 -> 11832.txt
# Archivo renombrado: 11833 -> 11833.txt
# Archivo renombrado: 11834 -> 11834.txt
# Archivo renombrado: 11836 -> 11836.txt
# Archivo renombrado: 11837 -> 11837.txt
# Archivo renombrado: 11839 -> 11839.txt
# Archivo renombrado: 1184 -> 1184.txt
# Archivo renombrado: 11840 -> 11840.txt
# Archivo renombrado: 11841 -> 11841.txt
# Archivo renombrado: 11843 -> 11843.txt
# Archivo renombrado: 11844 -> 11844.txt
# Archivo renombrado: 11847 -> 11847.txt
# Archivo renombrado: 11848 -> 11848.txt
# Archivo renombrado: 1185 -> 1185.txt
# Archivo renombrado: 11850 -> 11850.txt
# Archivo renombrado: 11852 -> 11852.txt
# Archivo renombrado: 11854 -> 11854.txt
# Archivo renombrado: 11855 -> 11855.txt
# Archivo renombrado: 11856 -> 11856.txt
# Archivo renombrado: 11858 -> 11858.txt
# Archivo renombrado: 11859 -> 11859.txt
# Archivo renombrado: 11860 -> 11860.txt
# Archivo renombrado: 11861 -> 11861.txt
# Archivo renombrado: 11862 -> 11862.txt
# Archivo renombrado: 11863 -> 11863.txt
# Archivo renombrado: 11864 -> 11864.txt
# Archivo renombrado: 11866 -> 11866.txt
# Archivo renombrado: 11867 -> 11867.txt
# Archivo renombrado: 11871 -> 11871.txt
# Archivo renombrado: 11872 -> 11872.txt
# Archivo renombrado: 11873 -> 11873.txt
# Archivo renombrado: 11876 -> 11876.txt
# Archivo renombrado: 11877 -> 11877.txt
# Archivo renombrado: 11878 -> 11878.txt
# Archivo renombrado: 11879 -> 11879.txt
# Archivo renombrado: 1188 -> 1188.txt
# Archivo renombrado: 11880 -> 11880.txt
# Archivo renombrado: 11882 -> 11882.txt
# Archivo renombrado: 11883 -> 11883.txt
# Archivo renombrado: 11884 -> 11884.txt
# Archivo renombrado: 11885 -> 11885.txt
# Archivo renombrado: 11886 -> 11886.txt
# Archivo renombrado: 11888 -> 11888.txt
# Archivo renombrado: 11891 -> 11891.txt
# Archivo renombrado: 11892 -> 11892.txt
# Archivo renombrado: 11893 -> 11893.txt
# Archivo renombrado: 11894 -> 11894.txt
# Archivo renombrado: 11895 -> 11895.txt
# Archivo renombrado: 11896 -> 11896.txt
# Archivo renombrado: 11898 -> 11898.txt
# Archivo renombrado: 11900 -> 11900.txt
# Archivo renombrado: 11903 -> 11903.txt
# Archivo renombrado: 11904 -> 11904.txt
# Archivo renombrado: 11905 -> 11905.txt
# Archivo renombrado: 11907 -> 11907.txt
# Archivo renombrado: 11908 -> 11908.txt
# Archivo renombrado: 11909 -> 11909.txt
# ...
# Archivo renombrado: 9302 -> 9302.txt
# Archivo renombrado: 9304 -> 9304.txt
# Archivo renombrado: 9305 -> 9305.txt
# Archivo renombrado: 9306 -> 9306.txt
# Archivo renombrado: 9308 -> 9308.txt
# Archivo renombrado: 9311 -> 9311.txt
# Archivo renombrado: 9312 -> 9312.txt
# Archivo renombrado: 9313 -> 9313.txt
# Archivo renombrado: 9314 -> 9314.txt
# Archivo renombrado: 9315 -> 9315.txt
# Archivo renombrado: 9316 -> 9316.txt
# Archivo renombrado: 932 -> 932.txt
# Archivo renombrado: 9324 -> 9324.txt
# Archivo renombrado: 9326 -> 9326.txt
# Archivo renombrado: 9327 -> 9327.txt
# Archivo renombrado: 9328 -> 9328.txt
# Archivo renombrado: 9330 -> 9330.txt
# Archivo renombrado: 9332 -> 9332.txt
# Archivo renombrado: 9333 -> 9333.txt
# Archivo renombrado: 9334 -> 9334.txt
# Archivo renombrado: 9335 -> 9335.txt
# Archivo renombrado: 9336 -> 9336.txt
# Archivo renombrado: 9337 -> 9337.txt
# Archivo renombrado: 9338 -> 9338.txt
# Archivo renombrado: 9339 -> 9339.txt
# Archivo renombrado: 934 -> 934.txt
# Archivo renombrado: 9343 -> 9343.txt
# Archivo renombrado: 9345 -> 9345.txt
# Archivo renombrado: 9346 -> 9346.txt
# Archivo renombrado: 9348 -> 9348.txt
# Archivo renombrado: 9349 -> 9349.txt
# Archivo renombrado: 9352 -> 9352.txt
# Archivo renombrado: 9354 -> 9354.txt
# Archivo renombrado: 9356 -> 9356.txt
# Archivo renombrado: 9357 -> 9357.txt
# Archivo renombrado: 9361 -> 9361.txt
# Archivo renombrado: 9362 -> 9362.txt
# Archivo renombrado: 9363 -> 9363.txt
# Archivo renombrado: 9364 -> 9364.txt
# Archivo renombrado: 9365 -> 9365.txt
# Archivo renombrado: 9366 -> 9366.txt
# Archivo renombrado: 9369 -> 9369.txt
# Archivo renombrado: 937 -> 937.txt
# Archivo renombrado: 9371 -> 9371.txt
# Archivo renombrado: 9372 -> 9372.txt
# Archivo renombrado: 9373 -> 9373.txt
# Archivo renombrado: 9374 -> 9374.txt
# Archivo renombrado: 9377 -> 9377.txt
# Archivo renombrado: 9378 -> 9378.txt
# Archivo renombrado: 938 -> 938.txt
# Archivo renombrado: 9381 -> 9381.txt
# Archivo renombrado: 9382 -> 9382.txt
# Archivo renombrado: 9383 -> 9383.txt
# Archivo renombrado: 9385 -> 9385.txt
# Archivo renombrado: 9388 -> 9388.txt
# Archivo renombrado: 9389 -> 9389.txt
# Archivo renombrado: 939 -> 939.txt
# Archivo renombrado: 9392 -> 9392.txt
# Archivo renombrado: 9393 -> 9393.txt
# Archivo renombrado: 9397 -> 9397.txt
# Archivo renombrado: 9398 -> 9398.txt
# Archivo renombrado: 9399 -> 9399.txt
# Archivo renombrado: 94 -> 94.txt
# Archivo renombrado: 940 -> 940.txt
# Archivo renombrado: 9403 -> 9403.txt
# Archivo renombrado: 9405 -> 9405.txt
# Archivo renombrado: 9406 -> 9406.txt
# Archivo renombrado: 9408 -> 9408.txt
# Archivo renombrado: 941 -> 941.txt
# Archivo renombrado: 9410 -> 9410.txt
# Archivo renombrado: 9412 -> 9412.txt
# Archivo renombrado: 9413 -> 9413.txt
# Archivo renombrado: 9414 -> 9414.txt
# Archivo renombrado: 9415 -> 9415.txt
# Archivo renombrado: 9417 -> 9417.txt
# Archivo renombrado: 942 -> 942.txt
# Archivo renombrado: 9422 -> 9422.txt
# Archivo renombrado: 9423 -> 9423.txt
# Archivo renombrado: 9425 -> 9425.txt
# Archivo renombrado: 9426 -> 9426.txt
# Archivo renombrado: 9427 -> 9427.txt
# Archivo renombrado: 9428 -> 9428.txt
# Archivo renombrado: 9429 -> 9429.txt
# Archivo renombrado: 943 -> 943.txt
# Archivo renombrado: 9431 -> 9431.txt
# Archivo renombrado: 9432 -> 9432.txt
# Archivo renombrado: 9433 -> 9433.txt
# Archivo renombrado: 9434 -> 9434.txt
# Archivo renombrado: 9435 -> 9435.txt
# Archivo renombrado: 9436 -> 9436.txt
# Archivo renombrado: 9437 -> 9437.txt
# Archivo renombrado: 9438 -> 9438.txt
# Archivo renombrado: 944 -> 944.txt
# Archivo renombrado: 9441 -> 9441.txt
# Archivo renombrado: 9443 -> 9443.txt
# Archivo renombrado: 9444 -> 9444.txt
# Archivo renombrado: 9445 -> 9445.txt
# Archivo renombrado: 945 -> 945.txt
# Archivo renombrado: 9450 -> 9450.txt
# Archivo renombrado: 9453 -> 9453.txt
# Archivo renombrado: 9454 -> 9454.txt
# Archivo renombrado: 9463 -> 9463.txt
# Archivo renombrado: 9465 -> 9465.txt
# Archivo renombrado: 9469 -> 9469.txt
# Archivo renombrado: 9470 -> 9470.txt
# Archivo renombrado: 9472 -> 9472.txt
# Archivo renombrado: 9473 -> 9473.txt
# Archivo renombrado: 9475 -> 9475.txt
# Archivo renombrado: 9477 -> 9477.txt
# Archivo renombrado: 9478 -> 9478.txt
# Archivo renombrado: 9479 -> 9479.txt
# Archivo renombrado: 9484 -> 9484.txt
# Archivo renombrado: 9486 -> 9486.txt
# Archivo renombrado: 9487 -> 9487.txt
# Archivo renombrado: 9488 -> 9488.txt
# Archivo renombrado: 9489 -> 9489.txt
# Archivo renombrado: 949 -> 949.txt
# Archivo renombrado: 9491 -> 9491.txt
# Archivo renombrado: 9493 -> 9493.txt
# Archivo renombrado: 9497 -> 9497.txt
# Archivo renombrado: 9498 -> 9498.txt
# Archivo renombrado: 9499 -> 9499.txt
# Archivo renombrado: 95 -> 95.txt
# Archivo renombrado: 9502 -> 9502.txt
# Archivo renombrado: 9503 -> 9503.txt
# Archivo renombrado: 9505 -> 9505.txt
# Archivo renombrado: 9509 -> 9509.txt
# Archivo renombrado: 9510 -> 9510.txt
# Archivo renombrado: 9511 -> 9511.txt
# Archivo renombrado: 9515 -> 9515.txt
# Archivo renombrado: 9519 -> 9519.txt
# Archivo renombrado: 952 -> 952.txt
# Archivo renombrado: 9521 -> 9521.txt
# Archivo renombrado: 9525 -> 9525.txt
# Archivo renombrado: 9526 -> 9526.txt
# Archivo renombrado: 9527 -> 9527.txt
# Archivo renombrado: 953 -> 953.txt
# Archivo renombrado: 9530 -> 9530.txt
# Archivo renombrado: 9531 -> 9531.txt
# Archivo renombrado: 9532 -> 9532.txt
# Archivo renombrado: 9534 -> 9534.txt
# Archivo renombrado: 9535 -> 9535.txt
# Archivo renombrado: 9538 -> 9538.txt
# Archivo renombrado: 9539 -> 9539.txt
# Archivo renombrado: 9543 -> 9543.txt
# Archivo renombrado: 9544 -> 9544.txt
# Archivo renombrado: 9547 -> 9547.txt
# Archivo renombrado: 9549 -> 9549.txt
# Archivo renombrado: 955 -> 955.txt
# Archivo renombrado: 9550 -> 9550.txt
# Archivo renombrado: 9551 -> 9551.txt
# Archivo renombrado: 9554 -> 9554.txt
# Archivo renombrado: 9556 -> 9556.txt
# Archivo renombrado: 9557 -> 9557.txt
# Archivo renombrado: 9558 -> 9558.txt
# Archivo renombrado: 9559 -> 9559.txt
# Archivo renombrado: 9560 -> 9560.txt
# Archivo renombrado: 9561 -> 9561.txt
# Archivo renombrado: 9562 -> 9562.txt
# Archivo renombrado: 9563 -> 9563.txt
# Archivo renombrado: 9565 -> 9565.txt
# Archivo renombrado: 9566 -> 9566.txt
# Archivo renombrado: 9570 -> 9570.txt
# Archivo renombrado: 9572 -> 9572.txt
# Archivo renombrado: 9573 -> 9573.txt
# Archivo renombrado: 9576 -> 9576.txt
# Archivo renombrado: 9577 -> 9577.txt
# Archivo renombrado: 9578 -> 9578.txt
# Archivo renombrado: 958 -> 958.txt
# Archivo renombrado: 9580 -> 9580.txt
# Archivo renombrado: 9582 -> 9582.txt
# Archivo renombrado: 9583 -> 9583.txt
# Archivo renombrado: 9585 -> 9585.txt
# Archivo renombrado: 9587 -> 9587.txt
# Archivo renombrado: 9588 -> 9588.txt
# Archivo renombrado: 9590 -> 9590.txt
# Archivo renombrado: 9592 -> 9592.txt
# Archivo renombrado: 9597 -> 9597.txt
# Archivo renombrado: 9598 -> 9598.txt
# Archivo renombrado: 9599 -> 9599.txt
# Archivo renombrado: 96 -> 96.txt
# Archivo renombrado: 960 -> 960.txt
# Archivo renombrado: 9600 -> 9600.txt
# Archivo renombrado: 9603 -> 9603.txt
# Archivo renombrado: 9604 -> 9604.txt
# Archivo renombrado: 9605 -> 9605.txt
# Archivo renombrado: 9606 -> 9606.txt
# Archivo renombrado: 9607 -> 9607.txt
# Archivo renombrado: 9608 -> 9608.txt
# Archivo renombrado: 9610 -> 9610.txt
# Archivo renombrado: 9611 -> 9611.txt
# Archivo renombrado: 9612 -> 9612.txt
# Archivo renombrado: 9613 -> 9613.txt
# Archivo renombrado: 9614 -> 9614.txt
# Archivo renombrado: 9615 -> 9615.txt
# Archivo renombrado: 9617 -> 9617.txt
# Archivo renombrado: 9618 -> 9618.txt
# Archivo renombrado: 9619 -> 9619.txt
# Archivo renombrado: 9625 -> 9625.txt
# Archivo renombrado: 9626 -> 9626.txt
# Archivo renombrado: 9628 -> 9628.txt
# Archivo renombrado: 963 -> 963.txt
# Archivo renombrado: 9634 -> 9634.txt
# Archivo renombrado: 9635 -> 9635.txt
# Archivo renombrado: 9637 -> 9637.txt
# Archivo renombrado: 9638 -> 9638.txt
# Archivo renombrado: 9639 -> 9639.txt
# Archivo renombrado: 9640 -> 9640.txt
# Archivo renombrado: 9641 -> 9641.txt
# Archivo renombrado: 9642 -> 9642.txt
# Archivo renombrado: 9644 -> 9644.txt
# Archivo renombrado: 9647 -> 9647.txt
# Archivo renombrado: 9650 -> 9650.txt
# Archivo renombrado: 9652 -> 9652.txt
# Archivo renombrado: 9654 -> 9654.txt
# Archivo renombrado: 9656 -> 9656.txt
# Archivo renombrado: 9657 -> 9657.txt
# Archivo renombrado: 9661 -> 9661.txt
# Archivo renombrado: 9667 -> 9667.txt
# Archivo renombrado: 9668 -> 9668.txt
# Archivo renombrado: 9671 -> 9671.txt
# Archivo renombrado: 9674 -> 9674.txt
# Archivo renombrado: 9675 -> 9675.txt
# Archivo renombrado: 9677 -> 9677.txt
# Archivo renombrado: 9678 -> 9678.txt
# Archivo renombrado: 968 -> 968.txt
# Archivo renombrado: 9680 -> 9680.txt
# Archivo renombrado: 9681 -> 9681.txt
# Archivo renombrado: 9682 -> 9682.txt
# Archivo renombrado: 9686 -> 9686.txt
# Archivo renombrado: 9689 -> 9689.txt
# Archivo renombrado: 969 -> 969.txt
# Archivo renombrado: 9697 -> 9697.txt
# Archivo renombrado: 9698 -> 9698.txt
# Archivo renombrado: 9699 -> 9699.txt
# Archivo renombrado: 97 -> 97.txt
# Archivo renombrado: 9700 -> 9700.txt
# Archivo renombrado: 9701 -> 9701.txt
# Archivo renombrado: 9704 -> 9704.txt
# Archivo renombrado: 9705 -> 9705.txt
# Archivo renombrado: 9706 -> 9706.txt
# Archivo renombrado: 9707 -> 9707.txt
# Archivo renombrado: 971 -> 971.txt
# Archivo renombrado: 9712 -> 9712.txt
# Archivo renombrado: 9718 -> 9718.txt
# Archivo renombrado: 972 -> 972.txt
# Archivo renombrado: 9720 -> 9720.txt
# Archivo renombrado: 9723 -> 9723.txt
# Archivo renombrado: 9727 -> 9727.txt
# Archivo renombrado: 9728 -> 9728.txt
# Archivo renombrado: 9729 -> 9729.txt
# Archivo renombrado: 9730 -> 9730.txt
# Archivo renombrado: 9731 -> 9731.txt
# Archivo renombrado: 9733 -> 9733.txt
# Archivo renombrado: 9734 -> 9734.txt
# Archivo renombrado: 9735 -> 9735.txt
# Archivo renombrado: 9736 -> 9736.txt
# Archivo renombrado: 9737 -> 9737.txt
# Archivo renombrado: 9738 -> 9738.txt
# Archivo renombrado: 974 -> 974.txt
# Archivo renombrado: 9741 -> 9741.txt
# Archivo renombrado: 9742 -> 9742.txt
# Archivo renombrado: 9744 -> 9744.txt
# Archivo renombrado: 9745 -> 9745.txt
# Archivo renombrado: 9746 -> 9746.txt
# Archivo renombrado: 9747 -> 9747.txt
# Archivo renombrado: 9748 -> 9748.txt
# Archivo renombrado: 9749 -> 9749.txt
# Archivo renombrado: 9751 -> 9751.txt
# Archivo renombrado: 9752 -> 9752.txt
# Archivo renombrado: 9753 -> 9753.txt
# Archivo renombrado: 9754 -> 9754.txt
# Archivo renombrado: 9755 -> 9755.txt
# Archivo renombrado: 9756 -> 9756.txt
# Archivo renombrado: 976 -> 976.txt
# Archivo renombrado: 9760 -> 9760.txt
# Archivo renombrado: 9761 -> 9761.txt
# Archivo renombrado: 9763 -> 9763.txt
# Archivo renombrado: 9764 -> 9764.txt
# Archivo renombrado: 9767 -> 9767.txt
# Archivo renombrado: 9768 -> 9768.txt
# Archivo renombrado: 9769 -> 9769.txt
# Archivo renombrado: 977 -> 977.txt
# Archivo renombrado: 9770 -> 9770.txt
# Archivo renombrado: 9771 -> 9771.txt
# Archivo renombrado: 9772 -> 9772.txt
# Archivo renombrado: 9773 -> 9773.txt
# Archivo renombrado: 9777 -> 9777.txt
# Archivo renombrado: 9779 -> 9779.txt
# Archivo renombrado: 978 -> 978.txt
# Archivo renombrado: 9781 -> 9781.txt
# Archivo renombrado: 9782 -> 9782.txt
# Archivo renombrado: 9783 -> 9783.txt
# Archivo renombrado: 9784 -> 9784.txt
# Archivo renombrado: 9787 -> 9787.txt
# Archivo renombrado: 9792 -> 9792.txt
# Archivo renombrado: 9793 -> 9793.txt
# Archivo renombrado: 9795 -> 9795.txt
# Archivo renombrado: 9797 -> 9797.txt
# Archivo renombrado: 9799 -> 9799.txt
# Archivo renombrado: 98 -> 98.txt
# Archivo renombrado: 9801 -> 9801.txt
# Archivo renombrado: 9804 -> 9804.txt
# Archivo renombrado: 9805 -> 9805.txt
# Archivo renombrado: 9807 -> 9807.txt
# Archivo renombrado: 9809 -> 9809.txt
# Archivo renombrado: 981 -> 981.txt
# Archivo renombrado: 9810 -> 9810.txt
# Archivo renombrado: 9812 -> 9812.txt
# Archivo renombrado: 9814 -> 9814.txt
# Archivo renombrado: 9815 -> 9815.txt
# Archivo renombrado: 9816 -> 9816.txt
# Archivo renombrado: 9818 -> 9818.txt
# Archivo renombrado: 982 -> 982.txt
# Archivo renombrado: 9821 -> 9821.txt
# Archivo renombrado: 9822 -> 9822.txt
# Archivo renombrado: 9823 -> 9823.txt
# Archivo renombrado: 9824 -> 9824.txt
# Archivo renombrado: 9825 -> 9825.txt
# Archivo renombrado: 9827 -> 9827.txt
# Archivo renombrado: 9829 -> 9829.txt
# Archivo renombrado: 983 -> 983.txt
# Archivo renombrado: 9833 -> 9833.txt
# Archivo renombrado: 9834 -> 9834.txt
# Archivo renombrado: 9836 -> 9836.txt
# Archivo renombrado: 9837 -> 9837.txt
# Archivo renombrado: 9839 -> 9839.txt
# Archivo renombrado: 984 -> 984.txt
# Archivo renombrado: 9841 -> 9841.txt
# Archivo renombrado: 9844 -> 9844.txt
# Archivo renombrado: 9847 -> 9847.txt
# Archivo renombrado: 9848 -> 9848.txt
# Archivo renombrado: 9849 -> 9849.txt
# Archivo renombrado: 985 -> 985.txt
# Archivo renombrado: 9850 -> 9850.txt
# Archivo renombrado: 9851 -> 9851.txt
# Archivo renombrado: 9852 -> 9852.txt
# Archivo renombrado: 9853 -> 9853.txt
# Archivo renombrado: 9855 -> 9855.txt
# Archivo renombrado: 9857 -> 9857.txt
# Archivo renombrado: 9858 -> 9858.txt
# Archivo renombrado: 986 -> 986.txt
# Archivo renombrado: 9860 -> 9860.txt
# Archivo renombrado: 9861 -> 9861.txt
# Archivo renombrado: 9862 -> 9862.txt
# Archivo renombrado: 9864 -> 9864.txt
# Archivo renombrado: 9865 -> 9865.txt
# Archivo renombrado: 9866 -> 9866.txt
# Archivo renombrado: 9867 -> 9867.txt
# Archivo renombrado: 9868 -> 9868.txt
# Archivo renombrado: 9869 -> 9869.txt
# Archivo renombrado: 9871 -> 9871.txt
# Archivo renombrado: 9872 -> 9872.txt
# Archivo renombrado: 9874 -> 9874.txt
# Archivo renombrado: 9875 -> 9875.txt
# Archivo renombrado: 9878 -> 9878.txt
# Archivo renombrado: 988 -> 988.txt
# Archivo renombrado: 9880 -> 9880.txt
# Archivo renombrado: 9884 -> 9884.txt
# Archivo renombrado: 9891 -> 9891.txt
# Archivo renombrado: 9892 -> 9892.txt
# Archivo renombrado: 9893 -> 9893.txt
# Archivo renombrado: 9894 -> 9894.txt
# Archivo renombrado: 9896 -> 9896.txt
# Archivo renombrado: 9897 -> 9897.txt
# Archivo renombrado: 99 -> 99.txt
# Archivo renombrado: 9901 -> 9901.txt
# Archivo renombrado: 9902 -> 9902.txt
# Archivo renombrado: 9903 -> 9903.txt
# Archivo renombrado: 9904 -> 9904.txt
# Archivo renombrado: 9905 -> 9905.txt
# Archivo renombrado: 9906 -> 9906.txt
# Archivo renombrado: 9907 -> 9907.txt
# Archivo renombrado: 9909 -> 9909.txt
# Archivo renombrado: 991 -> 991.txt
# Archivo renombrado: 9912 -> 9912.txt
# Archivo renombrado: 9913 -> 9913.txt
# Archivo renombrado: 9914 -> 9914.txt
# Archivo renombrado: 9915 -> 9915.txt
# Archivo renombrado: 9918 -> 9918.txt
# Archivo renombrado: 9919 -> 9919.txt
# Archivo renombrado: 9920 -> 9920.txt
# Archivo renombrado: 9923 -> 9923.txt
# Archivo renombrado: 9925 -> 9925.txt
# Archivo renombrado: 9926 -> 9926.txt
# Archivo renombrado: 9927 -> 9927.txt
# Archivo renombrado: 9928 -> 9928.txt
# Archivo renombrado: 9929 -> 9929.txt
# Archivo renombrado: 9930 -> 9930.txt
# Archivo renombrado: 9933 -> 9933.txt
# Archivo renombrado: 9934 -> 9934.txt
# Archivo renombrado: 9936 -> 9936.txt
# Archivo renombrado: 9937 -> 9937.txt
# Archivo renombrado: 9939 -> 9939.txt
# Archivo renombrado: 9940 -> 9940.txt
# Archivo renombrado: 9941 -> 9941.txt
# Archivo renombrado: 9942 -> 9942.txt
# Archivo renombrado: 9943 -> 9943.txt
# Archivo renombrado: 9946 -> 9946.txt
# Archivo renombrado: 9947 -> 9947.txt
# Archivo renombrado: 995 -> 995.txt
# Archivo renombrado: 9952 -> 9952.txt
# Archivo renombrado: 9953 -> 9953.txt
# Archivo renombrado: 9954 -> 9954.txt
# Archivo renombrado: 9955 -> 9955.txt
# Archivo renombrado: 9956 -> 9956.txt
# Archivo renombrado: 9957 -> 9957.txt
# Archivo renombrado: 9958 -> 9958.txt
# Archivo renombrado: 9959 -> 9959.txt
# Archivo renombrado: 9961 -> 9961.txt
# Archivo renombrado: 9963 -> 9963.txt
# Archivo renombrado: 9964 -> 9964.txt
# Archivo renombrado: 9965 -> 9965.txt
# Archivo renombrado: 9967 -> 9967.txt
# Archivo renombrado: 9970 -> 9970.txt
# Archivo renombrado: 9971 -> 9971.txt
# Archivo renombrado: 9972 -> 9972.txt
# Archivo renombrado: 9973 -> 9973.txt
# Archivo renombrado: 9974 -> 9974.txt
# Archivo renombrado: 9975 -> 9975.txt
# Archivo renombrado: 9976 -> 9976.txt
# Archivo renombrado: 9977 -> 9977.txt
# Archivo renombrado: 9978 -> 9978.txt
# Archivo renombrado: 998 -> 998.txt
# Archivo renombrado: 9981 -> 9981.txt
# Archivo renombrado: 9982 -> 9982.txt
# Archivo renombrado: 9984 -> 9984.txt
# Archivo renombrado: 9985 -> 9985.txt
# Archivo renombrado: 9988 -> 9988.txt
# Archivo renombrado: 9989 -> 9989.txt
# Archivo renombrado: 999 -> 999.txt
# Archivo renombrado: 9992 -> 9992.txt
# Archivo renombrado: 9993 -> 9993.txt
# Archivo renombrado: 9994 -> 9994.txt
# Archivo renombrado: 9995 -> 9995.txt

# %%
import os
import csv

# Ruta de la carpeta con los archivos .txt
ruta_carpeta = "./data"

# Ruta del archivo cats.txt
ruta_categorias = "./cats.txt"

# Ruta de salida para el archivo CSV
ruta_csv = "database.csv"

# Cargar las categorías desde cats.txt en un diccionario
categorias = {}
with open(ruta_categorias, "r") as f:
    for linea in f:
        partes = linea.strip().split(maxsplit=1)  # Solo dividir en 2 partes: nombre y categoría
        if len(partes) == 2:  # Asegurarse de que tiene nombre y categoría
            nombre_archivo = partes[0].split("/")[-1]  # Extraer solo el número
            categorias[nombre_archivo] = partes[1]  # Guardar la categoría completa

# Crear el CSV
with open(ruta_csv, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["nombre del archivo", "texto", "categorias", "titulo"])  # Escribir encabezado

    # Procesar cada archivo .txt en la carpeta
    for archivo in os.listdir(ruta_carpeta):
        if archivo.endswith(".txt"):  # Solo procesar archivos .txt
            ruta_archivo = os.path.join(ruta_carpeta, archivo)
            
            # Leer el contenido del archivo
            try:
                # Intentar leer con utf-8
                with open(ruta_archivo, "r", encoding="utf-8") as f:
                    lineas = f.readlines()
            except UnicodeDecodeError:
                # Si falla, intentar con latin-1
                with open(ruta_archivo, "r", encoding="latin-1") as f:
                    lineas = f.readlines()

            if lineas:  # Si el archivo tiene contenido
                titulo = lineas[0].strip()  # Primera línea como título
                texto = " ".join(lineas).strip()  # Unir todo el texto
                nombre_archivo = os.path.splitext(archivo)[0]  # Quitar extensión
                categoria = categorias.get(nombre_archivo, "Sin categoría")  # Obtener categoría
                
                # Escribir fila en el CSV
                writer.writerow([nombre_archivo, texto, categoria, titulo])

print(f"Archivo CSV creado en: {ruta_csv}")
# Out:
# Archivo CSV creado en: datosagrupados1.csv

# %%
import pandas as pd
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Descargar recursos necesarios de nltk
nltk.download('stopwords')

# Cargar el archivo CSV
ruta_csv = "database.csv"
corpus = pd.read_csv(ruta_csv)

# Definir funciones de preprocesamiento
def limpiar_texto(texto):
    """Convierte el texto a minúsculas y elimina puntuación."""
    texto = texto.lower()  # Convertir a minúsculas
    texto = texto.translate(str.maketrans("", "", string.punctuation))  # Eliminar puntuación
    return texto

def tokenizar_texto(texto):
    """Tokeniza el texto dividiéndolo en palabras."""
    return texto.split()

def eliminar_stopwords(tokens):
    """Elimina las stopwords del texto tokenizado."""
    stop_words = set(stopwords.words('english'))
    return [word for word in tokens if word not in stop_words]

def aplicar_stemming(tokens):
    """Aplica stemming a los tokens."""
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in tokens]

# Aplicar las funciones de preprocesamiento en cadena
corpus['texto'] = corpus['texto'].apply(limpiar_texto)  # Normalización
corpus['tokens'] = corpus['texto'].apply(tokenizar_texto)  # Tokenización
corpus['tokens'] = corpus['tokens'].apply(eliminar_stopwords)  # Eliminar stopwords
corpus['tokens'] = corpus['tokens'].apply(aplicar_stemming)  # Stemming

# Guardar el corpus preprocesado en un nuevo archivo CSV
corpus.to_csv("database_preprocessed.csv", index=False)

print("Corpus preprocesado guardado en 'database_preprocessed.csv'")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wbrja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Corpus preprocesado guardado en 'database_preprocessed.csv'

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import pandas as pd
import numpy as np

print("Todas las bibliotecas se importaron correctamente.")
# Out:
# Todas las bibliotecas se importaron correctamente.

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import pandas as pd
import numpy as np

# Cargar el archivo procesado
ruta_procesado = "database_preprocessed.csv"
corpus = pd.read_csv(ruta_procesado)

# Convertir la lista de tokens de nuevo a texto y como listas para Word2Vec
corpus['tokens_list'] = corpus['tokens'].apply(eval)  # Convertir strings de listas a listas reales
corpus['tokens_text'] = corpus['tokens_list'].apply(lambda x: " ".join(x))  # Convertir lista a texto

# Bag of Words (BoW)
bow_vectorizer = CountVectorizer()
bow_matrix = bow_vectorizer.fit_transform(corpus['tokens_text'])

# TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus['tokens_text'])

# Word2Vec
# Entrenar el modelo Word2Vec con las listas de tokens
word2vec_model = Word2Vec(sentences=corpus['tokens_list'], vector_size=100, window=5, min_count=1, workers=4)

# Crear una representación vectorial promedio para cada documento
def get_average_word2vec(tokens, model, vector_size):
    """Obtiene el promedio de vectores de Word2Vec para un documento."""
    vector = np.zeros(vector_size)
    count = 0
    for word in tokens:
        if word in model.wv:
            vector += model.wv[word]
            count += 1
    return vector / count if count > 0 else vector

# Generar matriz de Word2Vec para el corpus
word2vec_matrix = np.array([get_average_word2vec(tokens, word2vec_model, 100) for tokens in corpus['tokens_list']])

# Guardar las matrices en archivos CSV
# BoW
pd.DataFrame(bow_matrix.toarray(), columns=bow_vectorizer.get_feature_names_out()).to_csv("bow_matrix.csv", index=False)

# TF-IDF
pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out()).to_csv("tfidf_matrix.csv", index=False)

# Word2Vec
pd.DataFrame(word2vec_matrix).to_csv("word2vec_matrix.csv", index=False)

print("Matrices BoW, TF-IDF y Word2Vec guardadas en 'bow_matrix.csv', 'tfidf_matrix.csv' y 'word2vec_matrix.csv'.")
# Out:
# Matrices BoW, TF-IDF y Word2Vec guardadas en 'bow_matrix.csv', 'tfidf_matrix.csv' y 'word2vec_matrix.csv'.

# %%
import pandas as pd
import numpy as np

# Cargar las matrices previamente generadas
bow_matrix = pd.read_csv("bow_matrix.csv")
tfidf_matrix = pd.read_csv("tfidf_matrix.csv")
word2vec_matrix = pd.read_csv("word2vec_matrix.csv")

# Crear un índice invertido basado en la matriz TF-IDF
def build_inverted_index(tfidf_matrix, feature_names):
    """Construir un índice invertido a partir de la matriz TF-IDF."""
    inverted_index = {}
    for term_idx, term in enumerate(feature_names):
        docs_with_term = np.where(tfidf_matrix.iloc[:, term_idx] > 0)[0]
        inverted_index[term] = docs_with_term.tolist()
    return inverted_index

# Cargar nombres de características (palabras)
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_vectorizer.fit_transform(pd.read_csv("database_preprocessed.csv")["tokens_text"])
feature_names = tfidf_vectorizer.get_feature_names_out()

# Construir el índice invertido
inverted_index = build_inverted_index(tfidf_matrix, feature_names)

# Guardar el índice invertido
import json
with open("inverted_index.json", "w") as f:
    json.dump(inverted_index, f)

print("Índice invertido creado y guardado como 'inverted_index.json'.")
# Out:
# Índice invertido creado y guardado como 'inverted_index.json'.

# %%
import json

# Cargar el índice invertido
with open("inverted_index.json", "r") as f:
    inverted_index = json.load(f)

def buscar_termino(termino, indice):
    """
    Busca un término en el índice invertido y devuelve los documentos donde aparece.
    """
    if termino in indice:
        return indice[termino]
    else:
        return []

def buscar_consulta(consulta, indice):
    """
    Busca una consulta compuesta por varios términos en el índice invertido.
    Devuelve una lista de documentos donde aparecen todos los términos.
    """
    terminos = consulta.split()  # Dividir la consulta en términos
    resultados = [set(buscar_termino(termino, indice)) for termino in terminos]

    # Intersección de resultados (documentos que contienen todos los términos)
    if resultados:
        documentos_relevantes = set.intersection(*resultados)
        return list(documentos_relevantes)
    else:
        return []

# Ejemplo de búsqueda
consulta = "bahia cocoa"
resultados = buscar_consulta(consulta, inverted_index)

print(f"Documentos relevantes para la consulta '{consulta}': {resultados}")
# Out:
# Documentos relevantes para la consulta 'bahia cocoa': [0, 2047, 941, 3773]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Cargar el corpus procesado
ruta_corpus = "database_preprocessed.csv"
corpus = pd.read_csv(ruta_corpus)

# Crear el vectorizador TF-IDF y ajustar al texto
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus["tokens_text"])  # Matriz TF-IDF

# Función de búsqueda con similitud coseno
def buscar_similitud_coseno(consulta, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5):
    """
    Realiza una búsqueda basada en similitud coseno usando TF-IDF.
    
    Parámetros:
        consulta: Consulta de búsqueda (str).
        tfidf_vectorizer: Vectorizador TF-IDF ajustado al corpus.
        tfidf_matrix: Matriz TF-IDF del corpus.
        corpus: DataFrame con el corpus original.
        top_n: Número de documentos relevantes a devolver.
    
    Retorna:
        DataFrame con los documentos más relevantes y sus puntuaciones de similitud.
    """
    # Vectorizar la consulta
    consulta_vector = tfidf_vectorizer.transform([consulta])

    # Calcular similitud coseno entre la consulta y todos los documentos
    similitudes = cosine_similarity(consulta_vector, tfidf_matrix).flatten()

    # Obtener los índices de los documentos más similares
    top_indices = similitudes.argsort()[-top_n:][::-1]  # Top N en orden descendente

    # Crear un DataFrame con los resultados relevantes
    resultados = corpus.iloc[top_indices].copy()
    resultados["similitud"] = similitudes[top_indices]

    return resultados

# Ejemplo de búsqueda
consulta = "asian cocoa"
resultados = buscar_similitud_coseno(consulta, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5)

# Mostrar los resultados
print("Resultados de búsqueda:")
print(resultados[["nombre del archivo", "similitud", "texto"]])

# Guardar resultados en un archivo CSV
resultados.to_csv("resultados_busqueda.csv", index=False)
print("Resultados guardados en 'resultados_busqueda.csv'.")
# Out:
# Resultados de búsqueda:
#       nombre del archivo  similitud  \
# 4862               20005   0.510436
# 318                10505   0.451663
# 7727                5258   0.395753
# 319                10506   0.395251
# 366                10586   0.394103
#
#                                                   texto
# 4862  asian cocoa producers expand despite critics\n...
# 318   icco council agrees cocoa buffer stock rules\n...
# 7727  cocoa latest focus for commodity pact negotiat...
# 319   cocoa buffer stock rules effective immediately...
# 366   cocoa council meeting ends after agreeing rule...
# Resultados guardados en 'resultados_busqueda.csv'.

# %% [markdown]
# 2.6. Evaluación del Sistema

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Resultados esperados (relevantes) para cada consulta (Ground Truth)
consultas = {
    "bahia cocoa": [0, 318, 3773, 4862, 7727],  # Índices de documentos relevantes para esta consulta
    "asian cocoa": [4862, 318, 7727, 319, 366],  # Otra consulta
}

# Función para calcular métricas de evaluación
def evaluar_sistema(consultas, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5):
    resultados = []
    for consulta, relevantes_esperados in consultas.items():
        # Realizar búsqueda con similitud coseno
        consulta_vector = tfidf_vectorizer.transform([consulta])
        similitudes = cosine_similarity(consulta_vector, tfidf_matrix).flatten()
        indices_top = similitudes.argsort()[-top_n:][::-1]  # Índices de documentos más relevantes

        # Calcular métricas
        y_true = [1 if idx in relevantes_esperados else 0 for idx in range(len(corpus))]
        y_pred = [1 if idx in indices_top else 0 for idx in range(len(corpus))]

        precision = precision_score(y_true, y_pred, zero_division=0)
        recall = recall_score(y_true, y_pred, zero_division=0)
        f1 = f1_score(y_true, y_pred, zero_division=0)

        # Guardar los resultados de la consulta
        resultados.append({
            "consulta": consulta,
            "precision": precision,
            "recall": recall,
            "f1_score": f1,
            "relevantes_encontrados": indices_top.tolist(),
        })

    return resultados

# Evaluar el sistema
resultados_evaluacion = evaluar_sistema(consultas, tfidf_vectorizer, tfidf_matrix, corpus)

# Mostrar los resultados
for resultado in resultados_evaluacion:
    print(f"Consulta: {resultado['consulta']}")
    print(f"  Precisión: {resultado['precision']:.2f}")
    print(f"  Recuperación: {resultado['recall']:.2f}")
    print(f"  F1-Score: {resultado['f1_score']:.2f}")
    print(f"  Documentos encontrados: {resultado['relevantes_encontrados']}")
    print()

# Guardar los resultados en un archivo CSV
import pandas as pd
df_resultados = pd.DataFrame(resultados_evaluacion)
df_resultados.to_csv("evaluacion_sistema.csv", index=False)
print("Resultados de evaluación guardados en 'evaluacion_sistema.csv'.")
# Out:
# Consulta: bahia cocoa
#   Precisión: 1.00
#   Recuperación: 1.00
#   F1-Score: 1.00
#   Documentos encontrados: [318, 4862, 0, 3773, 7727]
#
# Consulta: asian cocoa
#   Precisión: 1.00
#   Recuperación: 1.00
#   F1-Score: 1.00
#   Documentos encontrados: [4862, 318, 7727, 319, 366]
#
# Resultados de evaluación guardados en 'evaluacion_sistema.csv'.
