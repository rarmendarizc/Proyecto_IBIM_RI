# %% [markdown]
# # Pre-Procesamiento del Corpus
# Obtención de los datos
#
# Se agrega la extensión .txt a los documentos.

# %%
import os

# Ruta donde están los archivos
ruta_carpeta = "./data"

# Iterar sobre todos los archivos en la carpeta
for archivo in os.listdir(ruta_carpeta):
    # Ruta completa del archivo original
    archivo_original = os.path.join(ruta_carpeta, archivo)

    # Verificar que sea un archivo (no una carpeta)
    if os.path.isfile(archivo_original):
        # Separar el nombre y la extensión
        nombre, extension = os.path.splitext(archivo)

        # Crear el nuevo nombre con la extensión .txt
        nuevo_nombre = nombre + ".txt"
        archivo_nuevo = os.path.join(ruta_carpeta, nuevo_nombre)

        # Renombrar el archivo
        os.rename(archivo_original, archivo_nuevo)
        print(f"Archivo renombrado: {archivo} -> {nuevo_nombre}")
# Out:
# Archivo renombrado: 1.txt -> 1.txt
# Archivo renombrado: 10.txt -> 10.txt
# Archivo renombrado: 100.txt -> 100.txt
# Archivo renombrado: 1000.txt -> 1000.txt
# Archivo renombrado: 10000.txt -> 10000.txt
# Archivo renombrado: 10002.txt -> 10002.txt
# Archivo renombrado: 10005.txt -> 10005.txt
# Archivo renombrado: 10008.txt -> 10008.txt
# Archivo renombrado: 10011.txt -> 10011.txt
# Archivo renombrado: 10014.txt -> 10014.txt
# Archivo renombrado: 10015.txt -> 10015.txt
# Archivo renombrado: 10018.txt -> 10018.txt
# Archivo renombrado: 10023.txt -> 10023.txt
# Archivo renombrado: 10025.txt -> 10025.txt
# Archivo renombrado: 10027.txt -> 10027.txt
# Archivo renombrado: 1003.txt -> 1003.txt
# Archivo renombrado: 10032.txt -> 10032.txt
# Archivo renombrado: 10035.txt -> 10035.txt
# Archivo renombrado: 10037.txt -> 10037.txt
# Archivo renombrado: 10038.txt -> 10038.txt
# Archivo renombrado: 10040.txt -> 10040.txt
# Archivo renombrado: 10041.txt -> 10041.txt
# Archivo renombrado: 10042.txt -> 10042.txt
# Archivo renombrado: 10043.txt -> 10043.txt
# Archivo renombrado: 10046.txt -> 10046.txt
# Archivo renombrado: 10048.txt -> 10048.txt
# Archivo renombrado: 10049.txt -> 10049.txt
# Archivo renombrado: 10050.txt -> 10050.txt
# Archivo renombrado: 10052.txt -> 10052.txt
# Archivo renombrado: 10053.txt -> 10053.txt
# Archivo renombrado: 10054.txt -> 10054.txt
# Archivo renombrado: 10057.txt -> 10057.txt
# Archivo renombrado: 10058.txt -> 10058.txt
# Archivo renombrado: 10061.txt -> 10061.txt
# Archivo renombrado: 10062.txt -> 10062.txt
# Archivo renombrado: 10064.txt -> 10064.txt
# Archivo renombrado: 10065.txt -> 10065.txt
# Archivo renombrado: 10066.txt -> 10066.txt
# Archivo renombrado: 10067.txt -> 10067.txt
# Archivo renombrado: 10068.txt -> 10068.txt
# Archivo renombrado: 1007.txt -> 1007.txt
# Archivo renombrado: 10071.txt -> 10071.txt
# Archivo renombrado: 10073.txt -> 10073.txt
# Archivo renombrado: 10074.txt -> 10074.txt
# Archivo renombrado: 10075.txt -> 10075.txt
# Archivo renombrado: 10076.txt -> 10076.txt
# Archivo renombrado: 10078.txt -> 10078.txt
# Archivo renombrado: 10079.txt -> 10079.txt
# Archivo renombrado: 1008.txt -> 1008.txt
# Archivo renombrado: 10080.txt -> 10080.txt
# Archivo renombrado: 10081.txt -> 10081.txt
# Archivo renombrado: 10083.txt -> 10083.txt
# Archivo renombrado: 10085.txt -> 10085.txt
# Archivo renombrado: 10086.txt -> 10086.txt
# Archivo renombrado: 10088.txt -> 10088.txt
# Archivo renombrado: 10089.txt -> 10089.txt
# Archivo renombrado: 1009.txt -> 1009.txt
# Archivo renombrado: 10090.txt -> 10090.txt
# Archivo renombrado: 10091.txt -> 10091.txt
# Archivo renombrado: 10092.txt -> 10092.txt
# Archivo renombrado: 10094.txt -> 10094.txt
# Archivo renombrado: 10095.txt -> 10095.txt
# Archivo renombrado: 10096.txt -> 10096.txt
# Archivo renombrado: 10097.txt -> 10097.txt
# Archivo renombrado: 10098.txt -> 10098.txt
# Archivo renombrado: 10099.txt -> 10099.txt
# Archivo renombrado: 101.txt -> 101.txt
# Archivo renombrado: 1010.txt -> 1010.txt
# Archivo renombrado: 10100.txt -> 10100.txt
# Archivo renombrado: 10102.txt -> 10102.txt
# Archivo renombrado: 10105.txt -> 10105.txt
# Archivo renombrado: 10106.txt -> 10106.txt
# Archivo renombrado: 10107.txt -> 10107.txt
# Archivo renombrado: 10108.txt -> 10108.txt
# Archivo renombrado: 10109.txt -> 10109.txt
# Archivo renombrado: 1011.txt -> 1011.txt
# Archivo renombrado: 10110.txt -> 10110.txt
# Archivo renombrado: 10112.txt -> 10112.txt
# Archivo renombrado: 10114.txt -> 10114.txt
# Archivo renombrado: 10115.txt -> 10115.txt
# Archivo renombrado: 10119.txt -> 10119.txt
# Archivo renombrado: 10120.txt -> 10120.txt
# Archivo renombrado: 10122.txt -> 10122.txt
# Archivo renombrado: 10124.txt -> 10124.txt
# Archivo renombrado: 10128.txt -> 10128.txt
# Archivo renombrado: 10129.txt -> 10129.txt
# Archivo renombrado: 1013.txt -> 1013.txt
# Archivo renombrado: 10130.txt -> 10130.txt
# Archivo renombrado: 10135.txt -> 10135.txt
# Archivo renombrado: 10136.txt -> 10136.txt
# Archivo renombrado: 10139.txt -> 10139.txt
# Archivo renombrado: 10140.txt -> 10140.txt
# Archivo renombrado: 10146.txt -> 10146.txt
# Archivo renombrado: 1015.txt -> 1015.txt
# Archivo renombrado: 10151.txt -> 10151.txt
# Archivo renombrado: 10153.txt -> 10153.txt
# Archivo renombrado: 10154.txt -> 10154.txt
# Archivo renombrado: 10155.txt -> 10155.txt
# Archivo renombrado: 10156.txt -> 10156.txt
# Archivo renombrado: 10158.txt -> 10158.txt
# Archivo renombrado: 1016.txt -> 1016.txt
# Archivo renombrado: 10162.txt -> 10162.txt
# Archivo renombrado: 10163.txt -> 10163.txt
# Archivo renombrado: 10165.txt -> 10165.txt
# Archivo renombrado: 10168.txt -> 10168.txt
# Archivo renombrado: 1017.txt -> 1017.txt
# Archivo renombrado: 10171.txt -> 10171.txt
# Archivo renombrado: 10172.txt -> 10172.txt
# Archivo renombrado: 10173.txt -> 10173.txt
# Archivo renombrado: 10174.txt -> 10174.txt
# Archivo renombrado: 10175.txt -> 10175.txt
# Archivo renombrado: 10176.txt -> 10176.txt
# Archivo renombrado: 10177.txt -> 10177.txt
# Archivo renombrado: 10178.txt -> 10178.txt
# Archivo renombrado: 10180.txt -> 10180.txt
# Archivo renombrado: 10181.txt -> 10181.txt
# Archivo renombrado: 10183.txt -> 10183.txt
# Archivo renombrado: 10185.txt -> 10185.txt
# Archivo renombrado: 10186.txt -> 10186.txt
# Archivo renombrado: 1019.txt -> 1019.txt
# Archivo renombrado: 10190.txt -> 10190.txt
# Archivo renombrado: 10191.txt -> 10191.txt
# Archivo renombrado: 10192.txt -> 10192.txt
# Archivo renombrado: 10196.txt -> 10196.txt
# Archivo renombrado: 10197.txt -> 10197.txt
# Archivo renombrado: 102.txt -> 102.txt
# Archivo renombrado: 1020.txt -> 1020.txt
# Archivo renombrado: 10200.txt -> 10200.txt
# Archivo renombrado: 10201.txt -> 10201.txt
# Archivo renombrado: 10207.txt -> 10207.txt
# Archivo renombrado: 10208.txt -> 10208.txt
# Archivo renombrado: 10209.txt -> 10209.txt
# Archivo renombrado: 10211.txt -> 10211.txt
# Archivo renombrado: 10213.txt -> 10213.txt
# Archivo renombrado: 10214.txt -> 10214.txt
# Archivo renombrado: 10215.txt -> 10215.txt
# Archivo renombrado: 10216.txt -> 10216.txt
# Archivo renombrado: 10218.txt -> 10218.txt
# Archivo renombrado: 10219.txt -> 10219.txt
# Archivo renombrado: 1022.txt -> 1022.txt
# Archivo renombrado: 10222.txt -> 10222.txt
# Archivo renombrado: 10224.txt -> 10224.txt
# Archivo renombrado: 10225.txt -> 10225.txt
# Archivo renombrado: 10227.txt -> 10227.txt
# Archivo renombrado: 10228.txt -> 10228.txt
# Archivo renombrado: 1023.txt -> 1023.txt
# Archivo renombrado: 10230.txt -> 10230.txt
# Archivo renombrado: 10231.txt -> 10231.txt
# Archivo renombrado: 10233.txt -> 10233.txt
# Archivo renombrado: 10235.txt -> 10235.txt
# Archivo renombrado: 10237.txt -> 10237.txt
# Archivo renombrado: 10238.txt -> 10238.txt
# Archivo renombrado: 1024.txt -> 1024.txt
# Archivo renombrado: 10240.txt -> 10240.txt
# Archivo renombrado: 10242.txt -> 10242.txt
# Archivo renombrado: 10243.txt -> 10243.txt
# Archivo renombrado: 10245.txt -> 10245.txt
# Archivo renombrado: 10246.txt -> 10246.txt
# Archivo renombrado: 10253.txt -> 10253.txt
# Archivo renombrado: 10254.txt -> 10254.txt
# Archivo renombrado: 10255.txt -> 10255.txt
# Archivo renombrado: 10258.txt -> 10258.txt
# Archivo renombrado: 1026.txt -> 1026.txt
# Archivo renombrado: 10260.txt -> 10260.txt
# Archivo renombrado: 10261.txt -> 10261.txt
# Archivo renombrado: 10262.txt -> 10262.txt
# Archivo renombrado: 10263.txt -> 10263.txt
# Archivo renombrado: 10264.txt -> 10264.txt
# Archivo renombrado: 10265.txt -> 10265.txt
# Archivo renombrado: 10268.txt -> 10268.txt
# Archivo renombrado: 10272.txt -> 10272.txt
# Archivo renombrado: 10275.txt -> 10275.txt
# Archivo renombrado: 10277.txt -> 10277.txt
# Archivo renombrado: 10280.txt -> 10280.txt
# Archivo renombrado: 10281.txt -> 10281.txt
# Archivo renombrado: 10282.txt -> 10282.txt
# Archivo renombrado: 10283.txt -> 10283.txt
# Archivo renombrado: 10284.txt -> 10284.txt
# Archivo renombrado: 10285.txt -> 10285.txt
# Archivo renombrado: 10289.txt -> 10289.txt
# Archivo renombrado: 1029.txt -> 1029.txt
# Archivo renombrado: 10291.txt -> 10291.txt
# Archivo renombrado: 10292.txt -> 10292.txt
# Archivo renombrado: 10294.txt -> 10294.txt
# Archivo renombrado: 10295.txt -> 10295.txt
# Archivo renombrado: 10297.txt -> 10297.txt
# Archivo renombrado: 10299.txt -> 10299.txt
# Archivo renombrado: 103.txt -> 103.txt
# Archivo renombrado: 1030.txt -> 1030.txt
# Archivo renombrado: 10300.txt -> 10300.txt
# Archivo renombrado: 10302.txt -> 10302.txt
# Archivo renombrado: 10305.txt -> 10305.txt
# Archivo renombrado: 10306.txt -> 10306.txt
# Archivo renombrado: 10308.txt -> 10308.txt
# Archivo renombrado: 10310.txt -> 10310.txt
# Archivo renombrado: 10311.txt -> 10311.txt
# Archivo renombrado: 10313.txt -> 10313.txt
# Archivo renombrado: 10314.txt -> 10314.txt
# Archivo renombrado: 10315.txt -> 10315.txt
# Archivo renombrado: 10318.txt -> 10318.txt
# Archivo renombrado: 10319.txt -> 10319.txt
# Archivo renombrado: 1032.txt -> 1032.txt
# Archivo renombrado: 10321.txt -> 10321.txt
# Archivo renombrado: 10322.txt -> 10322.txt
# Archivo renombrado: 10323.txt -> 10323.txt
# Archivo renombrado: 10324.txt -> 10324.txt
# Archivo renombrado: 10328.txt -> 10328.txt
# Archivo renombrado: 1033.txt -> 1033.txt
# Archivo renombrado: 10330.txt -> 10330.txt
# Archivo renombrado: 10332.txt -> 10332.txt
# Archivo renombrado: 10334.txt -> 10334.txt
# Archivo renombrado: 10335.txt -> 10335.txt
# Archivo renombrado: 10337.txt -> 10337.txt
# Archivo renombrado: 10338.txt -> 10338.txt
# Archivo renombrado: 10339.txt -> 10339.txt
# Archivo renombrado: 10340.txt -> 10340.txt
# Archivo renombrado: 10341.txt -> 10341.txt
# Archivo renombrado: 10342.txt -> 10342.txt
# Archivo renombrado: 10344.txt -> 10344.txt
# Archivo renombrado: 10347.txt -> 10347.txt
# Archivo renombrado: 10348.txt -> 10348.txt
# Archivo renombrado: 10349.txt -> 10349.txt
# Archivo renombrado: 1035.txt -> 1035.txt
# Archivo renombrado: 10352.txt -> 10352.txt
# Archivo renombrado: 10354.txt -> 10354.txt
# Archivo renombrado: 10355.txt -> 10355.txt
# Archivo renombrado: 10356.txt -> 10356.txt
# Archivo renombrado: 10357.txt -> 10357.txt
# Archivo renombrado: 10358.txt -> 10358.txt
# Archivo renombrado: 10359.txt -> 10359.txt
# Archivo renombrado: 1036.txt -> 1036.txt
# Archivo renombrado: 10361.txt -> 10361.txt
# Archivo renombrado: 10362.txt -> 10362.txt
# Archivo renombrado: 10364.txt -> 10364.txt
# Archivo renombrado: 10367.txt -> 10367.txt
# Archivo renombrado: 10368.txt -> 10368.txt
# Archivo renombrado: 10370.txt -> 10370.txt
# Archivo renombrado: 10371.txt -> 10371.txt
# Archivo renombrado: 10372.txt -> 10372.txt
# Archivo renombrado: 10373.txt -> 10373.txt
# Archivo renombrado: 10375.txt -> 10375.txt
# Archivo renombrado: 10376.txt -> 10376.txt
# Archivo renombrado: 10377.txt -> 10377.txt
# Archivo renombrado: 10381.txt -> 10381.txt
# Archivo renombrado: 10382.txt -> 10382.txt
# Archivo renombrado: 10384.txt -> 10384.txt
# Archivo renombrado: 10385.txt -> 10385.txt
# Archivo renombrado: 10387.txt -> 10387.txt
# Archivo renombrado: 10388.txt -> 10388.txt
# Archivo renombrado: 1039.txt -> 1039.txt
# Archivo renombrado: 10390.txt -> 10390.txt
# Archivo renombrado: 10391.txt -> 10391.txt
# Archivo renombrado: 10393.txt -> 10393.txt
# Archivo renombrado: 10394.txt -> 10394.txt
# Archivo renombrado: 10395.txt -> 10395.txt
# Archivo renombrado: 10397.txt -> 10397.txt
# Archivo renombrado: 10398.txt -> 10398.txt
# Archivo renombrado: 10399.txt -> 10399.txt
# Archivo renombrado: 104.txt -> 104.txt
# Archivo renombrado: 1040.txt -> 1040.txt
# Archivo renombrado: 10401.txt -> 10401.txt
# Archivo renombrado: 10402.txt -> 10402.txt
# Archivo renombrado: 10403.txt -> 10403.txt
# Archivo renombrado: 10404.txt -> 10404.txt
# Archivo renombrado: 10406.txt -> 10406.txt
# Archivo renombrado: 10411.txt -> 10411.txt
# Archivo renombrado: 10412.txt -> 10412.txt
# Archivo renombrado: 10414.txt -> 10414.txt
# Archivo renombrado: 10416.txt -> 10416.txt
# Archivo renombrado: 10418.txt -> 10418.txt
# Archivo renombrado: 10419.txt -> 10419.txt
# Archivo renombrado: 10423.txt -> 10423.txt
# Archivo renombrado: 10427.txt -> 10427.txt
# Archivo renombrado: 10429.txt -> 10429.txt
# Archivo renombrado: 10430.txt -> 10430.txt
# Archivo renombrado: 10431.txt -> 10431.txt
# Archivo renombrado: 10432.txt -> 10432.txt
# Archivo renombrado: 10434.txt -> 10434.txt
# Archivo renombrado: 10435.txt -> 10435.txt
# Archivo renombrado: 10436.txt -> 10436.txt
# Archivo renombrado: 10439.txt -> 10439.txt
# Archivo renombrado: 1044.txt -> 1044.txt
# Archivo renombrado: 10440.txt -> 10440.txt
# Archivo renombrado: 10442.txt -> 10442.txt
# Archivo renombrado: 10444.txt -> 10444.txt
# Archivo renombrado: 10445.txt -> 10445.txt
# Archivo renombrado: 10446.txt -> 10446.txt
# Archivo renombrado: 10447.txt -> 10447.txt
# Archivo renombrado: 10449.txt -> 10449.txt
# Archivo renombrado: 10452.txt -> 10452.txt
# Archivo renombrado: 10453.txt -> 10453.txt
# Archivo renombrado: 10454.txt -> 10454.txt
# Archivo renombrado: 10455.txt -> 10455.txt
# Archivo renombrado: 10458.txt -> 10458.txt
# Archivo renombrado: 10459.txt -> 10459.txt
# Archivo renombrado: 10462.txt -> 10462.txt
# Archivo renombrado: 10464.txt -> 10464.txt
# Archivo renombrado: 10467.txt -> 10467.txt
# Archivo renombrado: 1047.txt -> 1047.txt
# Archivo renombrado: 10470.txt -> 10470.txt
# Archivo renombrado: 10471.txt -> 10471.txt
# Archivo renombrado: 10472.txt -> 10472.txt
# Archivo renombrado: 10473.txt -> 10473.txt
# Archivo renombrado: 10475.txt -> 10475.txt
# Archivo renombrado: 10478.txt -> 10478.txt
# Archivo renombrado: 10484.txt -> 10484.txt
# Archivo renombrado: 10485.txt -> 10485.txt
# Archivo renombrado: 10487.txt -> 10487.txt
# Archivo renombrado: 10489.txt -> 10489.txt
# Archivo renombrado: 1049.txt -> 1049.txt
# Archivo renombrado: 10491.txt -> 10491.txt
# Archivo renombrado: 10494.txt -> 10494.txt
# Archivo renombrado: 10498.txt -> 10498.txt
# Archivo renombrado: 10499.txt -> 10499.txt
# Archivo renombrado: 105.txt -> 105.txt
# Archivo renombrado: 1050.txt -> 1050.txt
# Archivo renombrado: 10500.txt -> 10500.txt
# Archivo renombrado: 10503.txt -> 10503.txt
# Archivo renombrado: 10505.txt -> 10505.txt
# Archivo renombrado: 10506.txt -> 10506.txt
# Archivo renombrado: 10508.txt -> 10508.txt
# Archivo renombrado: 10509.txt -> 10509.txt
# Archivo renombrado: 10515.txt -> 10515.txt
# Archivo renombrado: 10518.txt -> 10518.txt
# Archivo renombrado: 10519.txt -> 10519.txt
# Archivo renombrado: 1052.txt -> 1052.txt
# Archivo renombrado: 10520.txt -> 10520.txt
# Archivo renombrado: 10521.txt -> 10521.txt
# Archivo renombrado: 10524.txt -> 10524.txt
# Archivo renombrado: 10527.txt -> 10527.txt
# Archivo renombrado: 10529.txt -> 10529.txt
# Archivo renombrado: 10530.txt -> 10530.txt
# Archivo renombrado: 10531.txt -> 10531.txt
# Archivo renombrado: 10532.txt -> 10532.txt
# Archivo renombrado: 10534.txt -> 10534.txt
# Archivo renombrado: 10536.txt -> 10536.txt
# Archivo renombrado: 10537.txt -> 10537.txt
# Archivo renombrado: 10538.txt -> 10538.txt
# Archivo renombrado: 10539.txt -> 10539.txt
# Archivo renombrado: 10541.txt -> 10541.txt
# Archivo renombrado: 10542.txt -> 10542.txt
# Archivo renombrado: 10544.txt -> 10544.txt
# Archivo renombrado: 10545.txt -> 10545.txt
# Archivo renombrado: 10546.txt -> 10546.txt
# Archivo renombrado: 10547.txt -> 10547.txt
# Archivo renombrado: 10548.txt -> 10548.txt
# Archivo renombrado: 10551.txt -> 10551.txt
# Archivo renombrado: 10553.txt -> 10553.txt
# Archivo renombrado: 10555.txt -> 10555.txt
# Archivo renombrado: 10556.txt -> 10556.txt
# Archivo renombrado: 10559.txt -> 10559.txt
# Archivo renombrado: 10561.txt -> 10561.txt
# Archivo renombrado: 10563.txt -> 10563.txt
# Archivo renombrado: 10564.txt -> 10564.txt
# Archivo renombrado: 10565.txt -> 10565.txt
# Archivo renombrado: 10566.txt -> 10566.txt
# Archivo renombrado: 10567.txt -> 10567.txt
# Archivo renombrado: 10569.txt -> 10569.txt
# Archivo renombrado: 1057.txt -> 1057.txt
# Archivo renombrado: 10573.txt -> 10573.txt
# Archivo renombrado: 10576.txt -> 10576.txt
# Archivo renombrado: 1058.txt -> 1058.txt
# Archivo renombrado: 10581.txt -> 10581.txt
# Archivo renombrado: 10582.txt -> 10582.txt
# Archivo renombrado: 10584.txt -> 10584.txt
# Archivo renombrado: 10585.txt -> 10585.txt
# Archivo renombrado: 10586.txt -> 10586.txt
# Archivo renombrado: 10587.txt -> 10587.txt
# Archivo renombrado: 10588.txt -> 10588.txt
# Archivo renombrado: 1059.txt -> 1059.txt
# Archivo renombrado: 10590.txt -> 10590.txt
# Archivo renombrado: 10592.txt -> 10592.txt
# Archivo renombrado: 10593.txt -> 10593.txt
# Archivo renombrado: 10594.txt -> 10594.txt
# Archivo renombrado: 10596.txt -> 10596.txt
# Archivo renombrado: 10597.txt -> 10597.txt
# Archivo renombrado: 10598.txt -> 10598.txt
# Archivo renombrado: 10599.txt -> 10599.txt
# Archivo renombrado: 106.txt -> 106.txt
# Archivo renombrado: 10600.txt -> 10600.txt
# Archivo renombrado: 10601.txt -> 10601.txt
# Archivo renombrado: 10602.txt -> 10602.txt
# Archivo renombrado: 10604.txt -> 10604.txt
# Archivo renombrado: 10606.txt -> 10606.txt
# Archivo renombrado: 10608.txt -> 10608.txt
# Archivo renombrado: 10609.txt -> 10609.txt
# Archivo renombrado: 10610.txt -> 10610.txt
# Archivo renombrado: 10611.txt -> 10611.txt
# Archivo renombrado: 10612.txt -> 10612.txt
# Archivo renombrado: 10613.txt -> 10613.txt
# Archivo renombrado: 10615.txt -> 10615.txt
# Archivo renombrado: 10616.txt -> 10616.txt
# Archivo renombrado: 10617.txt -> 10617.txt
# Archivo renombrado: 10618.txt -> 10618.txt
# Archivo renombrado: 10619.txt -> 10619.txt
# Archivo renombrado: 10620.txt -> 10620.txt
# Archivo renombrado: 10621.txt -> 10621.txt
# Archivo renombrado: 10622.txt -> 10622.txt
# Archivo renombrado: 10623.txt -> 10623.txt
# Archivo renombrado: 10625.txt -> 10625.txt
# Archivo renombrado: 10627.txt -> 10627.txt
# Archivo renombrado: 1063.txt -> 1063.txt
# Archivo renombrado: 10632.txt -> 10632.txt
# Archivo renombrado: 10633.txt -> 10633.txt
# Archivo renombrado: 10634.txt -> 10634.txt
# Archivo renombrado: 10636.txt -> 10636.txt
# Archivo renombrado: 10638.txt -> 10638.txt
# Archivo renombrado: 10640.txt -> 10640.txt
# Archivo renombrado: 10641.txt -> 10641.txt
# Archivo renombrado: 10642.txt -> 10642.txt
# Archivo renombrado: 10643.txt -> 10643.txt
# Archivo renombrado: 10644.txt -> 10644.txt
# Archivo renombrado: 10648.txt -> 10648.txt
# Archivo renombrado: 1065.txt -> 1065.txt
# Archivo renombrado: 10650.txt -> 10650.txt
# Archivo renombrado: 10651.txt -> 10651.txt
# Archivo renombrado: 10652.txt -> 10652.txt
# Archivo renombrado: 10653.txt -> 10653.txt
# Archivo renombrado: 10654.txt -> 10654.txt
# Archivo renombrado: 10657.txt -> 10657.txt
# Archivo renombrado: 10658.txt -> 10658.txt
# Archivo renombrado: 10659.txt -> 10659.txt
# Archivo renombrado: 1066.txt -> 1066.txt
# Archivo renombrado: 10660.txt -> 10660.txt
# Archivo renombrado: 10661.txt -> 10661.txt
# Archivo renombrado: 10662.txt -> 10662.txt
# Archivo renombrado: 10665.txt -> 10665.txt
# Archivo renombrado: 10669.txt -> 10669.txt
# Archivo renombrado: 1067.txt -> 1067.txt
# Archivo renombrado: 10674.txt -> 10674.txt
# Archivo renombrado: 10676.txt -> 10676.txt
# Archivo renombrado: 10678.txt -> 10678.txt
# Archivo renombrado: 10679.txt -> 10679.txt
# Archivo renombrado: 1068.txt -> 1068.txt
# Archivo renombrado: 10681.txt -> 10681.txt
# Archivo renombrado: 10682.txt -> 10682.txt
# Archivo renombrado: 10684.txt -> 10684.txt
# Archivo renombrado: 10685.txt -> 10685.txt
# Archivo renombrado: 10687.txt -> 10687.txt
# Archivo renombrado: 10688.txt -> 10688.txt
# Archivo renombrado: 10689.txt -> 10689.txt
# Archivo renombrado: 1069.txt -> 1069.txt
# Archivo renombrado: 10692.txt -> 10692.txt
# Archivo renombrado: 10693.txt -> 10693.txt
# Archivo renombrado: 10694.txt -> 10694.txt
# Archivo renombrado: 10695.txt -> 10695.txt
# Archivo renombrado: 10696.txt -> 10696.txt
# Archivo renombrado: 10699.txt -> 10699.txt
# Archivo renombrado: 1070.txt -> 1070.txt
# Archivo renombrado: 10701.txt -> 10701.txt
# Archivo renombrado: 10702.txt -> 10702.txt
# Archivo renombrado: 10703.txt -> 10703.txt
# Archivo renombrado: 10704.txt -> 10704.txt
# Archivo renombrado: 10705.txt -> 10705.txt
# Archivo renombrado: 10708.txt -> 10708.txt
# Archivo renombrado: 10709.txt -> 10709.txt
# Archivo renombrado: 1071.txt -> 1071.txt
# Archivo renombrado: 10710.txt -> 10710.txt
# Archivo renombrado: 10712.txt -> 10712.txt
# Archivo renombrado: 10714.txt -> 10714.txt
# Archivo renombrado: 10715.txt -> 10715.txt
# Archivo renombrado: 10717.txt -> 10717.txt
# Archivo renombrado: 10718.txt -> 10718.txt
# Archivo renombrado: 1072.txt -> 1072.txt
# Archivo renombrado: 10720.txt -> 10720.txt
# Archivo renombrado: 10721.txt -> 10721.txt
# Archivo renombrado: 10724.txt -> 10724.txt
# Archivo renombrado: 10729.txt -> 10729.txt
# Archivo renombrado: 10731.txt -> 10731.txt
# Archivo renombrado: 10734.txt -> 10734.txt
# Archivo renombrado: 10736.txt -> 10736.txt
# Archivo renombrado: 10737.txt -> 10737.txt
# Archivo renombrado: 10738.txt -> 10738.txt
# Archivo renombrado: 1074.txt -> 1074.txt
# Archivo renombrado: 10742.txt -> 10742.txt
# Archivo renombrado: 10743.txt -> 10743.txt
# Archivo renombrado: 10744.txt -> 10744.txt
# Archivo renombrado: 10746.txt -> 10746.txt
# Archivo renombrado: 10748.txt -> 10748.txt
# Archivo renombrado: 10749.txt -> 10749.txt
# Archivo renombrado: 10750.txt -> 10750.txt
# Archivo renombrado: 10751.txt -> 10751.txt
# Archivo renombrado: 10752.txt -> 10752.txt
# Archivo renombrado: 10754.txt -> 10754.txt
# Archivo renombrado: 10755.txt -> 10755.txt
# Archivo renombrado: 10756.txt -> 10756.txt
# Archivo renombrado: 10757.txt -> 10757.txt
# Archivo renombrado: 10758.txt -> 10758.txt
# Archivo renombrado: 1076.txt -> 1076.txt
# Archivo renombrado: 10760.txt -> 10760.txt
# Archivo renombrado: 10762.txt -> 10762.txt
# Archivo renombrado: 10766.txt -> 10766.txt
# Archivo renombrado: 10767.txt -> 10767.txt
# Archivo renombrado: 10768.txt -> 10768.txt
# Archivo renombrado: 10769.txt -> 10769.txt
# Archivo renombrado: 1077.txt -> 1077.txt
# Archivo renombrado: 10770.txt -> 10770.txt
# Archivo renombrado: 10771.txt -> 10771.txt
# Archivo renombrado: 10773.txt -> 10773.txt
# Archivo renombrado: 10774.txt -> 10774.txt
# Archivo renombrado: 10779.txt -> 10779.txt
# Archivo renombrado: 1078.txt -> 1078.txt
# Archivo renombrado: 10780.txt -> 10780.txt
# Archivo renombrado: 10781.txt -> 10781.txt
# Archivo renombrado: 10782.txt -> 10782.txt
# Archivo renombrado: 10784.txt -> 10784.txt
# Archivo renombrado: 10786.txt -> 10786.txt
# Archivo renombrado: 10787.txt -> 10787.txt
# Archivo renombrado: 10788.txt -> 10788.txt
# Archivo renombrado: 1079.txt -> 1079.txt
# Archivo renombrado: 10790.txt -> 10790.txt
# Archivo renombrado: 10794.txt -> 10794.txt
# Archivo renombrado: 10796.txt -> 10796.txt
# Archivo renombrado: 10797.txt -> 10797.txt
# Archivo renombrado: 108.txt -> 108.txt
# Archivo renombrado: 1080.txt -> 1080.txt
# Archivo renombrado: 10803.txt -> 10803.txt
# Archivo renombrado: 10804.txt -> 10804.txt
# Archivo renombrado: 10805.txt -> 10805.txt
# Archivo renombrado: 10807.txt -> 10807.txt
# Archivo renombrado: 10808.txt -> 10808.txt
# Archivo renombrado: 10809.txt -> 10809.txt
# Archivo renombrado: 10811.txt -> 10811.txt
# Archivo renombrado: 10815.txt -> 10815.txt
# Archivo renombrado: 10816.txt -> 10816.txt
# Archivo renombrado: 10817.txt -> 10817.txt
# Archivo renombrado: 1082.txt -> 1082.txt
# Archivo renombrado: 10822.txt -> 10822.txt
# Archivo renombrado: 10825.txt -> 10825.txt
# Archivo renombrado: 10826.txt -> 10826.txt
# Archivo renombrado: 10827.txt -> 10827.txt
# Archivo renombrado: 10830.txt -> 10830.txt
# Archivo renombrado: 10831.txt -> 10831.txt
# Archivo renombrado: 10832.txt -> 10832.txt
# Archivo renombrado: 10833.txt -> 10833.txt
# Archivo renombrado: 10834.txt -> 10834.txt
# Archivo renombrado: 10839.txt -> 10839.txt
# Archivo renombrado: 1084.txt -> 1084.txt
# Archivo renombrado: 10840.txt -> 10840.txt
# Archivo renombrado: 10841.txt -> 10841.txt
# Archivo renombrado: 10843.txt -> 10843.txt
# Archivo renombrado: 10844.txt -> 10844.txt
# Archivo renombrado: 10845.txt -> 10845.txt
# Archivo renombrado: 10847.txt -> 10847.txt
# Archivo renombrado: 10848.txt -> 10848.txt
# Archivo renombrado: 10849.txt -> 10849.txt
# Archivo renombrado: 1085.txt -> 1085.txt
# Archivo renombrado: 10851.txt -> 10851.txt
# Archivo renombrado: 10853.txt -> 10853.txt
# Archivo renombrado: 10855.txt -> 10855.txt
# Archivo renombrado: 10856.txt -> 10856.txt
# Archivo renombrado: 10857.txt -> 10857.txt
# Archivo renombrado: 10859.txt -> 10859.txt
# Archivo renombrado: 10860.txt -> 10860.txt
# Archivo renombrado: 10864.txt -> 10864.txt
# Archivo renombrado: 10867.txt -> 10867.txt
# Archivo renombrado: 10868.txt -> 10868.txt
# Archivo renombrado: 1087.txt -> 1087.txt
# Archivo renombrado: 10870.txt -> 10870.txt
# Archivo renombrado: 10871.txt -> 10871.txt
# Archivo renombrado: 10872.txt -> 10872.txt
# Archivo renombrado: 10873.txt -> 10873.txt
# Archivo renombrado: 10874.txt -> 10874.txt
# Archivo renombrado: 10876.txt -> 10876.txt
# Archivo renombrado: 10877.txt -> 10877.txt
# Archivo renombrado: 10879.txt -> 10879.txt
# Archivo renombrado: 1088.txt -> 1088.txt
# Archivo renombrado: 10882.txt -> 10882.txt
# Archivo renombrado: 10883.txt -> 10883.txt
# Archivo renombrado: 10884.txt -> 10884.txt
# Archivo renombrado: 10885.txt -> 10885.txt
# Archivo renombrado: 10886.txt -> 10886.txt
# Archivo renombrado: 10887.txt -> 10887.txt
# Archivo renombrado: 10891.txt -> 10891.txt
# Archivo renombrado: 10892.txt -> 10892.txt
# Archivo renombrado: 10893.txt -> 10893.txt
# Archivo renombrado: 10894.txt -> 10894.txt
# Archivo renombrado: 10895.txt -> 10895.txt
# Archivo renombrado: 10897.txt -> 10897.txt
# Archivo renombrado: 10899.txt -> 10899.txt
# Archivo renombrado: 109.txt -> 109.txt
# Archivo renombrado: 1090.txt -> 1090.txt
# Archivo renombrado: 10901.txt -> 10901.txt
# Archivo renombrado: 10902.txt -> 10902.txt
# Archivo renombrado: 10903.txt -> 10903.txt
# Archivo renombrado: 10904.txt -> 10904.txt
# Archivo renombrado: 10905.txt -> 10905.txt
# Archivo renombrado: 10907.txt -> 10907.txt
# Archivo renombrado: 10908.txt -> 10908.txt
# Archivo renombrado: 10909.txt -> 10909.txt
# Archivo renombrado: 1091.txt -> 1091.txt
# Archivo renombrado: 10913.txt -> 10913.txt
# Archivo renombrado: 10917.txt -> 10917.txt
# Archivo renombrado: 10918.txt -> 10918.txt
# Archivo renombrado: 10919.txt -> 10919.txt
# Archivo renombrado: 10921.txt -> 10921.txt
# Archivo renombrado: 10922.txt -> 10922.txt
# Archivo renombrado: 10923.txt -> 10923.txt
# Archivo renombrado: 10924.txt -> 10924.txt
# Archivo renombrado: 10925.txt -> 10925.txt
# Archivo renombrado: 10926.txt -> 10926.txt
# Archivo renombrado: 10928.txt -> 10928.txt
# Archivo renombrado: 10931.txt -> 10931.txt
# Archivo renombrado: 1094.txt -> 1094.txt
# Archivo renombrado: 10941.txt -> 10941.txt
# Archivo renombrado: 10943.txt -> 10943.txt
# Archivo renombrado: 10944.txt -> 10944.txt
# Archivo renombrado: 10946.txt -> 10946.txt
# Archivo renombrado: 10947.txt -> 10947.txt
# Archivo renombrado: 10950.txt -> 10950.txt
# Archivo renombrado: 10956.txt -> 10956.txt
# Archivo renombrado: 10959.txt -> 10959.txt
# Archivo renombrado: 1096.txt -> 1096.txt
# Archivo renombrado: 10960.txt -> 10960.txt
# Archivo renombrado: 10961.txt -> 10961.txt
# Archivo renombrado: 10962.txt -> 10962.txt
# Archivo renombrado: 10963.txt -> 10963.txt
# Archivo renombrado: 10964.txt -> 10964.txt
# Archivo renombrado: 10966.txt -> 10966.txt
# Archivo renombrado: 10969.txt -> 10969.txt
# Archivo renombrado: 10971.txt -> 10971.txt
# Archivo renombrado: 10972.txt -> 10972.txt
# Archivo renombrado: 10973.txt -> 10973.txt
# Archivo renombrado: 10974.txt -> 10974.txt
# Archivo renombrado: 10978.txt -> 10978.txt
# Archivo renombrado: 10980.txt -> 10980.txt
# Archivo renombrado: 10983.txt -> 10983.txt
# Archivo renombrado: 10985.txt -> 10985.txt
# Archivo renombrado: 10988.txt -> 10988.txt
# Archivo renombrado: 10989.txt -> 10989.txt
# Archivo renombrado: 1099.txt -> 1099.txt
# Archivo renombrado: 10992.txt -> 10992.txt
# Archivo renombrado: 10994.txt -> 10994.txt
# Archivo renombrado: 10998.txt -> 10998.txt
# Archivo renombrado: 10999.txt -> 10999.txt
# Archivo renombrado: 11.txt -> 11.txt
# Archivo renombrado: 110.txt -> 110.txt
# Archivo renombrado: 1100.txt -> 1100.txt
# Archivo renombrado: 11000.txt -> 11000.txt
# Archivo renombrado: 11006.txt -> 11006.txt
# Archivo renombrado: 11007.txt -> 11007.txt
# Archivo renombrado: 1101.txt -> 1101.txt
# Archivo renombrado: 11012.txt -> 11012.txt
# Archivo renombrado: 11015.txt -> 11015.txt
# Archivo renombrado: 11018.txt -> 11018.txt
# Archivo renombrado: 11019.txt -> 11019.txt
# Archivo renombrado: 1102.txt -> 1102.txt
# Archivo renombrado: 11025.txt -> 11025.txt
# Archivo renombrado: 11027.txt -> 11027.txt
# Archivo renombrado: 11028.txt -> 11028.txt
# Archivo renombrado: 11029.txt -> 11029.txt
# Archivo renombrado: 1103.txt -> 1103.txt
# Archivo renombrado: 11030.txt -> 11030.txt
# Archivo renombrado: 11031.txt -> 11031.txt
# Archivo renombrado: 11034.txt -> 11034.txt
# Archivo renombrado: 11035.txt -> 11035.txt
# Archivo renombrado: 11036.txt -> 11036.txt
# Archivo renombrado: 11039.txt -> 11039.txt
# Archivo renombrado: 1104.txt -> 1104.txt
# Archivo renombrado: 11040.txt -> 11040.txt
# Archivo renombrado: 11041.txt -> 11041.txt
# Archivo renombrado: 11043.txt -> 11043.txt
# Archivo renombrado: 11046.txt -> 11046.txt
# Archivo renombrado: 11047.txt -> 11047.txt
# Archivo renombrado: 11048.txt -> 11048.txt
# Archivo renombrado: 11049.txt -> 11049.txt
# Archivo renombrado: 1105.txt -> 1105.txt
# Archivo renombrado: 11051.txt -> 11051.txt
# Archivo renombrado: 11052.txt -> 11052.txt
# Archivo renombrado: 11056.txt -> 11056.txt
# Archivo renombrado: 11057.txt -> 11057.txt
# Archivo renombrado: 11058.txt -> 11058.txt
# Archivo renombrado: 11059.txt -> 11059.txt
# Archivo renombrado: 11060.txt -> 11060.txt
# Archivo renombrado: 11063.txt -> 11063.txt
# Archivo renombrado: 11064.txt -> 11064.txt
# Archivo renombrado: 11065.txt -> 11065.txt
# Archivo renombrado: 11066.txt -> 11066.txt
# Archivo renombrado: 11070.txt -> 11070.txt
# Archivo renombrado: 11071.txt -> 11071.txt
# Archivo renombrado: 11074.txt -> 11074.txt
# Archivo renombrado: 11076.txt -> 11076.txt
# Archivo renombrado: 11078.txt -> 11078.txt
# Archivo renombrado: 1108.txt -> 1108.txt
# Archivo renombrado: 11083.txt -> 11083.txt
# Archivo renombrado: 11085.txt -> 11085.txt
# Archivo renombrado: 11086.txt -> 11086.txt
# Archivo renombrado: 11087.txt -> 11087.txt
# Archivo renombrado: 11088.txt -> 11088.txt
# Archivo renombrado: 1109.txt -> 1109.txt
# Archivo renombrado: 11090.txt -> 11090.txt
# Archivo renombrado: 11091.txt -> 11091.txt
# Archivo renombrado: 11093.txt -> 11093.txt
# Archivo renombrado: 11095.txt -> 11095.txt
# Archivo renombrado: 11098.txt -> 11098.txt
# Archivo renombrado: 111.txt -> 111.txt
# Archivo renombrado: 1110.txt -> 1110.txt
# Archivo renombrado: 11100.txt -> 11100.txt
# Archivo renombrado: 11101.txt -> 11101.txt
# Archivo renombrado: 11102.txt -> 11102.txt
# Archivo renombrado: 11103.txt -> 11103.txt
# Archivo renombrado: 11104.txt -> 11104.txt
# Archivo renombrado: 11105.txt -> 11105.txt
# Archivo renombrado: 11106.txt -> 11106.txt
# Archivo renombrado: 11107.txt -> 11107.txt
# Archivo renombrado: 11109.txt -> 11109.txt
# Archivo renombrado: 1111.txt -> 1111.txt
# Archivo renombrado: 11111.txt -> 11111.txt
# Archivo renombrado: 11112.txt -> 11112.txt
# Archivo renombrado: 11113.txt -> 11113.txt
# Archivo renombrado: 11115.txt -> 11115.txt
# Archivo renombrado: 11118.txt -> 11118.txt
# Archivo renombrado: 11119.txt -> 11119.txt
# Archivo renombrado: 1112.txt -> 1112.txt
# Archivo renombrado: 11120.txt -> 11120.txt
# Archivo renombrado: 11121.txt -> 11121.txt
# Archivo renombrado: 11123.txt -> 11123.txt
# Archivo renombrado: 11124.txt -> 11124.txt
# Archivo renombrado: 11126.txt -> 11126.txt
# Archivo renombrado: 11127.txt -> 11127.txt
# Archivo renombrado: 11128.txt -> 11128.txt
# Archivo renombrado: 11132.txt -> 11132.txt
# Archivo renombrado: 11133.txt -> 11133.txt
# Archivo renombrado: 11134.txt -> 11134.txt
# Archivo renombrado: 11135.txt -> 11135.txt
# Archivo renombrado: 11136.txt -> 11136.txt
# Archivo renombrado: 11137.txt -> 11137.txt
# Archivo renombrado: 11139.txt -> 11139.txt
# Archivo renombrado: 11143.txt -> 11143.txt
# Archivo renombrado: 11144.txt -> 11144.txt
# Archivo renombrado: 11145.txt -> 11145.txt
# Archivo renombrado: 11149.txt -> 11149.txt
# Archivo renombrado: 11153.txt -> 11153.txt
# Archivo renombrado: 11154.txt -> 11154.txt
# Archivo renombrado: 11156.txt -> 11156.txt
# Archivo renombrado: 11158.txt -> 11158.txt
# Archivo renombrado: 11159.txt -> 11159.txt
# Archivo renombrado: 11160.txt -> 11160.txt
# Archivo renombrado: 11161.txt -> 11161.txt
# Archivo renombrado: 11162.txt -> 11162.txt
# Archivo renombrado: 11163.txt -> 11163.txt
# Archivo renombrado: 11164.txt -> 11164.txt
# Archivo renombrado: 11166.txt -> 11166.txt
# Archivo renombrado: 11168.txt -> 11168.txt
# Archivo renombrado: 1117.txt -> 1117.txt
# Archivo renombrado: 11170.txt -> 11170.txt
# Archivo renombrado: 11171.txt -> 11171.txt
# Archivo renombrado: 11173.txt -> 11173.txt
# Archivo renombrado: 11174.txt -> 11174.txt
# Archivo renombrado: 11175.txt -> 11175.txt
# Archivo renombrado: 11177.txt -> 11177.txt
# Archivo renombrado: 11179.txt -> 11179.txt
# Archivo renombrado: 1118.txt -> 1118.txt
# Archivo renombrado: 11181.txt -> 11181.txt
# Archivo renombrado: 11183.txt -> 11183.txt
# Archivo renombrado: 11185.txt -> 11185.txt
# Archivo renombrado: 11190.txt -> 11190.txt
# Archivo renombrado: 11191.txt -> 11191.txt
# Archivo renombrado: 11192.txt -> 11192.txt
# Archivo renombrado: 11193.txt -> 11193.txt
# Archivo renombrado: 11196.txt -> 11196.txt
# Archivo renombrado: 11197.txt -> 11197.txt
# Archivo renombrado: 11198.txt -> 11198.txt
# Archivo renombrado: 1120.txt -> 1120.txt
# Archivo renombrado: 11200.txt -> 11200.txt
# Archivo renombrado: 11201.txt -> 11201.txt
# Archivo renombrado: 11202.txt -> 11202.txt
# Archivo renombrado: 11203.txt -> 11203.txt
# Archivo renombrado: 11205.txt -> 11205.txt
# Archivo renombrado: 11208.txt -> 11208.txt
# Archivo renombrado: 11209.txt -> 11209.txt
# Archivo renombrado: 11210.txt -> 11210.txt
# Archivo renombrado: 11211.txt -> 11211.txt
# Archivo renombrado: 11212.txt -> 11212.txt
# Archivo renombrado: 11213.txt -> 11213.txt
# Archivo renombrado: 11216.txt -> 11216.txt
# Archivo renombrado: 1122.txt -> 1122.txt
# Archivo renombrado: 11220.txt -> 11220.txt
# Archivo renombrado: 11221.txt -> 11221.txt
# Archivo renombrado: 11222.txt -> 11222.txt
# Archivo renombrado: 11224.txt -> 11224.txt
# Archivo renombrado: 11225.txt -> 11225.txt
# Archivo renombrado: 11227.txt -> 11227.txt
# Archivo renombrado: 11228.txt -> 11228.txt
# Archivo renombrado: 11229.txt -> 11229.txt
# Archivo renombrado: 1123.txt -> 1123.txt
# Archivo renombrado: 11230.txt -> 11230.txt
# Archivo renombrado: 11231.txt -> 11231.txt
# Archivo renombrado: 11232.txt -> 11232.txt
# Archivo renombrado: 11233.txt -> 11233.txt
# Archivo renombrado: 11234.txt -> 11234.txt
# Archivo renombrado: 11236.txt -> 11236.txt
# Archivo renombrado: 11237.txt -> 11237.txt
# Archivo renombrado: 11238.txt -> 11238.txt
# Archivo renombrado: 11239.txt -> 11239.txt
# Archivo renombrado: 1124.txt -> 1124.txt
# Archivo renombrado: 11241.txt -> 11241.txt
# Archivo renombrado: 11242.txt -> 11242.txt
# Archivo renombrado: 11243.txt -> 11243.txt
# Archivo renombrado: 11244.txt -> 11244.txt
# Archivo renombrado: 11249.txt -> 11249.txt
# Archivo renombrado: 1125.txt -> 1125.txt
# Archivo renombrado: 11251.txt -> 11251.txt
# Archivo renombrado: 11252.txt -> 11252.txt
# Archivo renombrado: 11253.txt -> 11253.txt
# Archivo renombrado: 11254.txt -> 11254.txt
# Archivo renombrado: 11255.txt -> 11255.txt
# Archivo renombrado: 11256.txt -> 11256.txt
# Archivo renombrado: 11257.txt -> 11257.txt
# Archivo renombrado: 11259.txt -> 11259.txt
# Archivo renombrado: 11260.txt -> 11260.txt
# Archivo renombrado: 11261.txt -> 11261.txt
# Archivo renombrado: 11263.txt -> 11263.txt
# Archivo renombrado: 11265.txt -> 11265.txt
# Archivo renombrado: 11268.txt -> 11268.txt
# Archivo renombrado: 11269.txt -> 11269.txt
# Archivo renombrado: 11270.txt -> 11270.txt
# Archivo renombrado: 11271.txt -> 11271.txt
# Archivo renombrado: 11272.txt -> 11272.txt
# Archivo renombrado: 11273.txt -> 11273.txt
# Archivo renombrado: 11274.txt -> 11274.txt
# Archivo renombrado: 11276.txt -> 11276.txt
# Archivo renombrado: 11277.txt -> 11277.txt
# Archivo renombrado: 11278.txt -> 11278.txt
# Archivo renombrado: 11279.txt -> 11279.txt
# Archivo renombrado: 1128.txt -> 1128.txt
# Archivo renombrado: 11281.txt -> 11281.txt
# Archivo renombrado: 11282.txt -> 11282.txt
# Archivo renombrado: 11283.txt -> 11283.txt
# Archivo renombrado: 11284.txt -> 11284.txt
# Archivo renombrado: 11285.txt -> 11285.txt
# Archivo renombrado: 11287.txt -> 11287.txt
# Archivo renombrado: 11289.txt -> 11289.txt
# Archivo renombrado: 11291.txt -> 11291.txt
# Archivo renombrado: 11292.txt -> 11292.txt
# Archivo renombrado: 11295.txt -> 11295.txt
# Archivo renombrado: 11297.txt -> 11297.txt
# Archivo renombrado: 11299.txt -> 11299.txt
# Archivo renombrado: 113.txt -> 113.txt
# Archivo renombrado: 11300.txt -> 11300.txt
# Archivo renombrado: 11301.txt -> 11301.txt
# Archivo renombrado: 11302.txt -> 11302.txt
# Archivo renombrado: 11305.txt -> 11305.txt
# Archivo renombrado: 11306.txt -> 11306.txt
# Archivo renombrado: 11307.txt -> 11307.txt
# Archivo renombrado: 11308.txt -> 11308.txt
# Archivo renombrado: 1131.txt -> 1131.txt
# Archivo renombrado: 11314.txt -> 11314.txt
# Archivo renombrado: 11315.txt -> 11315.txt
# Archivo renombrado: 11316.txt -> 11316.txt
# Archivo renombrado: 11317.txt -> 11317.txt
# Archivo renombrado: 11320.txt -> 11320.txt
# Archivo renombrado: 11322.txt -> 11322.txt
# Archivo renombrado: 11324.txt -> 11324.txt
# Archivo renombrado: 11327.txt -> 11327.txt
# Archivo renombrado: 11330.txt -> 11330.txt
# Archivo renombrado: 11333.txt -> 11333.txt
# Archivo renombrado: 11335.txt -> 11335.txt
# Archivo renombrado: 11336.txt -> 11336.txt
# Archivo renombrado: 11338.txt -> 11338.txt
# Archivo renombrado: 1134.txt -> 1134.txt
# Archivo renombrado: 11340.txt -> 11340.txt
# Archivo renombrado: 11341.txt -> 11341.txt
# Archivo renombrado: 11343.txt -> 11343.txt
# Archivo renombrado: 11344.txt -> 11344.txt
# Archivo renombrado: 11348.txt -> 11348.txt
# Archivo renombrado: 11349.txt -> 11349.txt
# Archivo renombrado: 1135.txt -> 1135.txt
# Archivo renombrado: 11350.txt -> 11350.txt
# Archivo renombrado: 11352.txt -> 11352.txt
# Archivo renombrado: 11354.txt -> 11354.txt
# Archivo renombrado: 11356.txt -> 11356.txt
# Archivo renombrado: 11357.txt -> 11357.txt
# Archivo renombrado: 11358.txt -> 11358.txt
# Archivo renombrado: 11359.txt -> 11359.txt
# Archivo renombrado: 11362.txt -> 11362.txt
# Archivo renombrado: 11365.txt -> 11365.txt
# Archivo renombrado: 11369.txt -> 11369.txt
# Archivo renombrado: 1137.txt -> 1137.txt
# Archivo renombrado: 11370.txt -> 11370.txt
# Archivo renombrado: 11371.txt -> 11371.txt
# Archivo renombrado: 11372.txt -> 11372.txt
# Archivo renombrado: 11373.txt -> 11373.txt
# Archivo renombrado: 11374.txt -> 11374.txt
# Archivo renombrado: 11377.txt -> 11377.txt
# Archivo renombrado: 11378.txt -> 11378.txt
# Archivo renombrado: 11379.txt -> 11379.txt
# Archivo renombrado: 1138.txt -> 1138.txt
# Archivo renombrado: 11380.txt -> 11380.txt
# Archivo renombrado: 11381.txt -> 11381.txt
# Archivo renombrado: 11384.txt -> 11384.txt
# Archivo renombrado: 11385.txt -> 11385.txt
# Archivo renombrado: 11386.txt -> 11386.txt
# Archivo renombrado: 11387.txt -> 11387.txt
# Archivo renombrado: 11388.txt -> 11388.txt
# Archivo renombrado: 11390.txt -> 11390.txt
# Archivo renombrado: 11392.txt -> 11392.txt
# Archivo renombrado: 11393.txt -> 11393.txt
# Archivo renombrado: 11394.txt -> 11394.txt
# Archivo renombrado: 11395.txt -> 11395.txt
# Archivo renombrado: 11396.txt -> 11396.txt
# Archivo renombrado: 11397.txt -> 11397.txt
# Archivo renombrado: 11399.txt -> 11399.txt
# Archivo renombrado: 11400.txt -> 11400.txt
# Archivo renombrado: 11402.txt -> 11402.txt
# Archivo renombrado: 11403.txt -> 11403.txt
# Archivo renombrado: 11405.txt -> 11405.txt
# Archivo renombrado: 11406.txt -> 11406.txt
# Archivo renombrado: 11407.txt -> 11407.txt
# Archivo renombrado: 11413.txt -> 11413.txt
# Archivo renombrado: 11415.txt -> 11415.txt
# Archivo renombrado: 11416.txt -> 11416.txt
# Archivo renombrado: 11417.txt -> 11417.txt
# Archivo renombrado: 11418.txt -> 11418.txt
# Archivo renombrado: 11420.txt -> 11420.txt
# Archivo renombrado: 11421.txt -> 11421.txt
# Archivo renombrado: 11422.txt -> 11422.txt
# Archivo renombrado: 11424.txt -> 11424.txt
# Archivo renombrado: 11425.txt -> 11425.txt
# Archivo renombrado: 11427.txt -> 11427.txt
# Archivo renombrado: 11428.txt -> 11428.txt
# Archivo renombrado: 11429.txt -> 11429.txt
# Archivo renombrado: 1143.txt -> 1143.txt
# Archivo renombrado: 11430.txt -> 11430.txt
# Archivo renombrado: 11431.txt -> 11431.txt
# Archivo renombrado: 11433.txt -> 11433.txt
# Archivo renombrado: 11435.txt -> 11435.txt
# Archivo renombrado: 11436.txt -> 11436.txt
# Archivo renombrado: 11437.txt -> 11437.txt
# Archivo renombrado: 11440.txt -> 11440.txt
# Archivo renombrado: 11441.txt -> 11441.txt
# Archivo renombrado: 11443.txt -> 11443.txt
# Archivo renombrado: 11444.txt -> 11444.txt
# Archivo renombrado: 11445.txt -> 11445.txt
# Archivo renombrado: 11446.txt -> 11446.txt
# Archivo renombrado: 11447.txt -> 11447.txt
# Archivo renombrado: 11449.txt -> 11449.txt
# Archivo renombrado: 11450.txt -> 11450.txt
# Archivo renombrado: 11451.txt -> 11451.txt
# Archivo renombrado: 11452.txt -> 11452.txt
# Archivo renombrado: 11455.txt -> 11455.txt
# Archivo renombrado: 11459.txt -> 11459.txt
# Archivo renombrado: 11460.txt -> 11460.txt
# Archivo renombrado: 11461.txt -> 11461.txt
# Archivo renombrado: 11462.txt -> 11462.txt
# Archivo renombrado: 11464.txt -> 11464.txt
# Archivo renombrado: 11465.txt -> 11465.txt
# Archivo renombrado: 11466.txt -> 11466.txt
# Archivo renombrado: 11468.txt -> 11468.txt
# Archivo renombrado: 11469.txt -> 11469.txt
# Archivo renombrado: 1147.txt -> 1147.txt
# Archivo renombrado: 11470.txt -> 11470.txt
# Archivo renombrado: 11475.txt -> 11475.txt
# Archivo renombrado: 11476.txt -> 11476.txt
# Archivo renombrado: 11477.txt -> 11477.txt
# Archivo renombrado: 11478.txt -> 11478.txt
# Archivo renombrado: 11479.txt -> 11479.txt
# Archivo renombrado: 1148.txt -> 1148.txt
# Archivo renombrado: 11481.txt -> 11481.txt
# Archivo renombrado: 11484.txt -> 11484.txt
# Archivo renombrado: 11487.txt -> 11487.txt
# Archivo renombrado: 11488.txt -> 11488.txt
# Archivo renombrado: 11490.txt -> 11490.txt
# Archivo renombrado: 11491.txt -> 11491.txt
# Archivo renombrado: 11492.txt -> 11492.txt
# Archivo renombrado: 11494.txt -> 11494.txt
# Archivo renombrado: 11496.txt -> 11496.txt
# Archivo renombrado: 11497.txt -> 11497.txt
# Archivo renombrado: 11498.txt -> 11498.txt
# Archivo renombrado: 11499.txt -> 11499.txt
# Archivo renombrado: 11500.txt -> 11500.txt
# Archivo renombrado: 11501.txt -> 11501.txt
# Archivo renombrado: 11503.txt -> 11503.txt
# Archivo renombrado: 11504.txt -> 11504.txt
# Archivo renombrado: 11505.txt -> 11505.txt
# Archivo renombrado: 11506.txt -> 11506.txt
# Archivo renombrado: 11507.txt -> 11507.txt
# Archivo renombrado: 11508.txt -> 11508.txt
# Archivo renombrado: 1151.txt -> 1151.txt
# Archivo renombrado: 11510.txt -> 11510.txt
# Archivo renombrado: 11514.txt -> 11514.txt
# Archivo renombrado: 11515.txt -> 11515.txt
# Archivo renombrado: 11519.txt -> 11519.txt
# Archivo renombrado: 1152.txt -> 1152.txt
# Archivo renombrado: 11522.txt -> 11522.txt
# Archivo renombrado: 11523.txt -> 11523.txt
# Archivo renombrado: 11526.txt -> 11526.txt
# Archivo renombrado: 11527.txt -> 11527.txt
# Archivo renombrado: 11528.txt -> 11528.txt
# Archivo renombrado: 11529.txt -> 11529.txt
# Archivo renombrado: 1153.txt -> 1153.txt
# Archivo renombrado: 11536.txt -> 11536.txt
# Archivo renombrado: 11539.txt -> 11539.txt
# Archivo renombrado: 1154.txt -> 1154.txt
# Archivo renombrado: 11540.txt -> 11540.txt
# Archivo renombrado: 11541.txt -> 11541.txt
# Archivo renombrado: 11543.txt -> 11543.txt
# Archivo renombrado: 11544.txt -> 11544.txt
# Archivo renombrado: 11545.txt -> 11545.txt
# Archivo renombrado: 11546.txt -> 11546.txt
# Archivo renombrado: 11549.txt -> 11549.txt
# Archivo renombrado: 11550.txt -> 11550.txt
# Archivo renombrado: 11551.txt -> 11551.txt
# Archivo renombrado: 11553.txt -> 11553.txt
# Archivo renombrado: 11554.txt -> 11554.txt
# Archivo renombrado: 11555.txt -> 11555.txt
# Archivo renombrado: 11558.txt -> 11558.txt
# Archivo renombrado: 11559.txt -> 11559.txt
# Archivo renombrado: 1156.txt -> 1156.txt
# Archivo renombrado: 11563.txt -> 11563.txt
# Archivo renombrado: 11564.txt -> 11564.txt
# Archivo renombrado: 11565.txt -> 11565.txt
# Archivo renombrado: 11566.txt -> 11566.txt
# Archivo renombrado: 11567.txt -> 11567.txt
# Archivo renombrado: 11568.txt -> 11568.txt
# Archivo renombrado: 11569.txt -> 11569.txt
# Archivo renombrado: 1157.txt -> 1157.txt
# Archivo renombrado: 11570.txt -> 11570.txt
# Archivo renombrado: 11571.txt -> 11571.txt
# Archivo renombrado: 11572.txt -> 11572.txt
# Archivo renombrado: 11574.txt -> 11574.txt
# Archivo renombrado: 11575.txt -> 11575.txt
# Archivo renombrado: 11578.txt -> 11578.txt
# Archivo renombrado: 11579.txt -> 11579.txt
# Archivo renombrado: 1158.txt -> 1158.txt
# Archivo renombrado: 11580.txt -> 11580.txt
# Archivo renombrado: 11584.txt -> 11584.txt
# Archivo renombrado: 11587.txt -> 11587.txt
# Archivo renombrado: 11588.txt -> 11588.txt
# Archivo renombrado: 1159.txt -> 1159.txt
# Archivo renombrado: 11597.txt -> 11597.txt
# Archivo renombrado: 11598.txt -> 11598.txt
# Archivo renombrado: 11599.txt -> 11599.txt
# Archivo renombrado: 1160.txt -> 1160.txt
# Archivo renombrado: 11602.txt -> 11602.txt
# Archivo renombrado: 11607.txt -> 11607.txt
# Archivo renombrado: 11608.txt -> 11608.txt
# Archivo renombrado: 11609.txt -> 11609.txt
# Archivo renombrado: 11610.txt -> 11610.txt
# Archivo renombrado: 11611.txt -> 11611.txt
# Archivo renombrado: 11612.txt -> 11612.txt
# Archivo renombrado: 11614.txt -> 11614.txt
# Archivo renombrado: 11617.txt -> 11617.txt
# Archivo renombrado: 11619.txt -> 11619.txt
# Archivo renombrado: 11621.txt -> 11621.txt
# Archivo renombrado: 11622.txt -> 11622.txt
# Archivo renombrado: 11623.txt -> 11623.txt
# Archivo renombrado: 11625.txt -> 11625.txt
# Archivo renombrado: 11627.txt -> 11627.txt
# Archivo renombrado: 11628.txt -> 11628.txt
# Archivo renombrado: 11629.txt -> 11629.txt
# Archivo renombrado: 11630.txt -> 11630.txt
# Archivo renombrado: 11632.txt -> 11632.txt
# Archivo renombrado: 11633.txt -> 11633.txt
# Archivo renombrado: 11634.txt -> 11634.txt
# Archivo renombrado: 11635.txt -> 11635.txt
# Archivo renombrado: 11636.txt -> 11636.txt
# Archivo renombrado: 11637.txt -> 11637.txt
# Archivo renombrado: 11638.txt -> 11638.txt
# Archivo renombrado: 11639.txt -> 11639.txt
# Archivo renombrado: 1164.txt -> 1164.txt
# Archivo renombrado: 11640.txt -> 11640.txt
# Archivo renombrado: 11643.txt -> 11643.txt
# Archivo renombrado: 11644.txt -> 11644.txt
# Archivo renombrado: 11645.txt -> 11645.txt
# Archivo renombrado: 11649.txt -> 11649.txt
# Archivo renombrado: 11655.txt -> 11655.txt
# Archivo renombrado: 11657.txt -> 11657.txt
# Archivo renombrado: 11658.txt -> 11658.txt
# Archivo renombrado: 11660.txt -> 11660.txt
# Archivo renombrado: 11661.txt -> 11661.txt
# Archivo renombrado: 11663.txt -> 11663.txt
# Archivo renombrado: 11664.txt -> 11664.txt
# Archivo renombrado: 11665.txt -> 11665.txt
# Archivo renombrado: 11666.txt -> 11666.txt
# Archivo renombrado: 11667.txt -> 11667.txt
# Archivo renombrado: 11668.txt -> 11668.txt
# Archivo renombrado: 1167.txt -> 1167.txt
# Archivo renombrado: 11671.txt -> 11671.txt
# Archivo renombrado: 11674.txt -> 11674.txt
# Archivo renombrado: 11679.txt -> 11679.txt
# Archivo renombrado: 11682.txt -> 11682.txt
# Archivo renombrado: 11683.txt -> 11683.txt
# Archivo renombrado: 11684.txt -> 11684.txt
# Archivo renombrado: 11685.txt -> 11685.txt
# Archivo renombrado: 11687.txt -> 11687.txt
# Archivo renombrado: 11689.txt -> 11689.txt
# Archivo renombrado: 1169.txt -> 1169.txt
# Archivo renombrado: 11690.txt -> 11690.txt
# Archivo renombrado: 11694.txt -> 11694.txt
# Archivo renombrado: 11696.txt -> 11696.txt
# Archivo renombrado: 11697.txt -> 11697.txt
# Archivo renombrado: 11699.txt -> 11699.txt
# Archivo renombrado: 1170.txt -> 1170.txt
# Archivo renombrado: 11700.txt -> 11700.txt
# Archivo renombrado: 11701.txt -> 11701.txt
# Archivo renombrado: 11702.txt -> 11702.txt
# Archivo renombrado: 11705.txt -> 11705.txt
# Archivo renombrado: 11706.txt -> 11706.txt
# Archivo renombrado: 11707.txt -> 11707.txt
# Archivo renombrado: 11708.txt -> 11708.txt
# Archivo renombrado: 11711.txt -> 11711.txt
# Archivo renombrado: 11713.txt -> 11713.txt
# Archivo renombrado: 11714.txt -> 11714.txt
# Archivo renombrado: 11716.txt -> 11716.txt
# Archivo renombrado: 11717.txt -> 11717.txt
# Archivo renombrado: 11721.txt -> 11721.txt
# Archivo renombrado: 11722.txt -> 11722.txt
# Archivo renombrado: 11723.txt -> 11723.txt
# Archivo renombrado: 11724.txt -> 11724.txt
# Archivo renombrado: 11725.txt -> 11725.txt
# Archivo renombrado: 11726.txt -> 11726.txt
# Archivo renombrado: 11727.txt -> 11727.txt
# Archivo renombrado: 11728.txt -> 11728.txt
# Archivo renombrado: 11729.txt -> 11729.txt
# Archivo renombrado: 1173.txt -> 1173.txt
# Archivo renombrado: 11730.txt -> 11730.txt
# Archivo renombrado: 11731.txt -> 11731.txt
# Archivo renombrado: 11733.txt -> 11733.txt
# Archivo renombrado: 11734.txt -> 11734.txt
# Archivo renombrado: 11736.txt -> 11736.txt
# Archivo renombrado: 11738.txt -> 11738.txt
# ...
# Archivo renombrado: 9371.txt -> 9371.txt
# Archivo renombrado: 9372.txt -> 9372.txt
# Archivo renombrado: 9373.txt -> 9373.txt
# Archivo renombrado: 9374.txt -> 9374.txt
# Archivo renombrado: 9377.txt -> 9377.txt
# Archivo renombrado: 9378.txt -> 9378.txt
# Archivo renombrado: 938.txt -> 938.txt
# Archivo renombrado: 9381.txt -> 9381.txt
# Archivo renombrado: 9382.txt -> 9382.txt
# Archivo renombrado: 9383.txt -> 9383.txt
# Archivo renombrado: 9385.txt -> 9385.txt
# Archivo renombrado: 9388.txt -> 9388.txt
# Archivo renombrado: 9389.txt -> 9389.txt
# Archivo renombrado: 939.txt -> 939.txt
# Archivo renombrado: 9392.txt -> 9392.txt
# Archivo renombrado: 9393.txt -> 9393.txt
# Archivo renombrado: 9397.txt -> 9397.txt
# Archivo renombrado: 9398.txt -> 9398.txt
# Archivo renombrado: 9399.txt -> 9399.txt
# Archivo renombrado: 94.txt -> 94.txt
# Archivo renombrado: 940.txt -> 940.txt
# Archivo renombrado: 9403.txt -> 9403.txt
# Archivo renombrado: 9405.txt -> 9405.txt
# Archivo renombrado: 9406.txt -> 9406.txt
# Archivo renombrado: 9408.txt -> 9408.txt
# Archivo renombrado: 941.txt -> 941.txt
# Archivo renombrado: 9410.txt -> 9410.txt
# Archivo renombrado: 9412.txt -> 9412.txt
# Archivo renombrado: 9413.txt -> 9413.txt
# Archivo renombrado: 9414.txt -> 9414.txt
# Archivo renombrado: 9415.txt -> 9415.txt
# Archivo renombrado: 9417.txt -> 9417.txt
# Archivo renombrado: 942.txt -> 942.txt
# Archivo renombrado: 9422.txt -> 9422.txt
# Archivo renombrado: 9423.txt -> 9423.txt
# Archivo renombrado: 9425.txt -> 9425.txt
# Archivo renombrado: 9426.txt -> 9426.txt
# Archivo renombrado: 9427.txt -> 9427.txt
# Archivo renombrado: 9428.txt -> 9428.txt
# Archivo renombrado: 9429.txt -> 9429.txt
# Archivo renombrado: 943.txt -> 943.txt
# Archivo renombrado: 9431.txt -> 9431.txt
# Archivo renombrado: 9432.txt -> 9432.txt
# Archivo renombrado: 9433.txt -> 9433.txt
# Archivo renombrado: 9434.txt -> 9434.txt
# Archivo renombrado: 9435.txt -> 9435.txt
# Archivo renombrado: 9436.txt -> 9436.txt
# Archivo renombrado: 9437.txt -> 9437.txt
# Archivo renombrado: 9438.txt -> 9438.txt
# Archivo renombrado: 944.txt -> 944.txt
# Archivo renombrado: 9441.txt -> 9441.txt
# Archivo renombrado: 9443.txt -> 9443.txt
# Archivo renombrado: 9444.txt -> 9444.txt
# Archivo renombrado: 9445.txt -> 9445.txt
# Archivo renombrado: 945.txt -> 945.txt
# Archivo renombrado: 9450.txt -> 9450.txt
# Archivo renombrado: 9453.txt -> 9453.txt
# Archivo renombrado: 9454.txt -> 9454.txt
# Archivo renombrado: 9463.txt -> 9463.txt
# Archivo renombrado: 9465.txt -> 9465.txt
# Archivo renombrado: 9469.txt -> 9469.txt
# Archivo renombrado: 9470.txt -> 9470.txt
# Archivo renombrado: 9472.txt -> 9472.txt
# Archivo renombrado: 9473.txt -> 9473.txt
# Archivo renombrado: 9475.txt -> 9475.txt
# Archivo renombrado: 9477.txt -> 9477.txt
# Archivo renombrado: 9478.txt -> 9478.txt
# Archivo renombrado: 9479.txt -> 9479.txt
# Archivo renombrado: 9484.txt -> 9484.txt
# Archivo renombrado: 9486.txt -> 9486.txt
# Archivo renombrado: 9487.txt -> 9487.txt
# Archivo renombrado: 9488.txt -> 9488.txt
# Archivo renombrado: 9489.txt -> 9489.txt
# Archivo renombrado: 949.txt -> 949.txt
# Archivo renombrado: 9491.txt -> 9491.txt
# Archivo renombrado: 9493.txt -> 9493.txt
# Archivo renombrado: 9497.txt -> 9497.txt
# Archivo renombrado: 9498.txt -> 9498.txt
# Archivo renombrado: 9499.txt -> 9499.txt
# Archivo renombrado: 95.txt -> 95.txt
# Archivo renombrado: 9502.txt -> 9502.txt
# Archivo renombrado: 9503.txt -> 9503.txt
# Archivo renombrado: 9505.txt -> 9505.txt
# Archivo renombrado: 9509.txt -> 9509.txt
# Archivo renombrado: 9510.txt -> 9510.txt
# Archivo renombrado: 9511.txt -> 9511.txt
# Archivo renombrado: 9515.txt -> 9515.txt
# Archivo renombrado: 9519.txt -> 9519.txt
# Archivo renombrado: 952.txt -> 952.txt
# Archivo renombrado: 9521.txt -> 9521.txt
# Archivo renombrado: 9525.txt -> 9525.txt
# Archivo renombrado: 9526.txt -> 9526.txt
# Archivo renombrado: 9527.txt -> 9527.txt
# Archivo renombrado: 953.txt -> 953.txt
# Archivo renombrado: 9530.txt -> 9530.txt
# Archivo renombrado: 9531.txt -> 9531.txt
# Archivo renombrado: 9532.txt -> 9532.txt
# Archivo renombrado: 9534.txt -> 9534.txt
# Archivo renombrado: 9535.txt -> 9535.txt
# Archivo renombrado: 9538.txt -> 9538.txt
# Archivo renombrado: 9539.txt -> 9539.txt
# Archivo renombrado: 9543.txt -> 9543.txt
# Archivo renombrado: 9544.txt -> 9544.txt
# Archivo renombrado: 9547.txt -> 9547.txt
# Archivo renombrado: 9549.txt -> 9549.txt
# Archivo renombrado: 955.txt -> 955.txt
# Archivo renombrado: 9550.txt -> 9550.txt
# Archivo renombrado: 9551.txt -> 9551.txt
# Archivo renombrado: 9554.txt -> 9554.txt
# Archivo renombrado: 9556.txt -> 9556.txt
# Archivo renombrado: 9557.txt -> 9557.txt
# Archivo renombrado: 9558.txt -> 9558.txt
# Archivo renombrado: 9559.txt -> 9559.txt
# Archivo renombrado: 9560.txt -> 9560.txt
# Archivo renombrado: 9561.txt -> 9561.txt
# Archivo renombrado: 9562.txt -> 9562.txt
# Archivo renombrado: 9563.txt -> 9563.txt
# Archivo renombrado: 9565.txt -> 9565.txt
# Archivo renombrado: 9566.txt -> 9566.txt
# Archivo renombrado: 9570.txt -> 9570.txt
# Archivo renombrado: 9572.txt -> 9572.txt
# Archivo renombrado: 9573.txt -> 9573.txt
# Archivo renombrado: 9576.txt -> 9576.txt
# Archivo renombrado: 9577.txt -> 9577.txt
# Archivo renombrado: 9578.txt -> 9578.txt
# Archivo renombrado: 958.txt -> 958.txt
# Archivo renombrado: 9580.txt -> 9580.txt
# Archivo renombrado: 9582.txt -> 9582.txt
# Archivo renombrado: 9583.txt -> 9583.txt
# Archivo renombrado: 9585.txt -> 9585.txt
# Archivo renombrado: 9587.txt -> 9587.txt
# Archivo renombrado: 9588.txt -> 9588.txt
# Archivo renombrado: 9590.txt -> 9590.txt
# Archivo renombrado: 9592.txt -> 9592.txt
# Archivo renombrado: 9597.txt -> 9597.txt
# Archivo renombrado: 9598.txt -> 9598.txt
# Archivo renombrado: 9599.txt -> 9599.txt
# Archivo renombrado: 96.txt -> 96.txt
# Archivo renombrado: 960.txt -> 960.txt
# Archivo renombrado: 9600.txt -> 9600.txt
# Archivo renombrado: 9603.txt -> 9603.txt
# Archivo renombrado: 9604.txt -> 9604.txt
# Archivo renombrado: 9605.txt -> 9605.txt
# Archivo renombrado: 9606.txt -> 9606.txt
# Archivo renombrado: 9607.txt -> 9607.txt
# Archivo renombrado: 9608.txt -> 9608.txt
# Archivo renombrado: 9610.txt -> 9610.txt
# Archivo renombrado: 9611.txt -> 9611.txt
# Archivo renombrado: 9612.txt -> 9612.txt
# Archivo renombrado: 9613.txt -> 9613.txt
# Archivo renombrado: 9614.txt -> 9614.txt
# Archivo renombrado: 9615.txt -> 9615.txt
# Archivo renombrado: 9617.txt -> 9617.txt
# Archivo renombrado: 9618.txt -> 9618.txt
# Archivo renombrado: 9619.txt -> 9619.txt
# Archivo renombrado: 9625.txt -> 9625.txt
# Archivo renombrado: 9626.txt -> 9626.txt
# Archivo renombrado: 9628.txt -> 9628.txt
# Archivo renombrado: 963.txt -> 963.txt
# Archivo renombrado: 9634.txt -> 9634.txt
# Archivo renombrado: 9635.txt -> 9635.txt
# Archivo renombrado: 9637.txt -> 9637.txt
# Archivo renombrado: 9638.txt -> 9638.txt
# Archivo renombrado: 9639.txt -> 9639.txt
# Archivo renombrado: 9640.txt -> 9640.txt
# Archivo renombrado: 9641.txt -> 9641.txt
# Archivo renombrado: 9642.txt -> 9642.txt
# Archivo renombrado: 9644.txt -> 9644.txt
# Archivo renombrado: 9647.txt -> 9647.txt
# Archivo renombrado: 9650.txt -> 9650.txt
# Archivo renombrado: 9652.txt -> 9652.txt
# Archivo renombrado: 9654.txt -> 9654.txt
# Archivo renombrado: 9656.txt -> 9656.txt
# Archivo renombrado: 9657.txt -> 9657.txt
# Archivo renombrado: 9661.txt -> 9661.txt
# Archivo renombrado: 9667.txt -> 9667.txt
# Archivo renombrado: 9668.txt -> 9668.txt
# Archivo renombrado: 9671.txt -> 9671.txt
# Archivo renombrado: 9674.txt -> 9674.txt
# Archivo renombrado: 9675.txt -> 9675.txt
# Archivo renombrado: 9677.txt -> 9677.txt
# Archivo renombrado: 9678.txt -> 9678.txt
# Archivo renombrado: 968.txt -> 968.txt
# Archivo renombrado: 9680.txt -> 9680.txt
# Archivo renombrado: 9681.txt -> 9681.txt
# Archivo renombrado: 9682.txt -> 9682.txt
# Archivo renombrado: 9686.txt -> 9686.txt
# Archivo renombrado: 9689.txt -> 9689.txt
# Archivo renombrado: 969.txt -> 969.txt
# Archivo renombrado: 9697.txt -> 9697.txt
# Archivo renombrado: 9698.txt -> 9698.txt
# Archivo renombrado: 9699.txt -> 9699.txt
# Archivo renombrado: 97.txt -> 97.txt
# Archivo renombrado: 9700.txt -> 9700.txt
# Archivo renombrado: 9701.txt -> 9701.txt
# Archivo renombrado: 9704.txt -> 9704.txt
# Archivo renombrado: 9705.txt -> 9705.txt
# Archivo renombrado: 9706.txt -> 9706.txt
# Archivo renombrado: 9707.txt -> 9707.txt
# Archivo renombrado: 971.txt -> 971.txt
# Archivo renombrado: 9712.txt -> 9712.txt
# Archivo renombrado: 9718.txt -> 9718.txt
# Archivo renombrado: 972.txt -> 972.txt
# Archivo renombrado: 9720.txt -> 9720.txt
# Archivo renombrado: 9723.txt -> 9723.txt
# Archivo renombrado: 9727.txt -> 9727.txt
# Archivo renombrado: 9728.txt -> 9728.txt
# Archivo renombrado: 9729.txt -> 9729.txt
# Archivo renombrado: 9730.txt -> 9730.txt
# Archivo renombrado: 9731.txt -> 9731.txt
# Archivo renombrado: 9733.txt -> 9733.txt
# Archivo renombrado: 9734.txt -> 9734.txt
# Archivo renombrado: 9735.txt -> 9735.txt
# Archivo renombrado: 9736.txt -> 9736.txt
# Archivo renombrado: 9737.txt -> 9737.txt
# Archivo renombrado: 9738.txt -> 9738.txt
# Archivo renombrado: 974.txt -> 974.txt
# Archivo renombrado: 9741.txt -> 9741.txt
# Archivo renombrado: 9742.txt -> 9742.txt
# Archivo renombrado: 9744.txt -> 9744.txt
# Archivo renombrado: 9745.txt -> 9745.txt
# Archivo renombrado: 9746.txt -> 9746.txt
# Archivo renombrado: 9747.txt -> 9747.txt
# Archivo renombrado: 9748.txt -> 9748.txt
# Archivo renombrado: 9749.txt -> 9749.txt
# Archivo renombrado: 9751.txt -> 9751.txt
# Archivo renombrado: 9752.txt -> 9752.txt
# Archivo renombrado: 9753.txt -> 9753.txt
# Archivo renombrado: 9754.txt -> 9754.txt
# Archivo renombrado: 9755.txt -> 9755.txt
# Archivo renombrado: 9756.txt -> 9756.txt
# Archivo renombrado: 976.txt -> 976.txt
# Archivo renombrado: 9760.txt -> 9760.txt
# Archivo renombrado: 9761.txt -> 9761.txt
# Archivo renombrado: 9763.txt -> 9763.txt
# Archivo renombrado: 9764.txt -> 9764.txt
# Archivo renombrado: 9767.txt -> 9767.txt
# Archivo renombrado: 9768.txt -> 9768.txt
# Archivo renombrado: 9769.txt -> 9769.txt
# Archivo renombrado: 977.txt -> 977.txt
# Archivo renombrado: 9770.txt -> 9770.txt
# Archivo renombrado: 9771.txt -> 9771.txt
# Archivo renombrado: 9772.txt -> 9772.txt
# Archivo renombrado: 9773.txt -> 9773.txt
# Archivo renombrado: 9777.txt -> 9777.txt
# Archivo renombrado: 9779.txt -> 9779.txt
# Archivo renombrado: 978.txt -> 978.txt
# Archivo renombrado: 9781.txt -> 9781.txt
# Archivo renombrado: 9782.txt -> 9782.txt
# Archivo renombrado: 9783.txt -> 9783.txt
# Archivo renombrado: 9784.txt -> 9784.txt
# Archivo renombrado: 9787.txt -> 9787.txt
# Archivo renombrado: 9792.txt -> 9792.txt
# Archivo renombrado: 9793.txt -> 9793.txt
# Archivo renombrado: 9795.txt -> 9795.txt
# Archivo renombrado: 9797.txt -> 9797.txt
# Archivo renombrado: 9799.txt -> 9799.txt
# Archivo renombrado: 98.txt -> 98.txt
# Archivo renombrado: 9801.txt -> 9801.txt
# Archivo renombrado: 9804.txt -> 9804.txt
# Archivo renombrado: 9805.txt -> 9805.txt
# Archivo renombrado: 9807.txt -> 9807.txt
# Archivo renombrado: 9809.txt -> 9809.txt
# Archivo renombrado: 981.txt -> 981.txt
# Archivo renombrado: 9810.txt -> 9810.txt
# Archivo renombrado: 9812.txt -> 9812.txt
# Archivo renombrado: 9814.txt -> 9814.txt
# Archivo renombrado: 9815.txt -> 9815.txt
# Archivo renombrado: 9816.txt -> 9816.txt
# Archivo renombrado: 9818.txt -> 9818.txt
# Archivo renombrado: 982.txt -> 982.txt
# Archivo renombrado: 9821.txt -> 9821.txt
# Archivo renombrado: 9822.txt -> 9822.txt
# Archivo renombrado: 9823.txt -> 9823.txt
# Archivo renombrado: 9824.txt -> 9824.txt
# Archivo renombrado: 9825.txt -> 9825.txt
# Archivo renombrado: 9827.txt -> 9827.txt
# Archivo renombrado: 9829.txt -> 9829.txt
# Archivo renombrado: 983.txt -> 983.txt
# Archivo renombrado: 9833.txt -> 9833.txt
# Archivo renombrado: 9834.txt -> 9834.txt
# Archivo renombrado: 9836.txt -> 9836.txt
# Archivo renombrado: 9837.txt -> 9837.txt
# Archivo renombrado: 9839.txt -> 9839.txt
# Archivo renombrado: 984.txt -> 984.txt
# Archivo renombrado: 9841.txt -> 9841.txt
# Archivo renombrado: 9844.txt -> 9844.txt
# Archivo renombrado: 9847.txt -> 9847.txt
# Archivo renombrado: 9848.txt -> 9848.txt
# Archivo renombrado: 9849.txt -> 9849.txt
# Archivo renombrado: 985.txt -> 985.txt
# Archivo renombrado: 9850.txt -> 9850.txt
# Archivo renombrado: 9851.txt -> 9851.txt
# Archivo renombrado: 9852.txt -> 9852.txt
# Archivo renombrado: 9853.txt -> 9853.txt
# Archivo renombrado: 9855.txt -> 9855.txt
# Archivo renombrado: 9857.txt -> 9857.txt
# Archivo renombrado: 9858.txt -> 9858.txt
# Archivo renombrado: 986.txt -> 986.txt
# Archivo renombrado: 9860.txt -> 9860.txt
# Archivo renombrado: 9861.txt -> 9861.txt
# Archivo renombrado: 9862.txt -> 9862.txt
# Archivo renombrado: 9864.txt -> 9864.txt
# Archivo renombrado: 9865.txt -> 9865.txt
# Archivo renombrado: 9866.txt -> 9866.txt
# Archivo renombrado: 9867.txt -> 9867.txt
# Archivo renombrado: 9868.txt -> 9868.txt
# Archivo renombrado: 9869.txt -> 9869.txt
# Archivo renombrado: 9871.txt -> 9871.txt
# Archivo renombrado: 9872.txt -> 9872.txt
# Archivo renombrado: 9874.txt -> 9874.txt
# Archivo renombrado: 9875.txt -> 9875.txt
# Archivo renombrado: 9878.txt -> 9878.txt
# Archivo renombrado: 988.txt -> 988.txt
# Archivo renombrado: 9880.txt -> 9880.txt
# Archivo renombrado: 9884.txt -> 9884.txt
# Archivo renombrado: 9891.txt -> 9891.txt
# Archivo renombrado: 9892.txt -> 9892.txt
# Archivo renombrado: 9893.txt -> 9893.txt
# Archivo renombrado: 9894.txt -> 9894.txt
# Archivo renombrado: 9896.txt -> 9896.txt
# Archivo renombrado: 9897.txt -> 9897.txt
# Archivo renombrado: 99.txt -> 99.txt
# Archivo renombrado: 9901.txt -> 9901.txt
# Archivo renombrado: 9902.txt -> 9902.txt
# Archivo renombrado: 9903.txt -> 9903.txt
# Archivo renombrado: 9904.txt -> 9904.txt
# Archivo renombrado: 9905.txt -> 9905.txt
# Archivo renombrado: 9906.txt -> 9906.txt
# Archivo renombrado: 9907.txt -> 9907.txt
# Archivo renombrado: 9909.txt -> 9909.txt
# Archivo renombrado: 991.txt -> 991.txt
# Archivo renombrado: 9912.txt -> 9912.txt
# Archivo renombrado: 9913.txt -> 9913.txt
# Archivo renombrado: 9914.txt -> 9914.txt
# Archivo renombrado: 9915.txt -> 9915.txt
# Archivo renombrado: 9918.txt -> 9918.txt
# Archivo renombrado: 9919.txt -> 9919.txt
# Archivo renombrado: 9920.txt -> 9920.txt
# Archivo renombrado: 9923.txt -> 9923.txt
# Archivo renombrado: 9925.txt -> 9925.txt
# Archivo renombrado: 9926.txt -> 9926.txt
# Archivo renombrado: 9927.txt -> 9927.txt
# Archivo renombrado: 9928.txt -> 9928.txt
# Archivo renombrado: 9929.txt -> 9929.txt
# Archivo renombrado: 9930.txt -> 9930.txt
# Archivo renombrado: 9933.txt -> 9933.txt
# Archivo renombrado: 9934.txt -> 9934.txt
# Archivo renombrado: 9936.txt -> 9936.txt
# Archivo renombrado: 9937.txt -> 9937.txt
# Archivo renombrado: 9939.txt -> 9939.txt
# Archivo renombrado: 9940.txt -> 9940.txt
# Archivo renombrado: 9941.txt -> 9941.txt
# Archivo renombrado: 9942.txt -> 9942.txt
# Archivo renombrado: 9943.txt -> 9943.txt
# Archivo renombrado: 9946.txt -> 9946.txt
# Archivo renombrado: 9947.txt -> 9947.txt
# Archivo renombrado: 995.txt -> 995.txt
# Archivo renombrado: 9952.txt -> 9952.txt
# Archivo renombrado: 9953.txt -> 9953.txt
# Archivo renombrado: 9954.txt -> 9954.txt
# Archivo renombrado: 9955.txt -> 9955.txt
# Archivo renombrado: 9956.txt -> 9956.txt
# Archivo renombrado: 9957.txt -> 9957.txt
# Archivo renombrado: 9958.txt -> 9958.txt
# Archivo renombrado: 9959.txt -> 9959.txt
# Archivo renombrado: 9961.txt -> 9961.txt
# Archivo renombrado: 9963.txt -> 9963.txt
# Archivo renombrado: 9964.txt -> 9964.txt
# Archivo renombrado: 9965.txt -> 9965.txt
# Archivo renombrado: 9967.txt -> 9967.txt
# Archivo renombrado: 9970.txt -> 9970.txt
# Archivo renombrado: 9971.txt -> 9971.txt
# Archivo renombrado: 9972.txt -> 9972.txt
# Archivo renombrado: 9973.txt -> 9973.txt
# Archivo renombrado: 9974.txt -> 9974.txt
# Archivo renombrado: 9975.txt -> 9975.txt
# Archivo renombrado: 9976.txt -> 9976.txt
# Archivo renombrado: 9977.txt -> 9977.txt
# Archivo renombrado: 9978.txt -> 9978.txt
# Archivo renombrado: 998.txt -> 998.txt
# Archivo renombrado: 9981.txt -> 9981.txt
# Archivo renombrado: 9982.txt -> 9982.txt
# Archivo renombrado: 9984.txt -> 9984.txt
# Archivo renombrado: 9985.txt -> 9985.txt
# Archivo renombrado: 9988.txt -> 9988.txt
# Archivo renombrado: 9989.txt -> 9989.txt
# Archivo renombrado: 999.txt -> 999.txt
# Archivo renombrado: 9992.txt -> 9992.txt
# Archivo renombrado: 9993.txt -> 9993.txt
# Archivo renombrado: 9994.txt -> 9994.txt
# Archivo renombrado: 9995.txt -> 9995.txt

# %% [markdown]
# Se importan las librerias necesarias.

# %%
import csv
import html

# %%
# Ruta de la carpeta con los archivos .txt
ruta_carpeta = "./data"

# Ruta del archivo cats.txt
ruta_categorias = "./cats.txt"

# Ruta de salida para el archivo CSV
ruta_csv = "database.csv"

# %% [markdown]
# Cargar las categorías desde cats.txt en un diccionario

# %%
categorias = {}
with open(ruta_categorias, "r") as f:
    for linea in f:
        partes = linea.strip().split(maxsplit=1)  # Dividir en nombre y categoría
        if len(partes) == 2:  # Verificar que tiene nombre y categoría
            nombre_archivo = partes[0].split("/")[-1]  # Extraer solo el número del archivo
            categorias[nombre_archivo] = partes[1]  # Guardar la categoría completa

# %% [markdown]
# Creación CSV database con las siguientes columnas:
# - id
# - documento
# - titulo
# - texto
# - cats

# %%
# Crear el CSV
with open(ruta_csv, "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["id", "document", "title", "text", "cats"])  # Escribir encabezado

    # Procesar cada archivo .txt en la carpeta
    for archivo in os.listdir(ruta_carpeta):
        if archivo.endswith(".txt"):  # Procesar solo archivos .txt
            ruta_archivo = os.path.join(ruta_carpeta, archivo)

            # Leer el contenido del archivo
            try:
                with open(ruta_archivo, "r", encoding="utf-8") as f:
                    lineas = f.readlines()
            except UnicodeDecodeError:
                with open(ruta_archivo, "r", encoding="latin-1") as f:
                    lineas = f.readlines()

            if lineas:  # Verificar que el archivo tiene contenido
                # Extraer campos
                nombre_archivo = os.path.splitext(archivo)[0]  # Quitar extensión
                documento = "".join(lineas).strip()  # Todo el contenido del archivo
                documento = html.unescape(documento)  # Decodificar entidades HTML
                titulo = lineas[0].strip()  # Primera línea como título
                texto = " ".join(lineas[1:]).strip()  # Texto excluyendo la primera línea
                categoria = categorias.get(nombre_archivo, "Sin categoría")  # Obtener categoría

                # Escribir fila en el CSV
                writer.writerow([nombre_archivo, documento, titulo, texto, categoria])

print(f"Archivo CSV creado en: {ruta_csv}")
# Out:
# Archivo CSV creado en: database.csv

# %% [markdown]
# # Procesamiento

# %%
import pandas as pd
import string
from nltk.stem import PorterStemmer
import re

# %%
# Cargar el archivo CSV
ruta_csv = "database.csv"
corpus = pd.read_csv(ruta_csv)

# %% [markdown]
# Se agrega la columna preproc_doc en la cual se hará el preprocesamiento del contenido de cada documento de la database.

# %%
corpus['preproc_doc'] = corpus['document']

# %% [markdown]
# En la función minusculas se realiza la conversión a minúsculas.

# %%
def minusculas(texto):
    
    texto = texto.lower()  # Convertir a minúsculas
    
    return texto


corpus['preproc_doc'] = corpus['preproc_doc'].apply(minusculas)

# %% [markdown]
# En la función limpiar_texto se realiza la eliminación de caracteres especiales.

# %%
def limpiar_texto(texto):

    texto = re.sub(r'&lt;[^ ]*', '', texto)  # Eliminar el patrón desde &lt; hasta el primer espacio
    texto = re.sub(r'[<>]', '', texto)  # Remover caracteres sobrantes como < y >
    texto = re.sub(r'[.,;!?-]', '', texto)  # Remover caracteres específicos como , . ; ! ?
    texto = re.sub(r'[^\w\s]', '', texto)  # Remover cualquier otro carácter especial
    texto = re.sub(r'\s+', ' ', texto).strip()  # Reemplazar múltiples espacios por uno solo
    
    return texto


corpus['preproc_doc'] = corpus['preproc_doc'].apply(limpiar_texto) 
corpus['title'] = corpus['title'].apply(limpiar_texto)  # Limpiar título

# %% [markdown]
# Tokenización

# %%
def tokenizar_texto(texto):
    """Tokeniza el texto dividiéndolo en palabras."""
    return texto.split()

corpus['preproc_doc'] = corpus['preproc_doc'].apply(tokenizar_texto)

# %% [markdown]
# Eliminación de stopwords.

# %%
# Cargar el archivo de stopwords personalizado
ruta_stopwords = "stopwords"  # Ruta al archivo de stopwords
with open(ruta_stopwords, "r", encoding="utf-8") as f:
    custom_stopwords = set(f.read().splitlines())  # Leer stopwords y convertir a conjunto

def eliminar_stopwords(tokens):
    """Elimina las stopwords del texto tokenizado usando el archivo stopwords."""
    return [word for word in tokens if word not in custom_stopwords]

corpus['preproc_doc'] = corpus['preproc_doc'].apply(eliminar_stopwords)

# %% [markdown]
# Stemming

# %%
def aplicar_stemming(tokens):
    """Aplica stemming a los tokens."""
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in tokens]

corpus['preproc_doc'] = corpus['preproc_doc'].apply(aplicar_stemming)

# %% [markdown]
# Se guarda el corpus preprocesado en el mismo database.csv

# %%
corpus.to_csv(ruta_csv, index=False)

print("Corpus preprocesado guardado en 'database.csv'")
# Out:
# Corpus preprocesado guardado en 'database.csv'

# %% [markdown]
# # Vectorización

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import pandas as pd
import numpy as np

print("Todas las librerias se importaron correctamente.")
# Out:
# Todas las librerias se importaron correctamente.

# %% [markdown]
# Cargar el archivo database.csv

# %%
ruta_procesado = "database.csv"
corpus = pd.read_csv(ruta_procesado)

# %% [markdown]
# Converttir la lista de tokens de nuevo a texto y como listas para Word2Vec

# %%
corpus['tokens_list'] = corpus['preproc_doc'].apply(eval)  # Convertir strings de listas a listas reales
corpus['tokens_text'] = corpus['tokens_list'].apply(lambda x: " ".join(x))  # Convertir lista a texto

# %% [markdown]
# Bag of Words (BoW)

# %%
# Bag of Words (BoW)
bow_vectorizer = CountVectorizer()
bow_matrix = bow_vectorizer.fit_transform(corpus['tokens_text'])

# Guardar la matriz en archivo CSV
pd.DataFrame(bow_matrix.toarray(), columns=bow_vectorizer.get_feature_names_out()).to_csv("bow_matrix.csv", index=False)

# %% [markdown]
# TF-IDF

# %%
# TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus['tokens_text'])

# Guardar la matriz en archivo CSV
pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out()).to_csv("tfidf_matrix.csv", index=False)

# %% [markdown]
# Word2Vec

# %%
# Word2Vec
# Entrenar el modelo Word2Vec con las listas de tokens
word2vec_model = Word2Vec(sentences=corpus['tokens_list'], vector_size=100, window=5, min_count=1, workers=4)

# Crear una representación vectorial promedio para cada documento
def get_average_word2vec(tokens, model, vector_size):
    """Obtiene el promedio de vectores de Word2Vec para un documento."""
    vector = np.zeros(vector_size)
    count = 0
    for word in tokens:
        if word in model.wv:
            vector += model.wv[word]
            count += 1
    return vector / count if count > 0 else vector

# Generar matriz de Word2Vec para el corpus
word2vec_matrix = np.array([get_average_word2vec(tokens, word2vec_model, 100) for tokens in corpus['tokens_list']])

# Guardar la matriz en archivo CSV
pd.DataFrame(word2vec_matrix).to_csv("word2vec_matrix.csv", index=False)

# %% [markdown]
# # Indexación

# %%
import pandas as pd
import numpy as np
import json
from sklearn.feature_extraction.text import TfidfVectorizer

# Cargar la base de datos preprocesada
database = pd.read_csv("database.csv")

# Cargar las matrices previamente generadas
bow_matrix = pd.read_csv("bow_matrix.csv")
tfidf_matrix = pd.read_csv("tfidf_matrix.csv")
word2vec_matrix = pd.read_csv("word2vec_matrix.csv")

# Crear un índice invertido basado en la matriz TF-IDF
def build_inverted_index(tfidf_matrix, feature_names):
    """Construir un índice invertido a partir de la matriz TF-IDF."""
    inverted_index = {}
    for term_idx, term in enumerate(feature_names):
        # Obtener los documentos que contienen el término
        docs_with_term = tfidf_matrix.iloc[:, term_idx].to_numpy().nonzero()[0]
        inverted_index[term] = docs_with_term.tolist()
    return inverted_index

# Cargar el texto procesado para entrenar el vectorizador TF-IDF
corpus = database["preproc_doc"]  # Usar la columna completa de texto preprocesado
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix_transformed = tfidf_vectorizer.fit_transform(corpus)

# Convertir la matriz TF-IDF en DataFrame para su manipulación
tfidf_matrix_df = pd.DataFrame(
    tfidf_matrix_transformed.toarray(),
    columns=tfidf_vectorizer.get_feature_names_out()
)

# Construir el índice invertido
feature_names = tfidf_vectorizer.get_feature_names_out()
inverted_index = build_inverted_index(tfidf_matrix_df, feature_names)

# Guardar el índice invertido
with open("inverted_index.json", "w") as f:
    json.dump(inverted_index, f)

print("Índice invertido creado y guardado como 'inverted_index.json'.")
# Out:
# Índice invertido creado y guardado como 'inverted_index.json'.

# %%
import json

# Cargar el índice invertido
with open("inverted_index.json", "r") as f:
    inverted_index = json.load(f)

def buscar_termino(termino, indice):
    """
    Busca un término en el índice invertido y devuelve los documentos donde aparece.
    """
    if termino in indice:
        return indice[termino]
    else:
        return []

def buscar_consulta(consulta, indice):
    """
    Busca una consulta compuesta por varios términos en el índice invertido.
    Devuelve una lista de documentos donde aparecen todos los términos.
    """
    terminos = consulta.split()  # Dividir la consulta en términos
    resultados = [set(buscar_termino(termino, indice)) for termino in terminos]

    # Intersección de resultados (documentos que contienen todos los términos)
    if resultados:
        documentos_relevantes = set.intersection(*resultados)
        return list(documentos_relevantes)
    else:
        return []

# Ejemplo de búsqueda
consulta = "econo"
resultados = buscar_consulta(consulta, inverted_index)

print(f"Documentos relevantes para la consulta '{consulta}': {resultados}")
# Out:
# Documentos relevantes para la consulta 'automotive': []

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Cargar el corpus procesado
ruta_corpus = "database_preprocessed.csv"
corpus = pd.read_csv(ruta_corpus)

# Crear el vectorizador TF-IDF y ajustar al texto
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(corpus["tokens_text"])  # Matriz TF-IDF

# Función de búsqueda con similitud coseno
def buscar_similitud_coseno(consulta, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5):
    """
    Realiza una búsqueda basada en similitud coseno usando TF-IDF.
    
    Parámetros:
        consulta: Consulta de búsqueda (str).
        tfidf_vectorizer: Vectorizador TF-IDF ajustado al corpus.
        tfidf_matrix: Matriz TF-IDF del corpus.
        corpus: DataFrame con el corpus original.
        top_n: Número de documentos relevantes a devolver.
    
    Retorna:
        DataFrame con los documentos más relevantes y sus puntuaciones de similitud.
    """
    # Vectorizar la consulta
    consulta_vector = tfidf_vectorizer.transform([consulta])

    # Calcular similitud coseno entre la consulta y todos los documentos
    similitudes = cosine_similarity(consulta_vector, tfidf_matrix).flatten()

    # Obtener los índices de los documentos más similares
    top_indices = similitudes.argsort()[-top_n:][::-1]  # Top N en orden descendente

    # Crear un DataFrame con los resultados relevantes
    resultados = corpus.iloc[top_indices].copy()
    resultados["similitud"] = similitudes[top_indices]

    return resultados

# Ejemplo de búsqueda
consulta = "asian cocoa"
resultados = buscar_similitud_coseno(consulta, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5)

# Mostrar los resultados
print("Resultados de búsqueda:")
print(resultados[["nombre del archivo", "similitud", "texto"]])

# Guardar resultados en un archivo CSV
resultados.to_csv("resultados_busqueda.csv", index=False)
print("Resultados guardados en 'resultados_busqueda.csv'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 46
#      44 # Ejemplo de búsqueda
#      45 consulta = "automotive"
# ---> 46 resultados = buscar_similitud_coseno(consulta, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5)
#      48 # Mostrar los resultados
#      49 print("Resultados de búsqueda:")
#
# Cell In[7], line 28, in buscar_similitud_coseno(consulta, tfidf_vectorizer, tfidf_matrix, corpus, top_n)
#      14 def buscar_similitud_coseno(consulta, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5):
#      15     """
#      16     Realiza una búsqueda basada en similitud coseno usando TF-IDF.
#      17
#    (...)
#      26         DataFrame con los documentos más relevantes y sus puntuaciones de similitud.
#      27     """
# ---> 28     consulta_preprocesada = preprocesar_query(consulta)  # Preprocesar la consulta
#      29     # Vectorizar la consulta
#      30     consulta_vector = tfidf_vectorizer.transform([consulta_preprocesada])  # Vectorizar la consulta preprocesada
#
# Cell In[5], line 6, in preprocesar_query(query)
#       2 def preprocesar_query(query):
#       3     """
#       4     Aplica el mismo preprocesamiento que se aplica al corpus a una consulta.
#       5     """
# ----> 6     query = limpiar_texto(query)  # Normalizar texto (minúsculas y eliminar puntuación)
#       7     tokens = tokenizar_texto(query)  # Tokenizar
#       8     tokens = eliminar_stopwords(tokens)  # Eliminar stopwords
#
# NameError: name 'limpiar_texto' is not defined

# %% [markdown]
# 2.6. Evaluación del Sistema

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Resultados esperados (relevantes) para cada consulta (Ground Truth)
consultas = {
    "bahia cocoa": [0, 318, 3773, 4862, 7727],  # Índices de documentos relevantes para esta consulta
    "asian cocoa": [4862, 318, 7727, 319, 366],  # Otra consulta
}

# Función para calcular métricas de evaluación
def evaluar_sistema(consultas, tfidf_vectorizer, tfidf_matrix, corpus, top_n=5):
    resultados = []
    for consulta, relevantes_esperados in consultas.items():
        # Realizar búsqueda con similitud coseno
        consulta_vector = tfidf_vectorizer.transform([consulta])
        similitudes = cosine_similarity(consulta_vector, tfidf_matrix).flatten()
        indices_top = similitudes.argsort()[-top_n:][::-1]  # Índices de documentos más relevantes

        # Calcular métricas
        y_true = [1 if idx in relevantes_esperados else 0 for idx in range(len(corpus))]
        y_pred = [1 if idx in indices_top else 0 for idx in range(len(corpus))]

        precision = precision_score(y_true, y_pred, zero_division=0)
        recall = recall_score(y_true, y_pred, zero_division=0)
        f1 = f1_score(y_true, y_pred, zero_division=0)

        # Guardar los resultados de la consulta
        resultados.append({
            "consulta": consulta,
            "precision": precision,
            "recall": recall,
            "f1_score": f1,
            "relevantes_encontrados": indices_top.tolist(),
        })

    return resultados

# Evaluar el sistema
resultados_evaluacion = evaluar_sistema(consultas, tfidf_vectorizer, tfidf_matrix, corpus)

# Mostrar los resultados
for resultado in resultados_evaluacion:
    print(f"Consulta: {resultado['consulta']}")
    print(f"  Precisión: {resultado['precision']:.2f}")
    print(f"  Recuperación: {resultado['recall']:.2f}")
    print(f"  F1-Score: {resultado['f1_score']:.2f}")
    print(f"  Documentos encontrados: {resultado['relevantes_encontrados']}")
    print()

# Guardar los resultados en un archivo CSV
import pandas as pd
df_resultados = pd.DataFrame(resultados_evaluacion)
df_resultados.to_csv("evaluacion_sistema.csv", index=False)
print("Resultados de evaluación guardados en 'evaluacion_sistema.csv'.")
# Out:
# Consulta: bahia cocoa
#   Precisión: 1.00
#   Recuperación: 1.00
#   F1-Score: 1.00
#   Documentos encontrados: [318, 4862, 0, 3773, 7727]
#
# Consulta: asian cocoa
#   Precisión: 1.00
#   Recuperación: 1.00
#   F1-Score: 1.00
#   Documentos encontrados: [4862, 318, 7727, 319, 366]
#
# Resultados de evaluación guardados en 'evaluacion_sistema.csv'.
